# %%
import numpy as np
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# deck         object
# dtype: object

# %%
titanic.count()
# Out:
# survived    891
# pclass      891
# sex         891
# age         714
# sibsp       891
# parch       891
# fare        891
# embarked    889
# deck        203
# dtype: int64

# %%
titanic.survived.sum()
# Out:
# 342

# %%
342/891
# Out:
# 0.3838383838383838

# %%
titanic.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      2
# deck        688
# dtype: int64

# %%
titanic.head()
titanic.tail()
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.age.dtype
# Out:
# dtype('float64')

# %%
age = titanic.age

# %%
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
age.dtype
# Out:
# dtype('float64')

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe(include = 'all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked deck
# count   891.000000      889  203
# ...

# %%
age = titanic.age.copy()

# %%
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
age.dtype
type(age)
# Out:
# pandas.core.series.Series

# %%
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
age.fillna(age.mean(), inplace = True)

# %%
age
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
len(titanic.age)
# Out:
# 891

# %%
age.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 age.index()
#
# TypeError: 'RangeIndex' object is not callable

# %%
age.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
age.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35928\553789258.py in ?()
# ----> 1 age.columns
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
age.to_frame('hello')
# Out:
#          hello
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# ..         ...
# 886  27.000000
# 887  19.000000
# 888  29.699118
# 889  26.000000
# 890  32.000000
#
# [891 rows x 1 columns]

# %%
age
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
type(age.to_frame)
# Out:
# method

# %%
age.sum(skipna = True)
# Out:
# 26461.91382352941

# %%
age.sum()
# Out:
# 26461.91382352941

# %%
age.nunique()
# Out:
# 89

# %%
age.unique()
# Out:
# array([22.        , 38.        , 26.        , 35.        , 29.69911765,
#        54.        ,  2.        , 27.        , 14.        ,  4.        ,
#        58.        , 20.        , 39.        , 55.        , 31.        ,
#        34.        , 15.        , 28.        ,  8.        , 19.        ,
#        40.        , 66.        , 42.        , 21.        , 18.        ,
#         3.        ,  7.        , 49.        , 29.        , 65.        ,
#        28.5       ,  5.        , 11.        , 45.        , 17.        ,
#        32.        , 16.        , 25.        ,  0.83      , 30.        ,
#        33.        , 23.        , 24.        , 46.        , 59.        ,
#        71.        , 37.        , 47.        , 14.5       , 70.5       ,
#        32.5       , 12.        ,  9.        , 36.5       , 51.        ,
#        55.5       , 40.5       , 44.        ,  1.        , 61.        ,
#        56.        , 50.        , 36.        , 45.5       , 20.5       ,
# ...

# %%
age.mean()
# Out:
# 29.69911764705882

# %%
age.max()
# Out:
# 80.0

# %%
age.value_counts(sort = True, ascending = False)
# Out:
# age
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: count, Length: 89, dtype: int64

# %%
age.value_counts(sort = True, bins = 10000000)
# Out:
# (29.699113, 29.699121]    177
# (24.0, 24.000008]          30
# (21.999995, 22.000003]     27
# (17.999994, 18.000002]     26
# (29.999997, 30.000005]     25
#                          ...
# (26.947149, 26.947157]      0
# (26.947157, 26.947165]      0
# (26.947165, 26.947173]      0
# (26.947173, 26.947181]      0
# (40.21, 40.210008]          0
# Name: count, Length: 10000000, dtype: int64

# %%
age.count()
# Out:
# 891

# %%
age.value_counts()
# Out:
# age
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: count, Length: 89, dtype: int64

# %%
age.count()
# Out:
# 891

# %%
age.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
age.describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: age, dtype: float64

# %%
summer = pd.read_csv('summer.csv')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender',
#        'Event', 'Medal'],
#       dtype='object')

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.describe(include = 'all')
# Out:
#                 Year    City     Sport Discipline          Athlete Country  \
# count   31165.000000   31165     31165      31165            31165   31161
# unique           NaN      22        43         67            22762     147
# top              NaN  London  Aquatics  Athletics  PHELPS, Michael     USA
# freq             NaN    3567      4170       3638               22    4585
# mean     1970.482785     NaN       NaN        NaN              NaN     NaN
# std        33.158416     NaN       NaN        NaN              NaN     NaN
# min      1896.000000     NaN       NaN        NaN              NaN     NaN
# 25%      1948.000000     NaN       NaN        NaN              NaN     NaN
# 50%      1980.000000     NaN       NaN        NaN              NaN     NaN
# 75%      2000.000000     NaN       NaN        NaN              NaN     NaN
# max      2012.000000     NaN       NaN        NaN              NaN     NaN
#
#        Gender     Event  Medal
# count   31165     31165  31165
# ...

# %%
athlete = summer.Athlete

# %%
athlete.shape
# Out:
# (31165,)

# %%
athlete.size
# Out:
# 31165

# %%
athlete.unique()
# Out:
# array(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios', ...,
#        'TOTROV, Rustam', 'ALEKSANYAN, Artur', 'LIDBERG, Jimmy'],
#       dtype=object)

# %%
athlete.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object>

# %%
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Athlete        HAJOS, Alfred
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: 0, dtype: object

# %%
summer.iloc[100:,3:]
# Out:
#                 Discipline                    Athlete Country Gender  \
# 100            Artistic G.             FLATOW, Alfred     GER    Men
# 101            Artistic G.       FLATOW, Gustav Felix     GER    Men
# 102            Artistic G.              HILMAR, Georg     GER    Men
# 103            Artistic G.             HOFMANN, Fritz     GER    Men
# 104            Artistic G.          MANTEUFFEL, Fritz     GER    Men
# ...                    ...                        ...     ...    ...
# 31160  Wrestling Freestyle         JANIKOWSKI, Damian     POL    Men
# 31161  Wrestling Freestyle  REZAEI, Ghasem Gholamreza     IRI    Men
# 31162  Wrestling Freestyle             TOTROV, Rustam     RUS    Men
# 31163  Wrestling Freestyle          ALEKSANYAN, Artur     ARM    Men
# 31164  Wrestling Freestyle             LIDBERG, Jimmy     SWE    Men
#
#                      Event   Medal
# 100    Team, Parallel Bars    Gold
# 101    Team, Parallel Bars    Gold
# ...

# %%
athlete = pd.read_csv('summer.csv', usecols = ['Athlete']).squeeze('columns')

# %%
athlete
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
pd.DataFrame()
# Out:
#               Name  Age   City
# 0   Prateek Chawla   24  Delhi
# 10  Prateek Chawla   24  Delhi

# %%
test = pd.Series(summer.Athlete)

# %%
test
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.Athlete
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
sales = pd.Series(np.arange(0,20,2))

# %%
sales
# Out:
# 0     0
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# 6    12
# 7    14
# 8    16
# 9    18
# dtype: int32

# %%
dic = {"mon": 10, "Tues" : 20, "Wed":30}

# %%
test = pd.Series(dic,name = 'sales')

# %%
test
# Out:
# mon     10
# Tues    20
# Wed     30
# Name: sales, dtype: int64

# %%
age = summer.Athlete
age
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
age.iloc[-1]
# Out:
# 'LIDBERG, Jimmy'

# %%
age.iloc["HERSCHMANN, Otto"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 age.iloc["HERSCHMANN, Otto"]
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1749, in _iLocIndexer._getitem_axis(self, key, axis)
#    1747 key = item_from_zerodim(key)
#    1748 if not is_integer(key):
# -> 1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
#    1752 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
age
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.sort_values('Year',ascending = False)
# Out:
#        Year    City       Sport           Discipline               Athlete  \
# 31164  2012  London   Wrestling  Wrestling Freestyle        LIDBERG, Jimmy
# 29885  2012  London      Boxing               Boxing       NEVIN, John Joe
# 29857  2012  London  Basketball           Basketball          BISHOP, Abby
# 29858  2012  London  Basketball           Basketball    CAMBAGE, Elizabeth
# 29859  2012  London  Basketball           Basketball      HARROWER, Kristi
# ...     ...     ...         ...                  ...                   ...
# 101    1896  Athens  Gymnastics          Artistic G.  FLATOW, Gustav Felix
# 100    1896  Athens  Gymnastics          Artistic G.        FLATOW, Alfred
# 99     1896  Athens  Gymnastics          Artistic G.        BÖCKER, Konrad
# 98     1896  Athens  Gymnastics          Artistic G.  MITROPOULOS, Ioannis
# 0      1896  Athens    Aquatics             Swimming         HAJOS, Alfred
#
#       Country Gender                Event   Medal
# ...

# %%
summer.sort_index(ascending = False)
# Out:
#        Year    City      Sport           Discipline  \
# 31164  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31160  2012  London  Wrestling  Wrestling Freestyle
# ...     ...     ...        ...                  ...
# 4      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 0      1896  Athens   Aquatics             Swimming
#
#                          Athlete Country Gender                       Event  \
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# ...

# %%
summer.set_index('Year')
# Out:
#         City      Sport           Discipline                    Athlete  \
# Year
# 1896  Athens   Aquatics             Swimming              HAJOS, Alfred
# 1896  Athens   Aquatics             Swimming           HERSCHMANN, Otto
# 1896  Athens   Aquatics             Swimming          DRIVAS, Dimitrios
# 1896  Athens   Aquatics             Swimming         MALOKINIS, Ioannis
# 1896  Athens   Aquatics             Swimming         CHASAPIS, Spiridon
# ...      ...        ...                  ...                        ...
# 2012  London  Wrestling  Wrestling Freestyle         JANIKOWSKI, Damian
# 2012  London  Wrestling  Wrestling Freestyle  REZAEI, Ghasem Gholamreza
# 2012  London  Wrestling  Wrestling Freestyle             TOTROV, Rustam
# 2012  London  Wrestling  Wrestling Freestyle          ALEKSANYAN, Artur
# 2012  London  Wrestling  Wrestling Freestyle             LIDBERG, Jimmy
#
#      Country Gender                       Event   Medal
# Year
# ...

# %%
summer.iloc[2012:]
# Out:
#        Year       City      Sport           Discipline  \
# 2012   1912  Stockholm   Aquatics           Water polo
# 2013   1912  Stockholm   Aquatics           Water polo
# 2014   1912  Stockholm   Aquatics           Water polo
# 2015   1912  Stockholm  Athletics            Athletics
# 2016   1912  Stockholm  Athletics            Athletics
# ...     ...        ...        ...                  ...
# 31160  2012     London  Wrestling  Wrestling Freestyle
# 31161  2012     London  Wrestling  Wrestling Freestyle
# 31162  2012     London  Wrestling  Wrestling Freestyle
# 31163  2012     London  Wrestling  Wrestling Freestyle
# 31164  2012     London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender       Event   Medal
# 2012             HANSSON, Pontus     SWE    Men  Water Polo  Silver
# 2013          JULIN, Harald S.A.     SWE    Men  Water Polo  Silver
# 2014        KUMFELDT, K. Torsten     SWE    Men  Water Polo  Silver
# ...

# %%
sales.sort_values(ascending = False, na_position = 'last', inplace = True)

# %%
sales
# Out:
# 9    18
# 8    16
# 7    14
# 6    12
# 5    10
# 4     8
# 3     6
# 2     4
# 1     2
# 0     0
# dtype: int32

# %%
summer.sort_values('Athlete', inplace = True, na_position = 'last')

# %%
summer
# Out:
#       Year      City       Sport   Discipline                   Athlete  \
# 651   1900     Paris  Tug of War   Tug of War              AABYE, Edgar
# 2849  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian
# 2852  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian
# 7773  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes
# 8563  1952  Helsinki  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes
# ...    ...       ...         ...          ...                       ...
# 596   1900     Paris    Shooting     Shooting                ÖSTMO, Ole
# 608   1900     Paris    Shooting     Shooting                ÖSTMO, Ole
# 621   1900     Paris    Shooting     Shooting                ÖSTMO, Ole
# 603   1900     Paris    Shooting     Shooting                ÖSTMO, Ole
# 8051  1952  Helsinki    Aquatics     Swimming         ÖSTRAND, Per-Olof
#
#      Country Gender                          Event   Medal
# ...

# %%
summer.Year.nlargest(n = 1.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 summer.Year.nlargest(n = 1.5)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\series.py:4252, in Series.nlargest(self, n, keep)
#    4154 def nlargest(
#    4155     self, n: int = 5, keep: Literal["first", "last", "all"] = "first"
#    4156 ) -> Series:
#    4157     """
#    4158     Return the largest `n` elements.
#    4159
#    (...)
#    4250     dtype: int64
#    4251     """
# -> 4252     return selectn.SelectNSeries(self, n=n, keep=keep).nlargest()
#
# File c:\anaconda3\Lib\site-packages\pandas\core\methods\selectn.py:57, in SelectN.nlargest(self)
#      55 @final
#      56 def nlargest(self):
# ---> 57     return self.compute("nlargest")
#
# File c:\anaconda3\Lib\site-packages\pandas\core\methods\selectn.py:144, in SelectNSeries.compute(self, method)
# ...

# %%
sales.idxmax()
# Out:
# 9

# %%
sales.idxmin()
# Out:
# 0

# %%
summer.idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 summer.idxmax()
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:11890, in DataFrame.idxmax(self, axis, skipna, numeric_only)
#   11887 else:
#   11888     data = self
# > 11890 res = data._reduce(
#   11891     nanops.nanargmax, "argmax", axis=axis, skipna=skipna, numeric_only=False
#   11892 )
#   11893 indices = res._values
#   11894 # indices will always be 1d array since axis is not None
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
# ...

# %%
titanic.idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 titanic.idxmax()
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:11890, in DataFrame.idxmax(self, axis, skipna, numeric_only)
#   11887 else:
#   11888     data = self
# > 11890 res = data._reduce(
#   11891     nanops.nanargmax, "argmax", axis=axis, skipna=skipna, numeric_only=False
#   11892 )
#   11893 indices = res._values
#   11894 # indices will always be 1d array since axis is not None
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
# ...

# %%
titanic.idxmax(numeric_only= True)
# Out:
# survived      1
# pclass        0
# age         630
# sibsp       159
# parch       678
# fare        258
# dtype: int64

# %%
titanic.survived.idxmax()
# Out:
# 1

# %%
titanic.iloc[630]
# Out:
# survived       1
# pclass         1
# sex         male
# age         80.0
# sibsp          0
# parch          0
# fare        30.0
# embarked       S
# deck           A
# Name: 630, dtype: object

# %%
import pandas as pd

# %%
summer = pd.read_csv('summer.csv',index_col  = 'Athlete')

# %%
summer.nlargest(n = 10, columns = 'Year')
# Out:
#                         Year    City     Sport Discipline Country Gender  \
# Athlete
# BOUDIA, David           2012  London  Aquatics     Diving     USA    Men
# QIU, Bo                 2012  London  Aquatics     Diving     CHN    Men
# DALEY, Thomas           2012  London  Aquatics     Diving     GBR    Men
# CHEN, Ruolin            2012  London  Aquatics     Diving     CHN  Women
# BROBEN, Brittany        2012  London  Aquatics     Diving     AUS  Women
# PAMG, Pandelela Rinong  2012  London  Aquatics     Diving     MAS  Women
# ZAKHAROV, Ilya          2012  London  Aquatics     Diving     RUS    Men
# QIN, Kai                2012  London  Aquatics     Diving     CHN    Men
# HE, Chong               2012  London  Aquatics     Diving     CHN    Men
# WU, Minxia              2012  London  Aquatics     Diving     CHN  Women
#
#                                  Event   Medal
# Athlete
# BOUDIA, David             10M Platform    Gold
# QIU, Bo                   10M Platform  Silver
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
summer.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.tail(10)
# Out:
#                               Year    City      Sport           Discipline  \
# Athlete
# AHMADOV, Emin                 2012  London  Wrestling  Wrestling Freestyle
# KAZAKEVIC, Aleksandr          2012  London  Wrestling  Wrestling Freestyle
# KHUGAEV, Alan                 2012  London  Wrestling  Wrestling Freestyle
# EBRAHIM, Karam Mohamed Gaber  2012  London  Wrestling  Wrestling Freestyle
# GAJIYEV, Danyal               2012  London  Wrestling  Wrestling Freestyle
# JANIKOWSKI, Damian            2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza     2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam                2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur             2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy                2012  London  Wrestling  Wrestling Freestyle
#
#                              Country Gender     Event   Medal
# Athlete
# AHMADOV, Emin                    AZE    Men  Wg 74 KG  Bronze
# ...

# %%
summer.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Country', 'Gender', 'Event',
#        'Medal'],
#       dtype='object')

# %%
summer.index
# Out:
# Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#        'HAJOS, Alfred', 'ANDREOU, Joannis', 'CHOROPHAS, Efstathios',
#        'NEUMANN, Paul',
#        ...
#        'AHMADOV, Emin', 'KAZAKEVIC, Aleksandr', 'KHUGAEV, Alan',
#        'EBRAHIM, Karam Mohamed Gaber', 'GAJIYEV, Danyal', 'JANIKOWSKI, Damian',
#        'REZAEI, Ghasem Gholamreza', 'TOTROV, Rustam', 'ALEKSANYAN, Artur',
#        'LIDBERG, Jimmy'],
#       dtype='object', name='Athlete', length=31165)

# %%
summer.columns.to_list()
# Out:
# ['Year', 'City', 'Sport', 'Discipline', 'Country', 'Gender', 'Event', 'Medal']

# %%
summer.index.is_unique
# Out:
# False

# %%
summer.axes
# Out:
# [Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#         'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#         'HAJOS, Alfred', 'ANDREOU, Joannis', 'CHOROPHAS, Efstathios',
#         'NEUMANN, Paul',
#         ...
#         'AHMADOV, Emin', 'KAZAKEVIC, Aleksandr', 'KHUGAEV, Alan',
#         'EBRAHIM, Karam Mohamed Gaber', 'GAJIYEV, Danyal', 'JANIKOWSKI, Damian',
#         'REZAEI, Ghasem Gholamreza', 'TOTROV, Rustam', 'ALEKSANYAN, Artur',
#         'LIDBERG, Jimmy'],
#        dtype='object', name='Athlete', length=31165),
#  Index(['Year', 'City', 'Sport', 'Discipline', 'Country', 'Gender', 'Event',
#         'Medal'],
#        dtype='object')]

# %%
import pandas as pd

# %%
list_1 = [1,2,3]

# %%
pd.Index(list_1)
# Out:
# Index([1, 2, 100], dtype='int64')

# %%
type(list_1)
# Out:
# list

# %%
list_1[2] = 100

# %%
index_1 = pd.Index(list_1, name = 'numbers')

# %%
index_1
# Out:
# Index([1, 2, 100], dtype='int64', name='numbers')

# %%
df = pd.DataFrame(index_1, columns = index_1, index = index_1)

# %%
df
# Out:
# numbers  1    2    100
# numbers
# 1        NaN  NaN  NaN
# 2        NaN  NaN  NaN
# 100      NaN  NaN  NaN

# %%
list1 = [1,2,3,4,5]

# %%
list_1
# Out:
# [1, 2, 100]

# %%
list_1
# Out:
# [1, 2, 100]

# %%
pd.Series([34,35,21], index = 'index_1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[250], line 1
# ----> 1 pd.Series([34,35,21], index = 'index_1')
#
# File c:\anaconda3\Lib\site-packages\pandas\core\series.py:490, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     487 name = ibase.maybe_extract_name(name, data, type(self))
#     489 if index is not None:
# --> 490     index = ensure_index(index)
#     492 if dtype is not None:
#     493     dtype = self._validate_dtype(dtype)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7649, in ensure_index(index_like, copy)
#    7647         return Index(index_like, copy=copy, tupleize_cols=False)
#    7648 else:
# -> 7649     return Index(index_like, copy=copy)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:526, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
# ...

# %%
import pandas as pd

# %%
summer = pd.read_csv('summer.csv', index_col = 'Athlete')

# %%
summer.index
# Out:
# Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#        'HAJOS, Alfred', 'ANDREOU, Joannis', 'CHOROPHAS, Efstathios',
#        'NEUMANN, Paul',
#        ...
#        'AHMADOV, Emin', 'KAZAKEVIC, Aleksandr', 'KHUGAEV, Alan',
#        'EBRAHIM, Karam Mohamed Gaber', 'GAJIYEV, Danyal', 'JANIKOWSKI, Damian',
#        'REZAEI, Ghasem Gholamreza', 'TOTROV, Rustam', 'ALEKSANYAN, Artur',
#        'LIDBERG, Jimmy'],
#       dtype='object', name='Athlete', length=31165)

# %%
summer.drop_index('HERSCHMANN, Otto', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35928\417649030.py in ?()
# ----> 1 summer.drop_index('HERSCHMANN, Otto', inplace = True)
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_index'

# %%
summer.reset_index(drop = False, inplace = True)

# %%
summer
# Out:
#                          Athlete  Year    City      Sport  \
# 0                  HAJOS, Alfred  1896  Athens   Aquatics
# 1               HERSCHMANN, Otto  1896  Athens   Aquatics
# 2              DRIVAS, Dimitrios  1896  Athens   Aquatics
# 3             MALOKINIS, Ioannis  1896  Athens   Aquatics
# 4             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                          ...   ...     ...        ...
# 31160         JANIKOWSKI, Damian  2012  London  Wrestling
# 31161  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# 31162             TOTROV, Rustam  2012  London  Wrestling
# 31163          ALEKSANYAN, Artur  2012  London  Wrestling
# 31164             LIDBERG, Jimmy  2012  London  Wrestling
#
#                 Discipline Country Gender                       Event   Medal
# 0                 Swimming     HUN    Men              100M Freestyle    Gold
# 1                 Swimming     AUT    Men              100M Freestyle  Silver
# ...

# %%
summer.set_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[260], line 1
# ----> 1 summer.set_index()
#
# TypeError: DataFrame.set_index() missing 1 required positional argument: 'keys'

# %%
summer.index.size
# Out:
# 31165

# %%
summer.index.len
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[262], line 1
# ----> 1 summer.index.len
#
# AttributeError: 'RangeIndex' object has no attribute 'len'

# %%
len(summer.index)
# Out:
# 31165

# %%
index_1 = [f"Medal No {i}" for i in range (1, len(summer.index) + 1)]

# %%
index_1
# Out:
# ['Medal No 1',
#  'Medal No 2',
#  'Medal No 3',
#  'Medal No 4',
#  'Medal No 5',
#  'Medal No 6',
#  'Medal No 7',
#  'Medal No 8',
#  'Medal No 9',
#  'Medal No 10',
#  'Medal No 11',
#  'Medal No 12',
#  'Medal No 13',
#  'Medal No 14',
#  'Medal No 15',
#  'Medal No 16',
#  'Medal No 17',
#  'Medal No 18',
#  'Medal No 19',
#  'Medal No 20',
#  'Medal No 21',
#  'Medal No 22',
#  'Medal No 23',
#  'Medal No 24',
#  'Medal No 25',
#  'Medal No 26',
#  'Medal No 27',
#  'Medal No 28',
#  'Medal No 29',
#  'Medal No 30',
#  'Medal No 31',
#  'Medal No 32',
#  'Medal No 33',
#  'Medal No 34',
#  'Medal No 35',
#  'Medal No 36',
#  'Medal No 37',
#  'Medal No 38',
#  'Medal No 39',
#  'Medal No 40',
#  'Medal No 41',
#  'Medal No 42',
#  'Medal No 43',
#  'Medal No 44',
#  'Medal No 45',
#  'Medal No 46',
#  'Medal No 47',
#  'Medal No 48',
#  'Medal No 49',
#  'Medal No 50',
#  'Medal No 51',
#  'Medal No 52',
#  'Medal No 53',
#  'Medal No 54',
#  'Medal No 55',
#  'Medal No 56',
# ...

# %%
summer.reset_index(index_1, drop = True, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[274], line 1
# ----> 1 summer.reset_index(index_1, drop = True, inplace = True)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:6425, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6423 if not isinstance(level, (tuple, list)):
#    6424     level = [level]
# -> 6425 level = [self.index._get_level_number(lev) for lev in level]
#    6426 if len(level) < self.index.nlevels:
#    6427     new_index = self.index.droplevel(level)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2017, in Index._get_level_number(self, level)
#    2016 def _get_level_number(self, level) -> int:
# -> 2017     self._validate_index_level(level)
#    2018     return 0
#
# ...

# %%
index_1 =
# Out:
#                          Athlete  Year    City      Sport  \
# 0                  HAJOS, Alfred  1896  Athens   Aquatics
# 1               HERSCHMANN, Otto  1896  Athens   Aquatics
# 2              DRIVAS, Dimitrios  1896  Athens   Aquatics
# 3             MALOKINIS, Ioannis  1896  Athens   Aquatics
# 4             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                          ...   ...     ...        ...
# 31160         JANIKOWSKI, Damian  2012  London  Wrestling
# 31161  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# 31162             TOTROV, Rustam  2012  London  Wrestling
# 31163          ALEKSANYAN, Artur  2012  London  Wrestling
# 31164             LIDBERG, Jimmy  2012  London  Wrestling
#
#                 Discipline Country Gender                       Event   Medal
# 0                 Swimming     HUN    Men              100M Freestyle    Gold
# 1                 Swimming     AUT    Men              100M Freestyle  Silver
# ...

# %%
summer.index = index_1

# %%
summer.head()
# Out:
#                        Athlete  Year    City     Sport Discipline Country  \
# Medal No 1       HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN
# Medal No 2    HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming     AUT
# Medal No 3   DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE
# Medal No 4  MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE
# Medal No 5  CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE
#
#            Gender                       Event   Medal
# Medal No 1    Men              100M Freestyle    Gold
# Medal No 2    Men              100M Freestyle  Silver
# Medal No 3    Men  100M Freestyle For Sailors  Bronze
# Medal No 4    Men  100M Freestyle For Sailors    Gold
# Medal No 5    Men  100M Freestyle For Sailors  Silver

# %%
summer.index.name = 'Medal No'

# %%
summer.set_index('Medal No', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35928\2928386424.py in ?()
# ----> 1 summer.set_index('Medal No', inplace = True)
#
# c:\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Medal No'] are in the columns"

# %%
summer
# Out:
#                                   Athlete  Year    City      Sport  \
# Medal No
# Medal No 1                  HAJOS, Alfred  1896  Athens   Aquatics
# Medal No 2               HERSCHMANN, Otto  1896  Athens   Aquatics
# Medal No 3              DRIVAS, Dimitrios  1896  Athens   Aquatics
# Medal No 4             MALOKINIS, Ioannis  1896  Athens   Aquatics
# Medal No 5             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                                   ...   ...     ...        ...
# Medal No 31161         JANIKOWSKI, Damian  2012  London  Wrestling
# Medal No 31162  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# Medal No 31163             TOTROV, Rustam  2012  London  Wrestling
# Medal No 31164          ALEKSANYAN, Artur  2012  London  Wrestling
# Medal No 31165             LIDBERG, Jimmy  2012  London  Wrestling
#
#                          Discipline Country Gender  \
# Medal No
# Medal No 1                 Swimming     HUN    Men
# ...

# %%
summer.reset_index(inplace = True)

# %%
summer.set_index('Medal No', drop = True, inplace = True)

# %%
summer
# Out:
#                                   Athlete  Year    City      Sport  \
# Medal No
# Medal No 1                  HAJOS, Alfred  1896  Athens   Aquatics
# Medal No 2               HERSCHMANN, Otto  1896  Athens   Aquatics
# Medal No 3              DRIVAS, Dimitrios  1896  Athens   Aquatics
# Medal No 4             MALOKINIS, Ioannis  1896  Athens   Aquatics
# Medal No 5             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                                   ...   ...     ...        ...
# Medal No 31161         JANIKOWSKI, Damian  2012  London  Wrestling
# Medal No 31162  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# Medal No 31163             TOTROV, Rustam  2012  London  Wrestling
# Medal No 31164          ALEKSANYAN, Artur  2012  London  Wrestling
# Medal No 31165             LIDBERG, Jimmy  2012  London  Wrestling
#
#                          Discipline Country Gender  \
# Medal No
# Medal No 1                 Swimming     HUN    Men
# ...

# %%
summer.columns = summer.columns.str.replace(' ','_')

# %%
summer.Country.name('g g',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[300], line 1
# ----> 1 summer.Country.name('g g',inplace = True)
#
# TypeError: 'str' object is not callable

# %%
summer
# Out:
#                                   Athlete  Year    City      Sport  \
# Medal No
# Medal No 1                  HAJOS, Alfred  1896  Athens   Aquatics
# Medal No 2               HERSCHMANN, Otto  1896  Athens   Aquatics
# Medal No 3              DRIVAS, Dimitrios  1896  Athens   Aquatics
# Medal No 4             MALOKINIS, Ioannis  1896  Athens   Aquatics
# Medal No 5             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                                   ...   ...     ...        ...
# Medal No 31161         JANIKOWSKI, Damian  2012  London  Wrestling
# Medal No 31162  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# Medal No 31163             TOTROV, Rustam  2012  London  Wrestling
# Medal No 31164          ALEKSANYAN, Artur  2012  London  Wrestling
# Medal No 31165             LIDBERG, Jimmy  2012  London  Wrestling
#
#                          Discipline Country Gender  \
# Medal No
# Medal No 1                 Swimming     HUN    Men
# ...

# %%
summer.rename(columns={"Country": "country name"}, inplace=True)

# %%
summer.rename(columns = {'Country': 'country name'}, inplace = True)

# %%
summer
# Out:
#                                   Athlete  Year    City      Sport  \
# Medal No
# Medal No 1                  HAJOS, Alfred  1896  Athens   Aquatics
# Medal No 2               HERSCHMANN, Otto  1896  Athens   Aquatics
# Medal No 3              DRIVAS, Dimitrios  1896  Athens   Aquatics
# Medal No 4             MALOKINIS, Ioannis  1896  Athens   Aquatics
# Medal No 5             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                                   ...   ...     ...        ...
# Medal No 31161         JANIKOWSKI, Damian  2012  London  Wrestling
# Medal No 31162  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# Medal No 31163             TOTROV, Rustam  2012  London  Wrestling
# Medal No 31164          ALEKSANYAN, Artur  2012  London  Wrestling
# Medal No 31165             LIDBERG, Jimmy  2012  London  Wrestling
#
#                          Discipline country name Gender  \
# Medal No
# Medal No 1                 Swimming          HUN    Men
# ...

# %%
summer.columns.str.replace(' ','_', regex = False)
# Out:
# Index(['Athlete', 'Year', 'City', 'Sport', 'Discipline', 'country_name',
#        'Gender', 'Event', 'Medal'],
#       dtype='object')

# %%
summer
# Out:
#                                   Athlete  Year    City      Sport  \
# Medal No
# Medal No 1                  HAJOS, Alfred  1896  Athens   Aquatics
# Medal No 2               HERSCHMANN, Otto  1896  Athens   Aquatics
# Medal No 3              DRIVAS, Dimitrios  1896  Athens   Aquatics
# Medal No 4             MALOKINIS, Ioannis  1896  Athens   Aquatics
# Medal No 5             CHASAPIS, Spiridon  1896  Athens   Aquatics
# ...                                   ...   ...     ...        ...
# Medal No 31161         JANIKOWSKI, Damian  2012  London  Wrestling
# Medal No 31162  REZAEI, Ghasem Gholamreza  2012  London  Wrestling
# Medal No 31163             TOTROV, Rustam  2012  London  Wrestling
# Medal No 31164          ALEKSANYAN, Artur  2012  London  Wrestling
# Medal No 31165             LIDBERG, Jimmy  2012  London  Wrestling
#
#                          Discipline country name Gender  \
# Medal No
# Medal No 1                 Swimming          HUN    Men
# ...

# %%
#Data Frame Basics 2

# %% [markdown]
# #Data Frame Basisc2

# %%
###Data Frame Basisc2

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.sex.head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: sex, dtype: object

# %%
titanic[(titanic.sex == 'male') & (titanic.age >70)]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 96          0       1  male  71.0      0      0  34.6542        C    A
# 116         0       3  male  70.5      0      0   7.7500        Q  NaN
# 493         0       1  male  71.0      0      0  49.5042        C  NaN
# 630         1       1  male  80.0      0      0  30.0000        S    A
# 851         0       3  male  74.0      0      0   7.7750        S  NaN

# %%
titanic.loc[(titanic.sex == 'male'), 'survived']
# Out:
# 0      0
# 4      0
# 5      0
# 6      0
# 7      0
#       ..
# 883    0
# 884    0
# 886    0
# 889    1
# 890    0
# Name: survived, Length: 577, dtype: int64

# %%
titanic.iloc[5:45,4]
# Out:
# 5     0
# 6     0
# 7     3
# 8     0
# 9     1
# 10    1
# 11    0
# 12    0
# 13    1
# 14    0
# 15    0
# 16    4
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    0
# 23    0
# 24    3
# 25    1
# 26    0
# 27    3
# 28    0
# 29    0
# 30    0
# 31    1
# 32    0
# 33    0
# 34    1
# 35    1
# 36    0
# 37    0
# 38    2
# 39    1
# 40    1
# 41    1
# 42    0
# 43    1
# 44    0
# Name: sibsp, dtype: int64

# %%
mask1 = titanic.sex == 'male'

# %%
mask1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
titanic.loc[mask1,'survived']
# Out:
# 0      0
# 4      0
# 5      0
# 6      0
# 7      0
#       ..
# 883    0
# 884    0
# 886    0
# 889    1
# 890    0
# Name: survived, Length: 577, dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic[mask1].survived.count()
# Out:
# 577

# %%
titanic.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# deck         object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.loc[:, titanic.dtypes == 'int64']
# Out:
#      survived  pclass  sibsp  parch
# 0           0       3      1      0
# 1           1       1      1      0
# 2           1       3      0      0
# 3           1       1      1      0
# 4           0       3      0      0
# ..        ...     ...    ...    ...
# 886         0       2      0      0
# 887         1       1      0      0
# 888         0       3      1      2
# 889         1       1      0      0
# 890         0       3      0      0
#
# [891 rows x 4 columns]

# %%
summer[summer.Year.between(1990,2010, inclusive = 'both')].size
# Out:
# 86571

# %%
titanic['Zero'] = 0

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  Zero
# 0         0       3    male  22.0      1      0   7.2500        S  NaN     0
# 1         1       1  female  38.0      1      0  71.2833        C    C     0
# 2         1       3  female  26.0      0      0   7.9250        S  NaN     0
# 3         1       1  female  35.0      1      0  53.1000        S    C     0
# 4         0       3    male  35.0      0      0   8.0500        S  NaN     0

# %%
titanic.Zero = titanic.pclass + 1

# %%
if titanic.pclass == 3:
    titanic.Zero = 'Less chances'
else: titanic.Zero = 'High Chances'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35928\3962890677.py in ?()
# ----> 1 if titanic.pclass == 3:
#       2     titanic.Zero = 'Less chances'
#       3 else: titanic.Zero = 'High Chances'
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
titanic.zero = IF titanic.pclass == 3: 'Less chances', 'High Chances'
# Out:
#   Cell In[363], line 1
#     titanic.zero = IF titanic.pclass == 3: 'Less chances', 'High Chances'
#                       ^
# SyntaxError: invalid syntax

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  Zero
# 0         0       3    male  22.0      1      0   7.2500        S  NaN     4
# 1         1       1  female  38.0      1      0  71.2833        C    C     2
# 2         1       3  female  26.0      0      0   7.9250        S  NaN     4
# 3         1       1  female  35.0      1      0  53.1000        S    C     2
# 4         0       3    male  35.0      0      0   8.0500        S  NaN     4

# %%
titanic.insert(loc = 3, column = 'One1', value = titanic.Zero)

# %%
titanic
# Out:
#      survived  pclass     sex  One1  One   age  sibsp  parch     fare  \
# 0           0       3    male     4    0  22.0      1      0   7.2500
# 1           1       1  female     2    0  38.0      1      0  71.2833
# 2           1       3  female     4    0  26.0      0      0   7.9250
# 3           1       1  female     2    0  35.0      1      0  53.1000
# 4           0       3    male     4    0  35.0      0      0   8.0500
# ..        ...     ...     ...   ...  ...   ...    ...    ...      ...
# 886         0       2    male     3    0  27.0      0      0  13.0000
# 887         1       1  female     2    0  19.0      0      0  30.0000
# 888         0       3  female     4    0   NaN      1      2  23.4500
# 889         1       1    male     2    0  26.0      0      0  30.0000
# 890         0       3    male     4    0  32.0      0      0   7.7500
#
#     embarked deck  Zero
# 0          S  NaN     4
# 1          C    C     2
# 2          S  NaN     4
# 3          S    C     2
# ...

# %%
titanic.drop(columns = ['Zero','One','One1'], inplace = True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
Creating Data from SCratch
# Out:
#   Cell In[373], line 1
#     Creating Data from SCratch
#              ^
# SyntaxError: invalid syntax

# %%
player = ["Lionel Messi", "Cristiano Ronaldo", "Neymar Junior", "Kylian Mbappe", "Manuel Neuer"]

# %%
nationality = ["Argentina", "Portugal", "Brasil", "France", "Germany"]

# %%
club = ["FC Barcelona", "Juventus FC", "Paris SG", "Paris SG", "FC Bayern" ]

# %%
world_champion = [False, False, False, True, True]

# %%
height = [1.70, 1.87, 1.75, 1.78, 1.93]

# %%
goals = [45, 44, 28, 21, 0]
dic = {"Player":player, "Nationality":nationality, "Club":club, 
        "World_Champion":world_champion, "Height":height, "Goals_2018":goals
       }

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#               Player Nationality          Club  World_Champion  Height  \
# 0       Lionel Messi   Argentina  FC Barcelona           False    1.70
# 1  Cristiano Ronaldo    Portugal   Juventus FC           False    1.87
# 2      Neymar Junior      Brasil      Paris SG           False    1.75
# 3      Kylian Mbappe      France      Paris SG            True    1.78
# 4       Manuel Neuer     Germany     FC Bayern            True    1.93
#
#    Goals_2018
# 0          45
# 1          44
# 2          28
# 3          21
# 4           0

# %%
df.set_index('Player', inplace = True)

# %%
values = [['Prateek','Chawla',33],['Navya','Chawla',2]]

# %%
columns = ['First Name', 'Last Name', 'Age']

# %%
index = ['Person 1', 'Person 2']

# %%
df = pd.DataFrame(data = values, columns = columns, index = index)

# %%
df
# Out:
#          First Name Last Name  Age
# Person 1    Prateek    Chawla   33
# Person 2      Navya    Chawla    2

# %%
players = pd.read_csv('players.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[394], line 1
# ----> 1 players = pd.read_csv('players.csv')
#
# File c:\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
# Manipulating Values in DataFrame

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.loc[1,'sex'] = 'Napunsak'

# %%
titanic
# Out:
#      survived  pclass       sex   age  sibsp  parch     fare embarked deck
# 0          10      10        10  10.0     10     10  10.0000       10   10
# 1           1       1  Napunsak  38.0      1      0  71.2833        C    C
# 2           1       3    female  26.0      0      0   7.9250        S  NaN
# 3           1       1    female  35.0      1      0  53.1000        S    C
# 4           0       3      male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...       ...   ...    ...    ...      ...      ...  ...
# 886         0       2      male  27.0      0      0  13.0000        S  NaN
# 887         1       1    female  19.0      0      0  30.0000        S    B
# 888         0       3    female   NaN      1      2  23.4500        S  NaN
# 889         1       1      male  26.0      0      0  30.0000        C    C
# 890         0       3      male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['Zero'] = 0

# %%
titanic.Zero[titanic.pclass == 3] = 'Less Chances'
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_35928\2060829113.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   titanic.Zero[titanic.pclass == 3] = 'Less Chances'
# ...

# %%
titanic.Zero.unique()
# Out:
# array([0, 'Less Chances'], dtype=object)

# %%
titanic.loc[3:,'Zero'] == 'Less Chances']
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_35928\1534222921.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic[titanic.loc[3:,'Zero'] == 'Less Chances']
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[415], line 1
# ----> 1 titanic[titanic.loc[3:,'Zero'] == 'Less Chances']
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# ...

# %%
titanic.loc[0,'age'] = 99

# %%
titanic
# Out:
#      survived  pclass       sex   age  sibsp  parch     fare embarked deck  \
# 0          10      10        10  99.0     10     10  10.0000       10   10
# 1           1       1  Napunsak  38.0      1      0  71.2833        C    C
# 2           1       3    female  26.0      0      0   7.9250        S  NaN
# 3           1       1    female  35.0      1      0  53.1000        S    C
# 4           0       3      male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...       ...   ...    ...    ...      ...      ...  ...
# 886         0       2      male  27.0      0      0  13.0000        S  NaN
# 887         1       1    female  19.0      0      0  30.0000        S    B
# 888         0       3    female   NaN      1      2  23.4500        S  NaN
# 889         1       1      male  26.0      0      0  30.0000        C    C
# 890         0       3      male  32.0      0      0   7.7500        Q  NaN
#
#              Zero
# 0               0
# 1               0
# ...

# %%
slice1 = titanic[['sex','age']]

# %%
slice1[1,'sex'] = 999999
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_35928\3773651665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   slice1[1,'sex'] = 999999

# %%
slice1
# Out:
#           sex     age
# 0          10    99.0
# 1    Napunsak    38.0
# 2      female  9999.0
# 3      female    35.0
# 4        male    35.0
# ..        ...     ...
# 886      male    27.0
# 887    female    19.0
# 888    female     NaN
# 889      male    26.0
# 890      male    32.0
#
# [891 rows x 2 columns]

# %%
titanic
# Out:
#      survived  pclass       sex     age  sibsp  parch     fare embarked deck  \
# 0          10      10        10    99.0     10     10  10.0000       10   10
# 1           1       1  Napunsak  7000.0      1      0  71.2833        C    C
# 2           1       3    female    26.0      0      0   7.9250        S  NaN
# 3           1       1    female    35.0      1      0  53.1000        S    C
# 4           0       3      male    35.0      0      0   8.0500        S  NaN
# ..        ...     ...       ...     ...    ...    ...      ...      ...  ...
# 886         0       2      male    27.0      0      0  13.0000        S  NaN
# 887         1       1    female    19.0      0      0  30.0000        S    B
# 888         0       3    female     NaN      1      2  23.4500        S  NaN
# 889         1       1      male    26.0      0      0  30.0000        C    C
# 890         0       3      male    32.0      0      0   7.7500        Q  NaN
#
#              Zero
# 0               0
# ...

# %%
age = titanic['age']

# %%
age._is_view
# Out:
# True

# %%
age._is_copy

# %%
age[1] = 7000
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_35928\3909448776.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age[1] = 7000

# %%
titanic
# Out:
#      survived  pclass       sex     age  sibsp  parch     fare embarked deck  \
# 0          10      10        10    99.0     10     10  10.0000       10   10
# 1           1       1  Napunsak  7000.0      1      0  71.2833        C    C
# 2           1       3    female    26.0      0      0   7.9250        S  NaN
# 3           1       1    female    35.0      1      0  53.1000        S    C
# 4           0       3      male    35.0      0      0   8.0500        S  NaN
# ..        ...     ...       ...     ...    ...    ...      ...      ...  ...
# 886         0       2      male    27.0      0      0  13.0000        S  NaN
# 887         1       1    female    19.0      0      0  30.0000        S    B
# 888         0       3    female     NaN      1      2  23.4500        S  NaN
# 889         1       1      male    26.0      0      0  30.0000        C    C
# 890         0       3      male    32.0      0      0   7.7500        Q  NaN
#
#              Zero
# 0               0
# ...

# %%
import pandas as pd

# %%
titanic.age.sort_values(ascending = False)
# Out:
# 1      7000.0
# 0        99.0
# 630      80.0
# 851      74.0
# 96       71.0
#         ...
# 859       NaN
# 863       NaN
# 868       NaN
# 878       NaN
# 888       NaN
# Name: age, Length: 891, dtype: float64

# %%
titanic.sort_values(by = 'parch', na_position = 'last', inplace = True)

# %%
titanic.sex.unique()
# Out:
# array(['male', 'female', 'Napunsak', 10], dtype=object)

# %%
sales = pd.Series([15, 32, 45, 21, -1, 0, 0],  index = ["Mo", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"])

# %%
sales.rank(ascending = False, method = 'dense' )
# Out:
# Mo     4.0
# Tue    2.0
# Wed    1.0
# Thu    3.0
# Fri    6.0
# Sat    5.0
# Sun    5.0
# dtype: float64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 890         0       3    male  32.0      0      0    7.7500        Q  NaN
# 503         0       3  female  37.0      0      0    9.5875        S  NaN
# 504         1       1  female  16.0      0      0   86.5000        S    B
# 505         0       1    male  18.0      1      0  108.9000        C    C
# 507         1       1    male   NaN      0      0   26.5500        S  NaN
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 885         0       3  female  39.0      0      5   29.1250        Q  NaN
# 25          1       3  female  38.0      1      5   31.3875        S  NaN
# 13          0       3    male  39.0      1      5   31.2750        S  NaN
# 678         0       3  female  43.0      1      6   46.9000        S  NaN
# 0          10      10      10  99.0     10     10   10.0000       10   10
#
#              Zero
# 890  Less Chances
# 503  Less Chances
# 504             0
# ...

# %%
titanic.fare.rank(ascending = False, method = 'min')
# Out:
# 890    753.0
# 503    562.0
# 504     64.0
# 505     50.0
# 507    270.0
#        ...
# 885    244.0
# 25     212.0
# 13     216.0
# 678    166.0
# 0      556.0
# Name: fare, Length: 891, dtype: float64

# %%
titanic.sort_values('fare', ascending = False)[titanic.sex == 'male']
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_35928\4121723669.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic.sort_values('fare', ascending = False)[titanic.sex == 'male']
#      survived  pclass   sex   age  sibsp  parch      fare embarked deck  \
# 679         1       1  male  36.0      0      1  512.3292        C    B
# 737         1       1  male  35.0      0      0  512.3292        C    B
# 27          0       1  male  19.0      3      2  263.0000        S    C
# 438         0       1  male  64.0      1      4  263.0000        S    C
# 118         0       1  male  24.0      0      1  247.5208        C    B
# ..        ...     ...   ...   ...    ...    ...       ...      ...  ...
# 597         0       3  male  49.0      0      0    0.0000        S  NaN
# 732         0       2  male   NaN      0      0    0.0000        S  NaN
# 822         0       1  male  38.0      0      0    0.0000        S  NaN
# ...

# %%
titanic.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35928\1385196575.py in ?()
# ----> 1 titanic.unique()
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
titanic.age.unique()
# Out:
# array([3.20e+01, 3.70e+01, 1.60e+01, 1.80e+01,      nan, 2.80e+01,
#        2.60e+01, 2.90e+01, 3.60e+01, 5.40e+01, 2.40e+01, 4.70e+01,
#        3.40e+01, 3.00e+01, 2.20e+01, 2.10e+01, 2.30e+01, 5.00e+01,
#        6.30e+01, 2.50e+01, 3.50e+01, 5.80e+01, 5.50e+01, 7.10e+01,
#        1.70e+01, 4.05e+01, 4.00e+01, 1.90e+01, 6.20e+01, 5.30e+01,
#        3.90e+01, 4.80e+01, 1.50e+01, 4.50e+01, 6.40e+01, 2.70e+01,
#        4.60e+01, 2.00e+01, 5.10e+01, 3.30e+01, 4.40e+01, 3.10e+01,
#        4.20e+01, 3.45e+01, 4.90e+01, 6.50e+01, 3.80e+01, 5.60e+01,
#        5.20e+01, 1.10e+01, 2.85e+01, 5.00e+00, 1.30e+01, 4.10e+01,
#        3.05e+01, 5.70e+01, 6.00e+01, 4.30e+01, 6.10e+01, 8.00e+01,
#        7.00e+01, 2.45e+01, 1.45e+01, 7.05e+01, 3.25e+01, 1.20e+01,
#        5.55e+01, 4.55e+01, 6.60e+01, 1.40e+01, 7.00e+03, 5.90e+01,
#        7.40e+01, 2.35e+01, 2.05e+01, 3.00e+00, 6.00e+00, 2.00e+00,
#        7.00e+00, 6.70e-01, 8.00e+00, 4.00e+00, 4.20e-01, 1.00e+00,
# ...

# %%
titanic.age.nunique()
# Out:
# 90

# %%
titanic.fare.idxmin()
# Out:
# 481

# %%
titanic.describe(include = 'all')
# Out:
#           survived      pclass   sex          age       sibsp       parch  \
# count   891.000000  891.000000   891   714.000000  891.000000  891.000000
# unique         NaN         NaN     4          NaN         NaN         NaN
# top            NaN         NaN  male          NaN         NaN         NaN
# freq           NaN         NaN   576          NaN         NaN         NaN
# mean      0.395062    2.316498   NaN    39.557661    0.533109    0.392817
# std       0.583421    0.874577   NaN   261.270043    1.147432    0.867978
# min       0.000000    1.000000   NaN     0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN    20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN    28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN    38.750000    1.000000    0.000000
# max      10.000000   10.000000   NaN  7000.000000   10.000000   10.000000
#
#               fare embarked deck          Zero
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 890 to 0
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      204 non-null    object
#  9   Zero      891 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 108.9+ KB

# %%
titanic.count(axis = 1)
# Out:
# 890     9
# 503     9
# 504    10
# 505    10
# 507     8
#        ..
# 885     9
# 25      9
# 13      9
# 678     9
# 0      10
# Length: 891, dtype: int64

# %%
titanic.age.mean(axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35928\3825412280.py in ?()
# ----> 1 titanic.age.mean(axis = 1)
#
# c:\anaconda3\Lib\site-packages\pandas\core\series.py in ?(self, axis, skipna, numeric_only, **kwargs)
#    6545         skipna: bool = True,
#    6546         numeric_only: bool = False,
#    6547         **kwargs,
#    6548     ):
# ...

# %%
titanic.mean(numeric_only = True)
# Out:
# survived     0.395062
# pclass       2.316498
# age         39.557661
# sibsp        0.533109
# parch        0.392817
# fare        32.207294
# dtype: float64

# %%
titanic.fare.cumprod()
# Out:
# 890    7.750000e+00
# 503    7.430313e+01
# 504    6.427220e+03
# 505    6.999243e+05
# 507    1.858299e+07
#            ...
# 885    0.000000e+00
# 25     0.000000e+00
# 13     0.000000e+00
# 678    0.000000e+00
# 0      0.000000e+00
# Name: fare, Length: 891, dtype: float64

# %%
titanic.corr(numeric_only = True)
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.106596  0.037976  0.124783  0.267873  0.205961
# pclass   -0.106596  1.000000 -0.068655  0.157495  0.126146 -0.529292
# age       0.037976 -0.068655  1.000000  0.005380 -0.023866  0.030985
# sibsp     0.124783  0.157495  0.005380  1.000000  0.473168  0.149525
# parch     0.267873  0.126146 -0.023866  0.473168  1.000000  0.194993
# fare      0.205961 -0.529292  0.030985  0.149525  0.194993  1.000000

# %%
titanic.median(numeric_only = True)
# Out:
# survived     0.0000
# pclass       3.0000
# age         28.0000
# sibsp        0.0000
# parch        0.0000
# fare        14.4542
# dtype: float64

# %%
titanic.agg(['median'], numeric_only = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[482], line 1
# ----> 1 titanic.agg(['median'], numeric_only = True)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:10149, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   10146 axis = self._get_axis_number(axis)
#   10148 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# > 10149 result = op.agg()
#   10150 result = reconstruct_and_relabel_result(result, func, **kwargs)
#   10151 return result
#
# File c:\anaconda3\Lib\site-packages\pandas\core\apply.py:928, in FrameApply.agg(self)
#     926 result = None
#     927 try:
# --> 928     result = super().agg()
#     929 finally:
#     930     self.obj = obj
#
# File c:\anaconda3\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 890 to 0
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      204 non-null    object
#  9   Zero      891 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 108.9+ KB

# %%
titanic.select_dtypes('number').agg(['mean','median','max','min','std','var','count'])
# Out:
#           survived      pclass           age       sibsp       parch  \
# mean      0.395062    2.316498     39.557661    0.533109    0.392817
# median    0.000000    3.000000     28.000000    0.000000    0.000000
# max      10.000000   10.000000   7000.000000   10.000000   10.000000
# min       0.000000    1.000000      0.420000    0.000000    0.000000
# std       0.583421    0.874577    261.270043    1.147432    0.867978
# var       0.340380    0.764885  68262.035302    1.316599    0.753387
# count   891.000000  891.000000    714.000000  891.000000  891.000000
#
#                fare
# mean      32.207294
# median    14.454200
# max      512.329200
# min        0.000000
# std       49.691962
# var     2469.291122
# count    891.000000

# %%
sales = pd.read_csv('sales.csv', index_col = 0)

# %%
import pandas as pd

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.set_index('0', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35520\3029403609.py in ?()
# ----> 1 sales.set_index('0', inplace = True)
#
# c:\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['0'] are in the columns"

# %%
sales
# Out:
#             Mon  Tue  Wed   Thu  Fri
# Unnamed: 0
# Steven       34   27   15   NaN   33
# Mike         45    9   74  87.0   12
# Andi         17   33   54   8.0   29
# Paul         87   67   27  45.0    7

# %%
sales.rename(columns = {0: 'Month'}, inplace = True)

# %%
sales.index.rename('Name', inplace = True)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Name
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
def sample_function(x):
    return x**3

# %%
sales.apply(sample_function,axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sales.apply(sample_function,axis = 1,inplace = True)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\anaconda3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\anaconda3\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
# ...

# %%
sales.fillna(sales.mean(), inplace = True)

# %%
sales
# Out:
#         Mon  Tue  Wed        Thu  Fri
# Name
# Steven   34   27   15  46.666667   33
# Mike     45    9   74  87.000000   12
# Andi     17   33   54   8.000000   29
# Paul     87   67   27  45.000000    7
