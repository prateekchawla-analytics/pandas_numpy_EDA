# %%
import pandas as pd

# %%
cars = pd.read_csv('cars.csv')

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars.name.iloc[393]
# Out:
# 'ford mustang gl'

# %%
cars['name'].iloc[393]
# Out:
# 'ford mustang gl'

# %%
cars.iloc[100,:].cylinders
# Out:
# 6

# %%
cars.name.iloc[200]
# Out:
# 'ford granada ghia'

# %%
cars.iloc[-10:].loc[:,['mpg','horsepower','origin','name']]
# Out:
#       mpg  horsepower  origin                        name
# 388  26.0        92.0     usa  chrysler lebaron medallion
# 389  22.0       112.0     usa              ford granada l
# 390  32.0        96.0   japan            toyota celica gt
# 391  36.0        84.0     usa           dodge charger 2.2
# 392  27.0        90.0     usa            chevrolet camaro
# 393  27.0        86.0     usa             ford mustang gl
# 394  44.0        52.0  europe                   vw pickup
# 395  32.0        84.0     usa               dodge rampage
# 396  28.0        79.0     usa                 ford ranger
# 397  31.0        82.0     usa              chevrolet s-10

# %%
cars.tail(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 388  26.0          4         156.0        92.0    2585          14.5
# 389  22.0          6         232.0       112.0    2835          14.7
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                        name
# 388          82     usa  chrysler lebaron medallion
# 389          82     usa              ford granada l
# 390          82   japan            toyota celica gt
# 391          82     usa           dodge charger 2.2
# 392          82     usa            chevrolet camaro
# 393          82     usa             ford mustang gl
# 394          82  europe                   vw pickup
# 395          82     usa               dodge rampage
# 396          82     usa                 ford ranger
# 397          82     usa              chevrolet s-10

# %%
cars = pd.read_csv('cars.csv', index_col='name')

# %%
cars
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevrolet s-10             31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevrolet s-10                     19.4          82     usa
#
# [398 rows x 8 columns]

# %%
cars.index.sortlevel(ascending = False)
# Out:
# (Index(['vw type 3', 'vw super beetle', 'vw scirocco', 'vw rabbit l',
#         'vw rabbit custom diesel', 'vw rabbit custom', 'vw rabbit custom',
#         'vw rabbit c (diesel)', 'vw rabbit', 'vw rabbit',
#         ...
#         'amc gremlin', 'amc gremlin', 'amc concord dl 6', 'amc concord dl',
#         'amc concord d/l', 'amc concord', 'amc concord', 'amc ambassador sst',
#         'amc ambassador dpl', 'amc ambassador brougham'],
#        dtype='object', name='name', length=398),
#  array([ 59, 102, 278, 375, 244, 233, 293, 325, 175, 332, 309, 203, 197,
#         394,  55, 353, 326, 142, 172, 240,  77,  19, 360, 275, 207, 179,
#          76, 120, 335, 348, 343, 210, 123, 361,  82,  14, 318,  57, 267,
#         171,  31, 144, 310, 235,  84,  53, 131, 205, 167, 382, 356, 321,
#         270, 390, 108, 331, 239, 150, 346, 180, 122, 276,  22, 330, 218,
#         354, 186,  79, 201, 234,  44, 252, 372, 308, 280, 370, 229, 116,
#          47,  39, 156,   8,  63, 170, 208, 227, 256, 152,  97, 191, 135,
#          75,  34,   2, 271, 338, 342, 302, 378, 350, 301, 158,  64,   7,
#          41,  93, 163, 101,  15, 125, 105,  56, 344, 219,  11, 277, 359,
#          78,  20, 209, 299, 178,  51, 118, 143, 183,  50, 106, 272, 307,
#         124,  69, 222, 249, 300, 364, 387, 380, 281, 259, 251, 154,  90,
#          67, 379, 287, 224, 113, 184,  49, 297, 211, 328, 111,  71, 334,
#         243, 246, 294, 376, 377, 349, 322, 358, 319,  28, 355, 248, 181,
#         329, 345, 384, 383, 149, 198, 279, 216, 337, 381,  36,   4, 232,
#         396,  61,  80, 112,  32, 206, 168, 174, 130, 236, 166, 393, 336,
#          48, 155, 126, 193,  17, 100, 286,  92, 159, 389, 365, 200, 228,
#          74, 139, 136,  88, 190,  65,   5,  40, 264, 245, 373, 282, 255,
#         254, 314,  25, 214, 351, 352,  43, 290, 104, 151, 304, 182, 117,
#         147,  52, 148, 114, 288, 395, 269, 223,  42, 265, 250, 121,  27,
#         215, 138,  89, 188, 238, 295,  58,  83, 185, 323, 146, 391,  10,
#         199, 284, 316, 260, 340, 371,  18,  29, 220, 247, 129, 204, 362,
#         241, 145, 173, 110, 320,  81, 268, 385, 312, 333, 347, 303, 324,
#         357, 273,  54,  70,  94, 292, 366, 388, 231, 196,  30,  46, 109,
#         132,  60, 397,  98, 153, 128, 192, 165, 115, 230, 262,  12, 291,
#         253,  87,  62,   6,  38, 103, 225, 341, 306, 313, 311, 237, 195,
#         266, 187, 133, 161,  35,   0,  73, 368, 369, 367, 285, 221,  91,
#         392,  26, 213, 157, 212, 298, 305,   1, 226, 339, 164, 263, 217,
#          68, 289,  13,  95, 258, 137, 386,  85, 160, 363, 242,  23, 141,
#         327, 274, 317, 119, 177,  21, 296,   3, 202, 176,  72, 140,  86,
#         162, 189, 134,  37,  45, 194,  16,  99, 127,  33,  24, 107, 169,
#         283, 374, 261, 257, 315,  66,   9,  96], dtype=int64))

# %%
cars.loc["ford ranger"]
# Out:
# mpg              28.0
# cylinders           4
# displacement    120.0
# horsepower       79.0
# weight           2625
# acceleration     18.6
# model_year         82
# origin            usa
# Name: ford ranger, dtype: object

# %%
cars.loc[['mpg','weight']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cars.loc[['mpg','weight']]
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['mpg', 'weight'], dtype='object', name='name')] are in the [index]"

# %%
cars.reset_index(inplace = True)

# %%
cars
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397             chevrolet s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# 0      3504          12.0          70     usa
# 1      3693          11.5          70     usa
# 2      3436          11.0          70     usa
# 3      3433          12.0          70     usa
# 4      3449          10.5          70     usa
# ..      ...           ...         ...     ...
# 393    2790          15.6          82     usa
# 394    2130          24.6          82  europe
# 395    2295          11.6          82     usa
# 396    2625          18.6          82     usa
# 397    2720          19.4          82     usa
#
# [398 rows x 9 columns]

# %%
mpg = cars['mpg'].copy()

# %%
mpg.dtype
# Out:
# dtype('float64')

# %%
type(mpg)
# Out:
# pandas.core.series.Series

# %%
mpg.describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
mpg.min()
# Out:
# 9.0

# %%
mpg.max()
# Out:
# 46.6

# %%
cars[cars.mpg == mpg.max()]
# Out:
#           name   mpg  cylinders  displacement  horsepower  weight  \
# 322  mazda glc  46.6          4          86.0        65.0    2110
#
#      acceleration  model_year origin
# 322          17.9          80  japan

# %%
mpg.value_counts(normalize = True, sort = True)
# Out:
# mpg
# 13.0    0.050251
# 14.0    0.047739
# 18.0    0.042714
# 15.0    0.040201
# 26.0    0.035176
#           ...
# 31.9    0.002513
# 16.9    0.002513
# 18.2    0.002513
# 22.3    0.002513
# 44.0    0.002513
# Name: proportion, Length: 129, dtype: float64

# %%
cars
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397             chevrolet s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# 0      3504          12.0          70     usa
# 1      3693          11.5          70     usa
# 2      3436          11.0          70     usa
# 3      3433          12.0          70     usa
# 4      3449          10.5          70     usa
# ..      ...           ...         ...     ...
# 393    2790          15.6          82     usa
# 394    2130          24.6          82  europe
# 395    2295          11.6          82     usa
# 396    2625          18.6          82     usa
# 397    2720          19.4          82     usa
#
# [398 rows x 9 columns]

# %%
mpg.sort_values(ascending = False, inplace = True)

# %%
mpg
# Out:
# 322    46.6
# 329    44.6
# 325    44.3
# 394    44.0
# 326    43.4
#        ...
# 103    11.0
# 67     11.0
# 25     10.0
# 26     10.0
# 28      9.0
# Name: mpg, Length: 398, dtype: float64

# %%
mpg.index
# Out:
# Index([322, 329, 325, 394, 326, 244, 309, 330, 324, 247,
#        ...
#         90,  42,  95, 124,  27, 103,  67,  25,  26,  28],
#       dtype='int64', length=398)

# %%
mpg.sort_index(inplace = True)

# %%
mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
lpk = (235.21/mpg).round(2)

# %%
lpk
# Out:
# 0      13.07
# 1      15.68
# 2      13.07
# 3      14.70
# 4      13.84
#        ...
# 393     8.71
# 394     5.35
# 395     7.35
# 396     8.40
# 397     7.59
# Name: mpg, Length: 398, dtype: float64

# %%
lpk.describe()
# Out:
# count    398.000000
# mean      11.212789
# std        3.901407
# min        5.050000
# 25%        8.110000
# 50%       10.230000
# 75%       13.440000
# max       26.130000
# Name: mpg, dtype: float64

# %%
origin = cars.origin.copy()

# %%
origin
# Out:
# 0         usa
# 1         usa
# 2         usa
# 3         usa
# 4         usa
#         ...
# 393       usa
# 394    europe
# 395       usa
# 396       usa
# 397       usa
# Name: origin, Length: 398, dtype: object

# %%
origin.describe()
# Out:
# count     398
# unique      3
# top       usa
# freq      249
# Name: origin, dtype: object

# %%
import pandas as pd

# %%
cars = pd.read_csv('cars.csv')

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
cars.set_index('name', inplace = True, drop = True)

# %%
cars.reset_index(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31636\3824374089.py in ?()
# ----> 1 cars.reset_index(inplace = True)
#
# c:\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# c:\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert name, already exists

# %%
cars
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevrolet s-10             31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevrolet s-10                     19.4          82     usa
#
# [398 rows x 8 columns]

# %%
cars[cars.index.value_counts() > 1]
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_31636\77052822.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cars[cars.index.value_counts() > 1]
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# ford galaxie 500           15.0          8         429.0       198.0    4341
# chevrolet impala           14.0          8         454.0       220.0    4354
# plymouth fury iii          14.0          8         440.0       215.0    4312
# pontiac catalina           14.0          8         455.0       225.0    4425
# ...                         ...        ...           ...         ...     ...
# buick century              22.4          6         231.0       110.0    3415
# pontiac phoenix            27.0          4         151.0        90.0    2735
# honda accord               36.0          4         107.0        75.0    2205
# toyota corolla             34.0          4         108.0        70.0    2245
# honda civic                38.0          4          91.0        67.0    1965
#
#                            acceleration  model_year origin
# name
# chevrolet chevelle malibu          12.0          70    usa
# ford galaxie 500                   10.0          70    usa
# chevrolet impala                    9.0          70    usa
# plymouth fury iii                   8.5          70    usa
# pontiac catalina                   10.0          70    usa
# ...                                 ...         ...    ...
# buick century                      15.8          81    usa
# pontiac phoenix                    18.0          82    usa
# honda accord                       14.5          82  japan
# toyota corolla                     16.9          82  japan
# honda civic                        15.0          82  japan
#
# [155 rows x 8 columns]

# %%
cars.index.value_counts(sort = True, ascending = False)
# Out:
# name
# ford pinto             6
# vw rabbit              5
# ford maverick          5
# toyota corolla         5
# amc matador            5
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevrolet s-10         1
# Name: count, Length: 300, dtype: int64

# %%
cars.index.name = 'car_model'

# %%
cars
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# car_model
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevrolet s-10             31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin
# car_model
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevrolet s-10                     19.4          82     usa
#
# [398 rows x 8 columns]

# %%
cars.reset_index(inplace = True)

# %%
cars
# Out:
#                      car_model   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397             chevrolet s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# 0      3504          12.0          70     usa
# 1      3693          11.5          70     usa
# 2      3436          11.0          70     usa
# 3      3433          12.0          70     usa
# 4      3449          10.5          70     usa
# ..      ...           ...         ...     ...
# 393    2790          15.6          82     usa
# 394    2130          24.6          82  europe
# 395    2295          11.6          82     usa
# 396    2625          18.6          82     usa
# 397    2720          19.4          82     usa
#
# [398 rows x 9 columns]

# %%
cars.rename(columns = {'horsepower':'hp', 'origin':'country'}, inplace = True  )

# %%
cars
# Out:
#                      car_model   mpg  cylinders  displacement     hp  weight  \
# 0    chevrolet chevelle malibu  18.0          8         307.0  130.0    3504
# 1            buick skylark 320  15.0          8         350.0  165.0    3693
# 2           plymouth satellite  18.0          8         318.0  150.0    3436
# 3                amc rebel sst  16.0          8         304.0  150.0    3433
# 4                  ford torino  17.0          8         302.0  140.0    3449
# ..                         ...   ...        ...           ...    ...     ...
# 393            ford mustang gl  27.0          4         140.0   86.0    2790
# 394                  vw pickup  44.0          4          97.0   52.0    2130
# 395              dodge rampage  32.0          4         135.0   84.0    2295
# 396                ford ranger  28.0          4         120.0   79.0    2625
# 397             chevrolet s-10  31.0          4         119.0   82.0    2720
#
#      acceleration  model_year country
# 0            12.0          70     usa
# 1            11.5          70     usa
# 2            11.0          70     usa
# 3            12.0          70     usa
# 4            10.5          70     usa
# ..            ...         ...     ...
# 393          15.6          82     usa
# 394          24.6          82  europe
# 395          11.6          82     usa
# 396          18.6          82     usa
# 397          19.4          82     usa
#
# [398 rows x 9 columns]

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by = 'age', ascending = False, inplace = True)

# %%
tiatnic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tiatnic
#
# NameError: name 'tiatnic' is not defined

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 851         0       3    male  74.0      0      0   7.7750        S  NaN
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 116         0       3    male  70.5      0      0   7.7500        Q  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by = ["pclass", 'sex'], ascending = [True, False], inplace = True)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 745         0       1    male  70.0      1      1  71.0000        S    B
# 54          0       1    male  65.0      0      1  61.9792        C    B
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 697         1       3  female   NaN      0      0   7.7333        Q  NaN
# 727         1       3  female   NaN      0      0   7.7375        Q  NaN
# 792         0       3  female   NaN      8      2  69.5500        S  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by = 'age').reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0      803         1       3    male  0.42      0      1   8.5167        C
# 1      755         1       2    male  0.67      1      1  14.5000        S
# 2      469         1       3  female  0.75      2      1  19.2583        C
# 3      644         1       3  female  0.75      2      1  19.2583        C
# 4       78         1       2    male  0.83      0      2  29.0000        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886    697         1       3  female   NaN      0      0   7.7333        Q
# 887    727         1       3  female   NaN      0      0   7.7375        Q
# 888    792         0       3  female   NaN      8      2  69.5500        S
# 889    863         0       3  female   NaN      8      2  69.5500        S
# 890    888         0       3  female   NaN      1      2  23.4500        S
#
#     deck
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 886  NaN
# 887  NaN
# 888  NaN
# 889  NaN
# 890  NaN
#
# [891 rows x 10 columns]

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 745         0       1    male  70.0      1      1  71.0000        S    B
# 54          0       1    male  65.0      0      1  61.9792        C    B
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 697         1       3  female   NaN      0      0   7.7333        Q  NaN
# 727         1       3  female   NaN      0      0   7.7375        Q  NaN
# 792         0       3  female   NaN      8      2  69.5500        S  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
sales = pd.Series([100,200,300,400,500], index = ['jan', 'feb', 'mar', 'apr', 'may'])

# %%
sales
# Out:
# jan    100
# feb    200
# mar    300
# apr    400
# may    500
# dtype: int64

# %%
sales.rank(method = 'min', ascending = False).sort_values()
# Out:
# may    1.0
# apr    2.0
# mar    3.0
# feb    4.0
# jan    5.0
# dtype: float64

# %%
sales
# Out:
# jan    100
# feb    200
# mar    300
# apr    400
# may    500
# dtype: int64

# %%
import pandas as pd

# %%
cars = pd.read_csv('cars.csv')

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
cars.describe(include = 'all')
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin        name
# count     398.000000  398.000000    398         398
# unique           NaN         NaN      3         300
# top              NaN         NaN    usa  ford pinto
# freq             NaN         NaN    249           6
# mean       15.568090   76.010050    NaN         NaN
# std         2.757689    3.697627    NaN         NaN
# min         8.000000   70.000000    NaN         NaN
# 25%        13.825000   73.000000    NaN         NaN
# 50%        15.500000   76.000000    NaN         NaN
# 75%        17.175000   79.000000    NaN         NaN
# max        24.800000   82.000000    NaN         NaN

# %%
cars.index
# Out:
# Index(['chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite',
#        'amc rebel sst', 'ford torino', 'ford galaxie 500', 'chevrolet impala',
#        'plymouth fury iii', 'pontiac catalina', 'amc ambassador dpl',
#        ...
#        'chrysler lebaron medallion', 'ford granada l', 'toyota celica gt',
#        'dodge charger 2.2', 'chevrolet camaro', 'ford mustang gl', 'vw pickup',
#        'dodge rampage', 'ford ranger', 'chevrolet s-10'],
#       dtype='object', name='name', length=398)

# %%
cars.set_index('name', inplace = True, drop = False)

# %%
cars
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevrolet s-10             31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin  \
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevrolet s-10                     19.4          82     usa
#
#                                                 name
# name
# chevrolet chevelle malibu  chevrolet chevelle malibu
# buick skylark 320                  buick skylark 320
# plymouth satellite                plymouth satellite
# amc rebel sst                          amc rebel sst
# ford torino                              ford torino
# ...                                              ...
# ford mustang gl                      ford mustang gl
# vw pickup                                  vw pickup
# dodge rampage                          dodge rampage
# ford ranger                              ford ranger
# chevrolet s-10                        chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars.index.is_unique
# Out:
# False

# %%
cars.index.value_counts()
# Out:
# name
# ford pinto             6
# vw rabbit              5
# ford maverick          5
# toyota corolla         5
# amc matador            5
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevrolet s-10         1
# Name: count, Length: 300, dtype: int64

# %%
cars.index.rename('car_model', inplace = True)

# %%
cars
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# car_model
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevrolet s-10             31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin  \
# car_model
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevrolet s-10                     19.4          82     usa
#
#                                                 name
# car_model
# chevrolet chevelle malibu  chevrolet chevelle malibu
# buick skylark 320                  buick skylark 320
# plymouth satellite                plymouth satellite
# amc rebel sst                          amc rebel sst
# ford torino                              ford torino
# ...                                              ...
# ford mustang gl                      ford mustang gl
# vw pickup                                  vw pickup
# dodge rampage                          dodge rampage
# ford ranger                              ford ranger
# chevrolet s-10                        chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# car_model
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevrolet s-10             31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin  \
# car_model
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevrolet s-10                     19.4          82     usa
#
#                                                 name
# car_model
# chevrolet chevelle malibu  chevrolet chevelle malibu
# buick skylark 320                  buick skylark 320
# plymouth satellite                plymouth satellite
# amc rebel sst                          amc rebel sst
# ford torino                              ford torino
# ...                                              ...
# ford mustang gl                      ford mustang gl
# vw pickup                                  vw pickup
# dodge rampage                          dodge rampage
# ford ranger                              ford ranger
# chevrolet s-10                        chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars.reset_index(inplace = True)

# %%
cars.rename(columns ={'horsepower':'hp', 'origin':'country'}, inplace = True)

# %%
cars
# Out:
#                      car_model   mpg  cylinders  displacement     hp  weight  \
# 0    chevrolet chevelle malibu  18.0          8         307.0  130.0    3504
# 1            buick skylark 320  15.0          8         350.0  165.0    3693
# 2           plymouth satellite  18.0          8         318.0  150.0    3436
# 3                amc rebel sst  16.0          8         304.0  150.0    3433
# 4                  ford torino  17.0          8         302.0  140.0    3449
# ..                         ...   ...        ...           ...    ...     ...
# 393            ford mustang gl  27.0          4         140.0   86.0    2790
# 394                  vw pickup  44.0          4          97.0   52.0    2130
# 395              dodge rampage  32.0          4         135.0   84.0    2295
# 396                ford ranger  28.0          4         120.0   79.0    2625
# 397             chevrolet s-10  31.0          4         119.0   82.0    2720
#
#      acceleration  model_year country                       name
# 0            12.0          70     usa  chevrolet chevelle malibu
# 1            11.5          70     usa          buick skylark 320
# 2            11.0          70     usa         plymouth satellite
# 3            12.0          70     usa              amc rebel sst
# 4            10.5          70     usa                ford torino
# ..            ...         ...     ...                        ...
# 393          15.6          82     usa            ford mustang gl
# 394          24.6          82  europe                  vw pickup
# 395          11.6          82     usa              dodge rampage
# 396          18.6          82     usa                ford ranger
# 397          19.4          82     usa             chevrolet s-10
#
# [398 rows x 10 columns]

# %%
import pandas as pd

# %%
cars = pd.read_csv('cars.csv')

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
high_eff = cars[cars.mpg > 40].copy()

# %%
high_eff
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 244  43.1          4          90.0        48.0    1985          21.5
# 309  41.5          4          98.0        76.0    2144          14.7
# 322  46.6          4          86.0        65.0    2110          17.9
# 324  40.8          4          85.0        65.0    2110          19.2
# 325  44.3          4          90.0        48.0    2085          21.7
# 326  43.4          4          90.0        48.0    2335          23.7
# 329  44.6          4          91.0        67.0    1850          13.8
# 330  40.9          4          85.0         NaN    1835          17.3
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                     name
# 244          78  europe  vw rabbit custom diesel
# 309          80  europe                vw rabbit
# 322          80   japan                mazda glc
# 324          80   japan               datsun 210
# 325          80  europe     vw rabbit c (diesel)
# 326          80  europe       vw dasher (diesel)
# 329          80   japan      honda civic 1500 gl
# 330          80  europe     renault lecar deluxe
# 394          82  europe                vw pickup

# %%
high_eff['mpg'] = 40

# %%
high_eff
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 244   40          4          90.0        48.0    1985          21.5
# 309   40          4          98.0        76.0    2144          14.7
# 322   40          4          86.0        65.0    2110          17.9
# 324   40          4          85.0        65.0    2110          19.2
# 325   40          4          90.0        48.0    2085          21.7
# 326   40          4          90.0        48.0    2335          23.7
# 329   40          4          91.0        67.0    1850          13.8
# 330   40          4          85.0         NaN    1835          17.3
# 394   40          4          97.0        52.0    2130          24.6
#
#      model_year  origin                     name
# 244          78  europe  vw rabbit custom diesel
# 309          80  europe                vw rabbit
# 322          80   japan                mazda glc
# 324          80   japan               datsun 210
# 325          80  europe     vw rabbit c (diesel)
# 326          80  europe       vw dasher (diesel)
# 329          80   japan      honda civic 1500 gl
# 330          80  europe     renault lecar deluxe
# 394          82  europe                vw pickup

# %%
cars.mpg.max()
# Out:
# 46.6

# %%
cars[cars.mpg > 40]['mpg'] = 100
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_32072\602706789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars[cars.mpg > 40]['mpg'] = 100

# %%
cars[cars.mpg > 30].loc[:,'mpg'] = 50
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_32072\563956268.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cars[cars.mpg > 30].loc[:,'mpg'] = 50

# %%
cars.loc[cars.mpg > 30, 'mpg'] = 10000

# %%
cars
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0       18.0          8         307.0       130.0    3504          12.0
# 1       15.0          8         350.0       165.0    3693          11.5
# 2       18.0          8         318.0       150.0    3436          11.0
# 3       16.0          8         304.0       150.0    3433          12.0
# 4       17.0          8         302.0       140.0    3449          10.5
# ..       ...        ...           ...         ...     ...           ...
# 393     27.0          4         140.0        86.0    2790          15.6
# 394  10000.0          4          97.0        52.0    2130          24.6
# 395  10000.0          4         135.0        84.0    2295          11.6
# 396     28.0          4         120.0        79.0    2625          18.6
# 397  10000.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
Exercise 7
# Out:
#   Cell In[47], line 1
#     Exercise 7
#              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
cars.sort_values(by = 'mpg', ascending = False, inplace = True)

# %%
cars
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 397  10000.0          4         119.0        82.0    2720          19.4
# 337  10000.0          4         107.0        72.0    2290          17.0
# 319  10000.0          4         120.0        75.0    2542          17.5
# 320  10000.0          4         119.0        92.0    2434          15.0
# 238  10000.0          4          98.0        83.0    2075          15.9
# ..       ...        ...           ...         ...     ...           ...
# 103     11.0          8         400.0       150.0    4997          14.0
# 67      11.0          8         429.0       208.0    4633          11.0
# 25      10.0          8         360.0       215.0    4615          14.0
# 26      10.0          8         307.0       200.0    4376          15.0
# 28       9.0          8         304.0       193.0    4732          18.5
#
#      model_year origin                  name
# 397          82    usa        chevrolet s-10
# 337          80  japan          honda accord
# 319          80  japan             mazda 626
# 320          80  japan  datsun 510 hatchback
# 238          77    usa        dodge colt m/m
# ..          ...    ...                   ...
# 103          73    usa      chevrolet impala
# 67           72    usa       mercury marquis
# 25           70    usa             ford f250
# 26           70    usa         chevrolet c20
# 28           70    usa              ih 1200d
#
# [398 rows x 9 columns]

# %%
cars.sort_index(inplace = True)

# %%
cars
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0       18.0          8         307.0       130.0    3504          12.0
# 1       15.0          8         350.0       165.0    3693          11.5
# 2       18.0          8         318.0       150.0    3436          11.0
# 3       16.0          8         304.0       150.0    3433          12.0
# 4       17.0          8         302.0       140.0    3449          10.5
# ..       ...        ...           ...         ...     ...           ...
# 393     27.0          4         140.0        86.0    2790          15.6
# 394  10000.0          4          97.0        52.0    2130          24.6
# 395  10000.0          4         135.0        84.0    2295          11.6
# 396     28.0          4         120.0        79.0    2625          18.6
# 397  10000.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars['hp_rank'] = cars.hp.rank(method = 'min', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32072\4230904974.py in ?()
# ----> 1 cars['hp_rank'] = cars.hp.rank(method = 'min', ascending = False)
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'hp'

# %%
cars['hp_rank2'] = cars.mpg.rank(method = 'min', ascending = False)

# %%
cars.sort_values(by = 'hp_rank2', inplace = True)

# %%
cars
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 198  10000.0          4          91.0        53.0    1795          17.4
# 301  10000.0          4         105.0        70.0    2200          13.2
# 302  10000.0          4         105.0        70.0    2150          14.9
# 303  10000.0          4          85.0        65.0    2020          19.2
# 304  10000.0          4          91.0        69.0    2130          14.7
# ..       ...        ...           ...         ...     ...           ...
# 27      11.0          8         318.0       210.0    4382          13.5
# 103     11.0          8         400.0       150.0    4997          14.0
# 25      10.0          8         360.0       215.0    4615          14.0
# 26      10.0          8         307.0       200.0    4376          15.0
# 28       9.0          8         304.0       193.0    4732          18.5
#
#      model_year  origin                  name  hp_rank2
# 198          76   japan           honda civic       1.0
# 301          79     usa      plymouth horizon       1.0
# 302          79     usa  plymouth horizon tc3       1.0
# 303          79   japan            datsun 210       1.0
# 304          79  europe    fiat strada custom       1.0
# ..          ...     ...                   ...       ...
# 27           70     usa            dodge d200     392.0
# 103          73     usa      chevrolet impala     392.0
# 25           70     usa             ford f250     396.0
# 26           70     usa         chevrolet c20     396.0
# 28           70     usa              ih 1200d     398.0
#
# [398 rows x 10 columns]

# %%
cars.name.value_counts()
# Out:
# name
# ford pinto                6
# vw rabbit                 5
# amc matador               5
# ford maverick             5
# toyota corolla            5
#                          ..
# fiat 124 sport coupe      1
# bmw 2002                  1
# renault 12 (sw)           1
# dodge aries wagon (sw)    1
# ih 1200d                  1
# Name: count, Length: 300, dtype: int64

# %%
cars.name.nunique()
# Out:
# 300

# %%
cars.sort_values(by = 'weight', ascending = False, inplace = True)

# %%
cars.loc[:10,:]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 44   13.0          8         400.0       175.0    5140          12.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 42   12.0          8         383.0       180.0    4955          11.5
# 90   12.0          8         429.0       198.0    4952          11.5
# 95   12.0          8         455.0       225.0    4951          11.0
# ..    ...        ...           ...         ...     ...           ...
# 11   14.0          8         340.0       160.0    3609           8.0
# 291  19.2          8         267.0       125.0    3605          15.0
# 200  18.0          6         250.0        78.0    3574          21.0
# 251  20.2          8         302.0       139.0    3570          12.8
# 10   15.0          8         383.0       170.0    3563          10.0
#
#      model_year origin                           name  hp_rank2
# 44           71    usa            pontiac safari (sw)     366.0
# 103          73    usa               chevrolet impala     392.0
# 42           71    usa              dodge monaco (sw)     386.0
# 90           73    usa       mercury marquis brougham     386.0
# 95           73    usa       buick electra 225 custom     386.0
# ..          ...    ...                            ...       ...
# 11           70    usa             plymouth 'cuda 340     347.0
# 291          79    usa  chevrolet malibu classic (sw)     252.0
# 200          76    usa              ford granada ghia     275.0
# 251          78    usa           mercury monarch ghia     235.0
# 10           70    usa            dodge challenger se     330.0
#
# [104 rows x 10 columns]

# %%
cars.corr(numeric_only = True)
# Out:
# -0.7762849596761753

# %%
cars
# Out:
#          mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 44      13.0          8         400.0       175.0    5140          12.0
# 103     11.0          8         400.0       150.0    4997          14.0
# 42      12.0          8         383.0       180.0    4955          11.5
# 90      12.0          8         429.0       198.0    4952          11.5
# 95      12.0          8         455.0       225.0    4951          11.0
# ..       ...        ...           ...         ...     ...           ...
# 53   10000.0          4          71.0        65.0    1773          19.0
# 345  10000.0          4          81.0        60.0    1760          16.1
# 343  10000.0          4          79.0        58.0    1755          16.9
# 144  10000.0          4          76.0        52.0    1649          16.5
# 54   10000.0          4          72.0        69.0    1613          18.0
#
#      model_year origin                      name  hp_rank2
# 44           71    usa       pontiac safari (sw)     366.0
# 103          73    usa          chevrolet impala     392.0
# 42           71    usa         dodge monaco (sw)     386.0
# 90           73    usa  mercury marquis brougham     386.0
# 95           73    usa  buick electra 225 custom     386.0
# ..          ...    ...                       ...       ...
# 53           71  japan       toyota corolla 1200       1.0
# 345          81  japan          honda civic 1300       1.0
# 343          81  japan            toyota starlet       1.0
# 144          74  japan             toyota corona       1.0
# 54           71  japan               datsun 1200       1.0
#
# [398 rows x 10 columns]

# %%
cars = pd.read_csv('cars.csv')

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars.iloc[:,:-2].apply(lambda x: x.max() - x.min(), axis = 0)
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# model_year        12.0
# dtype: float64

# %%
cars.iloc[:,:-2].apply(lambda x: x.mean(), axis = 0)
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# horsepower       104.469388
# weight          2970.424623
# acceleration      15.568090
# model_year        76.010050
# dtype: float64

# %%
cars.set_index(['model_year','origin'], inplace = True, drop = False)

# %%
cars
# Out:
#                     mpg  cylinders  displacement  horsepower  weight  \
# model_year origin
# 70         usa     18.0          8         307.0       130.0    3504
#            usa     15.0          8         350.0       165.0    3693
#            usa     18.0          8         318.0       150.0    3436
#            usa     16.0          8         304.0       150.0    3433
#            usa     17.0          8         302.0       140.0    3449
# ...                 ...        ...           ...         ...     ...
# 82         usa     27.0          4         140.0        86.0    2790
#            europe  44.0          4          97.0        52.0    2130
#            usa     32.0          4         135.0        84.0    2295
#            usa     28.0          4         120.0        79.0    2625
#            usa     31.0          4         119.0        82.0    2720
#
#                    acceleration  model_year  origin                       name
# model_year origin
# 70         usa             12.0          70     usa  chevrolet chevelle malibu
#            usa             11.5          70     usa          buick skylark 320
#            usa             11.0          70     usa         plymouth satellite
#            usa             12.0          70     usa              amc rebel sst
#            usa             10.5          70     usa                ford torino
# ...                         ...         ...     ...                        ...
# 82         usa             15.6          82     usa            ford mustang gl
#            europe          24.6          82  europe                  vw pickup
#            usa             11.6          82     usa              dodge rampage
#            usa             18.6          82     usa                ford ranger
#            usa             19.4          82     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars.loc[(70,'usa'),'mpg']
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_32072\3073199419.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   cars.loc[(70,'usa'),'mpg']
# model_year  origin
# 70          usa       18.0
#             usa       15.0
#             usa       18.0
#             usa       16.0
#             usa       17.0
#             usa       15.0
#             usa       14.0
#             usa       14.0
#             usa       14.0
#             usa       15.0
#             usa       15.0
#             usa       14.0
#             usa       15.0
#             usa       14.0
#             usa       22.0
#             usa       18.0
#             usa       21.0
#             usa       21.0
#             usa       10.0
#             usa       10.0
#             usa       11.0
#             usa        9.0
# Name: mpg, dtype: float64

# %%
cars.loc[:,'origin'] = cars.origin.str.title()

# %%
cars
# Out:
#                     mpg  cylinders  displacement  horsepower  weight  \
# model_year origin
# 70         usa     18.0          8         307.0       130.0    3504
#            usa     15.0          8         350.0       165.0    3693
#            usa     18.0          8         318.0       150.0    3436
#            usa     16.0          8         304.0       150.0    3433
#            usa     17.0          8         302.0       140.0    3449
# ...                 ...        ...           ...         ...     ...
# 82         usa     27.0          4         140.0        86.0    2790
#            europe  44.0          4          97.0        52.0    2130
#            usa     32.0          4         135.0        84.0    2295
#            usa     28.0          4         120.0        79.0    2625
#            usa     31.0          4         119.0        82.0    2720
#
#                    acceleration  model_year  origin                       name
# model_year origin
# 70         usa             12.0          70     Usa  chevrolet chevelle malibu
#            usa             11.5          70     Usa          buick skylark 320
#            usa             11.0          70     Usa         plymouth satellite
#            usa             12.0          70     Usa              amc rebel sst
#            usa             10.5          70     Usa                ford torino
# ...                         ...         ...     ...                        ...
# 82         usa             15.6          82     Usa            ford mustang gl
#            europe          24.6          82  Europe                  vw pickup
#            usa             11.6          82     Usa              dodge rampage
#            usa             18.6          82     Usa                ford ranger
#            usa             19.4          82     Usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
split = cars.name.str.split(pat = " ", n = 1, expand = True)

# %%
cars.name.describe()
# Out:
# count            398
# unique           300
# top       ford pinto
# freq               6
# Name: name, dtype: object

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 398 entries, (70, 'usa') to (82, 'usa')
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 45.8+ KB

# %%
split[0]
# Out:
# model_year  origin
# 70          usa       chevrolet
#             usa           buick
#             usa        plymouth
#             usa             amc
#             usa            ford
#                         ...
# 82          usa            ford
#             europe           vw
#             usa           dodge
#             usa            ford
#             usa       chevrolet
# Name: 0, Length: 398, dtype: object

# %% [markdown]
# #Part 2
# Importing csv files

# %%
with open('titanic.csv','r') as f:
    text = f.readlines()

# %%
text
# Out:
# ['survived,pclass,sex,age,sibsp,parch,fare,embarked,deck\n',
#  '0,3,male,22.0,1,0,7.25,S,\n',
#  '1,1,female,38.0,1,0,71.2833,C,C\n',
#  '1,3,female,26.0,0,0,7.925,S,\n',
#  '1,1,female,35.0,1,0,53.1,S,C\n',
#  '0,3,male,35.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,8.4583,Q,\n',
#  '0,1,male,54.0,0,0,51.8625,S,E\n',
#  '0,3,male,2.0,3,1,21.075,S,\n',
#  '1,3,female,27.0,0,2,11.1333,S,\n',
#  '1,2,female,14.0,1,0,30.0708,C,\n',
#  '1,3,female,4.0,1,1,16.7,S,G\n',
#  '1,1,female,58.0,0,0,26.55,S,C\n',
#  '0,3,male,20.0,0,0,8.05,S,\n',
#  '0,3,male,39.0,1,5,31.275,S,\n',
#  '0,3,female,14.0,0,0,7.8542,S,\n',
#  '1,2,female,55.0,0,0,16.0,S,\n',
#  '0,3,male,2.0,4,1,29.125,Q,\n',
#  '1,2,male,,0,0,13.0,S,\n',
#  '0,3,female,31.0,1,0,18.0,S,\n',
#  '1,3,female,,0,0,7.225,C,\n',
#  '0,2,male,35.0,0,0,26.0,S,\n',
#  '1,2,male,34.0,0,0,13.0,S,D\n',
#  '1,3,female,15.0,0,0,8.0292,Q,\n',
#  '1,1,male,28.0,0,0,35.5,S,A\n',
#  '0,3,female,8.0,3,1,21.075,S,\n',
#  '1,3,female,38.0,1,5,31.3875,S,\n',
#  '0,3,male,,0,0,7.225,C,\n',
#  '0,1,male,19.0,3,2,263.0,S,C\n',
#  '1,3,female,,0,0,7.8792,Q,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '0,1,male,40.0,0,0,27.7208,C,\n',
#  '1,1,female,,1,0,146.5208,C,B\n',
#  '1,3,female,,0,0,7.75,Q,\n',
#  '0,2,male,66.0,0,0,10.5,S,\n',
#  '0,1,male,28.0,1,0,82.1708,C,\n',
#  '0,1,male,42.0,1,0,52.0,S,\n',
#  '1,3,male,,0,0,7.2292,C,\n',
#  '0,3,male,21.0,0,0,8.05,S,\n',
#  '0,3,female,18.0,2,0,18.0,S,\n',
#  '1,3,female,14.0,1,0,11.2417,C,\n',
#  '0,3,female,40.0,1,0,9.475,S,\n',
#  '0,2,female,27.0,1,0,21.0,S,\n',
#  '0,3,male,,0,0,7.8958,C,\n',
#  '1,2,female,3.0,1,2,41.5792,C,\n',
#  '1,3,female,19.0,0,0,7.8792,Q,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '0,3,male,,1,0,15.5,Q,\n',
#  '1,3,female,,0,0,7.75,Q,\n',
#  '0,3,male,,2,0,21.6792,C,\n',
#  '0,3,female,18.0,1,0,17.8,S,\n',
#  '0,3,male,7.0,4,1,39.6875,S,\n',
#  '0,3,male,21.0,0,0,7.8,S,\n',
#  '1,1,female,49.0,1,0,76.7292,C,D\n',
#  '1,2,female,29.0,1,0,26.0,S,\n',
#  '0,1,male,65.0,0,1,61.9792,C,B\n',
#  '1,1,male,,0,0,35.5,S,C\n',
#  '1,2,female,21.0,0,0,10.5,S,\n',
#  '0,3,male,28.5,0,0,7.2292,C,\n',
#  '1,2,female,5.0,1,2,27.75,S,\n',
#  '0,3,male,11.0,5,2,46.9,S,\n',
#  '0,3,male,22.0,0,0,7.2292,C,\n',
#  '1,1,female,38.0,0,0,80.0,,B\n',
#  '0,1,male,45.0,1,0,83.475,S,C\n',
#  '0,3,male,4.0,3,2,27.9,S,\n',
#  '0,1,male,,0,0,27.7208,C,\n',
#  '1,3,male,,1,1,15.2458,C,\n',
#  '1,2,female,29.0,0,0,10.5,S,F\n',
#  '0,3,male,19.0,0,0,8.1583,S,\n',
#  '1,3,female,17.0,4,2,7.925,S,\n',
#  '0,3,male,26.0,2,0,8.6625,S,\n',
#  '0,2,male,32.0,0,0,10.5,S,\n',
#  '0,3,female,16.0,5,2,46.9,S,\n',
#  '0,2,male,21.0,0,0,73.5,S,\n',
#  '0,3,male,26.0,1,0,14.4542,C,\n',
#  '1,3,male,32.0,0,0,56.4958,S,\n',
#  '0,3,male,25.0,0,0,7.65,S,F\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '1,2,male,0.83,0,2,29.0,S,\n',
#  '1,3,female,30.0,0,0,12.475,S,\n',
#  '0,3,male,22.0,0,0,9.0,S,\n',
#  '1,3,male,29.0,0,0,9.5,S,\n',
#  '1,3,female,,0,0,7.7875,Q,\n',
#  '0,1,male,28.0,0,0,47.1,S,\n',
#  '1,2,female,17.0,0,0,10.5,S,\n',
#  '1,3,female,33.0,3,0,15.85,S,\n',
#  '0,3,male,16.0,1,3,34.375,S,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '1,1,female,23.0,3,2,263.0,S,C\n',
#  '0,3,male,24.0,0,0,8.05,S,\n',
#  '0,3,male,29.0,0,0,8.05,S,\n',
#  '0,3,male,20.0,0,0,7.8542,S,\n',
#  '0,1,male,46.0,1,0,61.175,S,E\n',
#  '0,3,male,26.0,1,2,20.575,S,\n',
#  '0,3,male,59.0,0,0,7.25,S,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '0,1,male,71.0,0,0,34.6542,C,A\n',
#  '1,1,male,23.0,0,1,63.3583,C,D\n',
#  '1,2,female,34.0,0,1,23.0,S,\n',
#  '0,2,male,34.0,1,0,26.0,S,\n',
#  '0,3,female,28.0,0,0,7.8958,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '0,1,male,21.0,0,1,77.2875,S,D\n',
#  '0,3,male,33.0,0,0,8.6542,S,\n',
#  '0,3,male,37.0,2,0,7.925,S,\n',
#  '0,3,male,28.0,0,0,7.8958,S,\n',
#  '1,3,female,21.0,0,0,7.65,S,\n',
#  '1,3,male,,0,0,7.775,S,\n',
#  '0,3,male,38.0,0,0,7.8958,S,\n',
#  '1,3,female,,1,0,24.15,Q,\n',
#  '0,1,male,47.0,0,0,52.0,S,C\n',
#  '0,3,female,14.5,1,0,14.4542,C,\n',
#  '0,3,male,22.0,0,0,8.05,S,\n',
#  '0,3,female,20.0,1,0,9.825,S,\n',
#  '0,3,female,17.0,0,0,14.4583,C,\n',
#  '0,3,male,21.0,0,0,7.925,S,\n',
#  '0,3,male,70.5,0,0,7.75,Q,\n',
#  '0,2,male,29.0,1,0,21.0,S,\n',
#  '0,1,male,24.0,0,1,247.5208,C,B\n',
#  '0,3,female,2.0,4,2,31.275,S,\n',
#  '0,2,male,21.0,2,0,73.5,S,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '0,2,male,32.5,1,0,30.0708,C,\n',
#  '1,2,female,32.5,0,0,13.0,S,E\n',
#  '0,1,male,54.0,0,1,77.2875,S,D\n',
#  '1,3,male,12.0,1,0,11.2417,C,\n',
#  '0,3,male,,0,0,7.75,Q,\n',
#  '1,3,male,24.0,0,0,7.1417,S,\n',
#  '1,3,female,,1,1,22.3583,C,F\n',
#  '0,3,male,45.0,0,0,6.975,S,\n',
#  '0,3,male,33.0,0,0,7.8958,C,\n',
#  '0,3,male,20.0,0,0,7.05,S,\n',
#  '0,3,female,47.0,1,0,14.5,S,\n',
#  '1,2,female,29.0,1,0,26.0,S,\n',
#  '0,2,male,25.0,0,0,13.0,S,\n',
#  '0,2,male,23.0,0,0,15.0458,C,\n',
#  '1,1,female,19.0,0,2,26.2833,S,D\n',
#  '0,1,male,37.0,1,0,53.1,S,C\n',
#  '0,3,male,16.0,0,0,9.2167,S,\n',
#  '0,1,male,24.0,0,0,79.2,C,B\n',
#  '0,3,female,,0,2,15.2458,C,\n',
#  '1,3,female,22.0,0,0,7.75,S,\n',
#  '1,3,female,24.0,1,0,15.85,S,\n',
#  '0,3,male,19.0,0,0,6.75,Q,\n',
#  '0,2,male,18.0,0,0,11.5,S,\n',
#  '0,2,male,19.0,1,1,36.75,S,\n',
#  '1,3,male,27.0,0,0,7.7958,S,\n',
#  '0,3,female,9.0,2,2,34.375,S,\n',
#  '0,2,male,36.5,0,2,26.0,S,F\n',
#  '0,2,male,42.0,0,0,13.0,S,\n',
#  '0,2,male,51.0,0,0,12.525,S,\n',
#  '1,1,female,22.0,1,0,66.6,S,C\n',
#  '0,3,male,55.5,0,0,8.05,S,\n',
#  '0,3,male,40.5,0,2,14.5,S,\n',
#  '0,3,male,,0,0,7.3125,S,\n',
#  '0,1,male,51.0,0,1,61.3792,C,\n',
#  '1,3,female,16.0,0,0,7.7333,Q,\n',
#  '0,3,male,30.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,8.6625,S,\n',
#  '0,3,male,,8,2,69.55,S,\n',
#  '0,3,male,44.0,0,1,16.1,S,\n',
#  '1,2,female,40.0,0,0,15.75,S,\n',
#  '0,3,male,26.0,0,0,7.775,S,\n',
#  '0,3,male,17.0,0,0,8.6625,S,\n',
#  '0,3,male,1.0,4,1,39.6875,S,\n',
#  '1,3,male,9.0,0,2,20.525,S,\n',
#  '1,1,female,,0,1,55.0,S,E\n',
#  '0,3,female,45.0,1,4,27.9,S,\n',
#  '0,1,male,,0,0,25.925,S,\n',
#  '0,3,male,28.0,0,0,56.4958,S,\n',
#  '0,1,male,61.0,0,0,33.5,S,B\n',
#  '0,3,male,4.0,4,1,29.125,Q,\n',
#  '1,3,female,1.0,1,1,11.1333,S,\n',
#  '0,3,male,21.0,0,0,7.925,S,\n',
#  '0,1,male,56.0,0,0,30.6958,C,A\n',
#  '0,3,male,18.0,1,1,7.8542,S,\n',
#  '0,3,male,,3,1,25.4667,S,\n',
#  '0,1,female,50.0,0,0,28.7125,C,C\n',
#  '0,2,male,30.0,0,0,13.0,S,\n',
#  '0,3,male,36.0,0,0,0.0,S,\n',
#  '0,3,female,,8,2,69.55,S,\n',
#  '0,2,male,,0,0,15.05,C,\n',
#  '0,3,male,9.0,4,2,31.3875,S,\n',
#  '1,2,male,1.0,2,1,39.0,S,F\n',
#  '1,3,female,4.0,0,2,22.025,S,\n',
#  '0,1,male,,0,0,50.0,S,A\n',
#  '1,3,female,,1,0,15.5,Q,\n',
#  '1,1,male,45.0,0,0,26.55,S,\n',
#  '0,3,male,40.0,1,1,15.5,Q,\n',
#  '0,3,male,36.0,0,0,7.8958,S,\n',
#  '1,2,female,32.0,0,0,13.0,S,\n',
#  '0,2,male,19.0,0,0,13.0,S,\n',
#  '1,3,female,19.0,1,0,7.8542,S,\n',
#  '1,2,male,3.0,1,1,26.0,S,F\n',
#  '1,1,female,44.0,0,0,27.7208,C,B\n',
#  '1,1,female,58.0,0,0,146.5208,C,B\n',
#  '0,3,male,,0,0,7.75,Q,\n',
#  '0,3,male,42.0,0,1,8.4042,S,\n',
#  '1,3,female,,0,0,7.75,Q,\n',
#  '0,2,female,24.0,0,0,13.0,S,\n',
#  '0,3,male,28.0,0,0,9.5,S,\n',
#  '0,3,male,,8,2,69.55,S,\n',
#  '0,3,male,34.0,0,0,6.4958,S,\n',
#  '0,3,male,45.5,0,0,7.225,C,\n',
#  '1,3,male,18.0,0,0,8.05,S,\n',
#  '0,3,female,2.0,0,1,10.4625,S,G\n',
#  '0,3,male,32.0,1,0,15.85,S,\n',
#  '1,3,male,26.0,0,0,18.7875,C,\n',
#  '1,3,female,16.0,0,0,7.75,Q,\n',
#  '1,1,male,40.0,0,0,31.0,C,A\n',
#  '0,3,male,24.0,0,0,7.05,S,\n',
#  '1,2,female,35.0,0,0,21.0,S,\n',
#  '0,3,male,22.0,0,0,7.25,S,\n',
#  '0,2,male,30.0,0,0,13.0,S,\n',
#  '0,3,male,,1,0,7.75,Q,\n',
#  '1,1,female,31.0,1,0,113.275,C,D\n',
#  '1,3,female,27.0,0,0,7.925,S,\n',
#  '0,2,male,42.0,1,0,27.0,S,\n',
#  '1,1,female,32.0,0,0,76.2917,C,D\n',
#  '0,2,male,30.0,0,0,10.5,S,\n',
#  '1,3,male,16.0,0,0,8.05,S,\n',
#  '0,2,male,27.0,0,0,13.0,S,\n',
#  '0,3,male,51.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '1,1,male,38.0,1,0,90.0,S,C\n',
#  '0,3,male,22.0,0,0,9.35,S,\n',
#  '1,2,male,19.0,0,0,10.5,S,\n',
#  '0,3,male,20.5,0,0,7.25,S,\n',
#  '0,2,male,18.0,0,0,13.0,S,\n',
#  '0,3,female,,3,1,25.4667,S,\n',
#  '1,1,female,35.0,1,0,83.475,S,C\n',
#  '0,3,male,29.0,0,0,7.775,S,\n',
#  '0,2,male,59.0,0,0,13.5,S,\n',
#  '1,3,female,5.0,4,2,31.3875,S,\n',
#  '0,2,male,24.0,0,0,10.5,S,\n',
#  '0,3,female,,0,0,7.55,S,\n',
#  '0,2,male,44.0,1,0,26.0,S,\n',
#  '1,2,female,8.0,0,2,26.25,S,\n',
#  '0,2,male,19.0,0,0,10.5,S,\n',
#  '0,2,male,33.0,0,0,12.275,S,\n',
#  '0,3,female,,1,0,14.4542,C,\n',
#  '1,3,female,,1,0,15.5,Q,\n',
#  '0,2,male,29.0,0,0,10.5,S,\n',
#  '0,3,male,22.0,0,0,7.125,S,\n',
#  '0,3,male,30.0,0,0,7.225,C,\n',
#  '0,1,male,44.0,2,0,90.0,Q,C\n',
#  '0,3,female,25.0,0,0,7.775,S,\n',
#  '1,2,female,24.0,0,2,14.5,S,\n',
#  '1,1,male,37.0,1,1,52.5542,S,D\n',
#  '0,2,male,54.0,1,0,26.0,S,\n',
#  '0,3,male,,0,0,7.25,S,\n',
#  '0,3,female,29.0,1,1,10.4625,S,G\n',
#  '0,1,male,62.0,0,0,26.55,S,C\n',
#  '0,3,male,30.0,1,0,16.1,S,\n',
#  '0,3,female,41.0,0,2,20.2125,S,\n',
#  '1,3,female,29.0,0,2,15.2458,C,\n',
#  '1,1,female,,0,0,79.2,C,\n',
#  '1,1,female,30.0,0,0,86.5,S,B\n',
#  '1,1,female,35.0,0,0,512.3292,C,\n',
#  '1,2,female,50.0,0,1,26.0,S,\n',
#  '0,3,male,,0,0,7.75,Q,\n',
#  '1,3,male,3.0,4,2,31.3875,S,\n',
#  '0,1,male,52.0,1,1,79.65,S,E\n',
#  '0,1,male,40.0,0,0,0.0,S,B\n',
#  '0,3,female,,0,0,7.75,Q,\n',
#  '0,2,male,36.0,0,0,10.5,S,\n',
#  '0,3,male,16.0,4,1,39.6875,S,\n',
#  '1,3,male,25.0,1,0,7.775,S,\n',
#  '1,1,female,58.0,0,1,153.4625,S,C\n',
#  '1,1,female,35.0,0,0,135.6333,S,C\n',
#  '0,1,male,,0,0,31.0,S,\n',
#  '1,3,male,25.0,0,0,0.0,S,\n',
#  '1,2,female,41.0,0,1,19.5,S,\n',
#  '0,1,male,37.0,0,1,29.7,C,C\n',
#  '1,3,female,,0,0,7.75,Q,\n',
#  '1,1,female,63.0,1,0,77.9583,S,D\n',
#  '0,3,female,45.0,0,0,7.75,S,\n',
#  '0,2,male,,0,0,0.0,S,\n',
#  '0,3,male,7.0,4,1,29.125,Q,\n',
#  '1,3,female,35.0,1,1,20.25,S,\n',
#  '0,3,male,65.0,0,0,7.75,Q,\n',
#  '0,3,male,28.0,0,0,7.8542,S,\n',
#  '0,3,male,16.0,0,0,9.5,S,\n',
#  '1,3,male,19.0,0,0,8.05,S,\n',
#  '0,1,male,,0,0,26.0,S,A\n',
#  '0,3,male,33.0,0,0,8.6625,C,\n',
#  '1,3,male,30.0,0,0,9.5,S,\n',
#  '0,3,male,22.0,0,0,7.8958,S,\n',
#  '1,2,male,42.0,0,0,13.0,S,\n',
#  '1,3,female,22.0,0,0,7.75,Q,\n',
#  '1,1,female,26.0,0,0,78.85,S,\n',
#  '1,1,female,19.0,1,0,91.0792,C,B\n',
#  '0,2,male,36.0,0,0,12.875,C,D\n',
#  '0,3,female,24.0,0,0,8.85,S,\n',
#  '0,3,male,24.0,0,0,7.8958,S,\n',
#  '0,1,male,,0,0,27.7208,C,\n',
#  '0,3,male,23.5,0,0,7.2292,C,\n',
#  '0,1,female,2.0,1,2,151.55,S,C\n',
#  '1,1,male,,0,0,30.5,S,C\n',
#  '1,1,female,50.0,0,1,247.5208,C,B\n',
#  '1,3,female,,0,0,7.75,Q,\n',
#  '1,3,male,,2,0,23.25,Q,\n',
#  '0,3,male,19.0,0,0,0.0,S,\n',
#  '1,2,female,,0,0,12.35,Q,E\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '1,1,male,0.92,1,2,151.55,S,C\n',
#  '1,1,female,,0,0,110.8833,C,\n',
#  '1,1,female,17.0,1,0,108.9,C,C\n',
#  '0,2,male,30.0,1,0,24.0,C,\n',
#  '1,1,female,30.0,0,0,56.9292,C,E\n',
#  '1,1,female,24.0,0,0,83.1583,C,C\n',
#  '1,1,female,18.0,2,2,262.375,C,B\n',
#  '0,2,female,26.0,1,1,26.0,S,\n',
#  '0,3,male,28.0,0,0,7.8958,S,\n',
#  '0,2,male,43.0,1,1,26.25,S,\n',
#  '1,3,female,26.0,0,0,7.8542,S,\n',
#  '1,2,female,24.0,1,0,26.0,S,\n',
#  '0,2,male,54.0,0,0,14.0,S,\n',
#  '1,1,female,31.0,0,2,164.8667,S,C\n',
#  '1,1,female,40.0,1,1,134.5,C,E\n',
#  '0,3,male,22.0,0,0,7.25,S,\n',
#  '0,3,male,27.0,0,0,7.8958,S,\n',
#  '1,2,female,30.0,0,0,12.35,Q,\n',
#  '1,2,female,22.0,1,1,29.0,S,\n',
#  '0,3,male,,8,2,69.55,S,\n',
#  '1,1,female,36.0,0,0,135.6333,C,C\n',
#  '0,3,male,61.0,0,0,6.2375,S,\n',
#  '1,2,female,36.0,0,0,13.0,S,D\n',
#  '1,3,female,31.0,1,1,20.525,S,\n',
#  '1,1,female,16.0,0,1,57.9792,C,B\n',
#  '1,3,female,,2,0,23.25,Q,\n',
#  '0,1,male,45.5,0,0,28.5,S,C\n',
#  '0,1,male,38.0,0,1,153.4625,S,C\n',
#  '0,3,male,16.0,2,0,18.0,S,\n',
#  '1,1,female,,1,0,133.65,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '0,1,male,29.0,1,0,66.6,S,C\n',
#  '1,1,female,41.0,0,0,134.5,C,E\n',
#  '1,3,male,45.0,0,0,8.05,S,\n',
#  '0,1,male,45.0,0,0,35.5,S,\n',
#  '1,2,male,2.0,1,1,26.0,S,F\n',
#  '1,1,female,24.0,3,2,263.0,S,C\n',
#  '0,2,male,28.0,0,0,13.0,S,\n',
#  '0,2,male,25.0,0,0,13.0,S,\n',
#  '0,2,male,36.0,0,0,13.0,S,\n',
#  '1,2,female,24.0,0,0,13.0,S,F\n',
#  '1,2,female,40.0,0,0,13.0,S,\n',
#  '1,3,female,,1,0,16.1,S,\n',
#  '1,3,male,3.0,1,1,15.9,S,\n',
#  '0,3,male,42.0,0,0,8.6625,S,\n',
#  '0,3,male,23.0,0,0,9.225,S,\n',
#  '0,1,male,,0,0,35.0,S,C\n',
#  '0,3,male,15.0,1,1,7.2292,C,\n',
#  '0,3,male,25.0,1,0,17.8,S,\n',
#  '0,3,male,,0,0,7.225,C,\n',
#  '0,3,male,28.0,0,0,9.5,S,\n',
#  '1,1,female,22.0,0,1,55.0,S,E\n',
#  '0,2,female,38.0,0,0,13.0,S,\n',
#  '1,3,female,,0,0,7.8792,Q,\n',
#  '1,3,female,,0,0,7.8792,Q,\n',
#  '0,3,male,40.0,1,4,27.9,S,\n',
#  '0,2,male,29.0,1,0,27.7208,C,\n',
#  '0,3,female,45.0,0,1,14.4542,C,\n',
#  '0,3,male,35.0,0,0,7.05,S,\n',
#  '0,3,male,,1,0,15.5,Q,\n',
#  '0,3,male,30.0,0,0,7.25,S,\n',
#  '1,1,female,60.0,1,0,75.25,C,D\n',
#  '1,3,female,,0,0,7.2292,C,\n',
#  '1,3,female,,0,0,7.75,Q,\n',
#  '1,1,female,24.0,0,0,69.3,C,B\n',
#  '1,1,male,25.0,1,0,55.4417,C,E\n',
#  '0,3,male,18.0,1,0,6.4958,S,\n',
#  '0,3,male,19.0,0,0,8.05,S,\n',
#  '0,1,male,22.0,0,0,135.6333,C,\n',
#  '0,3,female,3.0,3,1,21.075,S,\n',
#  '1,1,female,,1,0,82.1708,C,\n',
#  '1,3,female,22.0,0,0,7.25,S,\n',
#  '0,1,male,27.0,0,2,211.5,C,C\n',
#  '0,3,male,20.0,0,0,4.0125,C,\n',
#  '0,3,male,19.0,0,0,7.775,S,\n',
#  '1,1,female,42.0,0,0,227.525,C,\n',
#  '1,3,female,1.0,0,2,15.7417,C,\n',
#  '0,3,male,32.0,0,0,7.925,S,\n',
#  '1,1,female,35.0,1,0,52.0,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '0,2,male,18.0,0,0,73.5,S,\n',
#  '0,3,male,1.0,5,2,46.9,S,\n',
#  '1,2,female,36.0,0,0,13.0,S,\n',
#  '0,3,male,,0,0,7.7292,Q,\n',
#  '1,2,female,17.0,0,0,12.0,C,\n',
#  '1,1,male,36.0,1,2,120.0,S,B\n',
#  '1,3,male,21.0,0,0,7.7958,S,\n',
#  '0,3,male,28.0,2,0,7.925,S,\n',
#  '1,1,female,23.0,1,0,113.275,C,D\n',
#  '1,3,female,24.0,0,2,16.7,S,G\n',
#  '0,3,male,22.0,0,0,7.7958,S,\n',
#  '0,3,female,31.0,0,0,7.8542,S,\n',
#  '0,2,male,46.0,0,0,26.0,S,\n',
#  '0,2,male,23.0,0,0,10.5,S,\n',
#  '1,2,female,28.0,0,0,12.65,S,\n',
#  '1,3,male,39.0,0,0,7.925,S,\n',
#  '0,3,male,26.0,0,0,8.05,S,\n',
#  '0,3,female,21.0,1,0,9.825,S,\n',
#  '0,3,male,28.0,1,0,15.85,S,\n',
#  '0,3,female,20.0,0,0,8.6625,S,\n',
#  '0,2,male,34.0,1,0,21.0,S,\n',
#  '0,3,male,51.0,0,0,7.75,S,\n',
#  '1,2,male,3.0,1,1,18.75,S,\n',
#  '0,3,male,21.0,0,0,7.775,S,\n',
#  '0,3,female,,3,1,25.4667,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '0,3,male,,0,0,6.8583,Q,\n',
#  '1,1,female,33.0,1,0,90.0,Q,C\n',
#  '0,2,male,,0,0,0.0,S,\n',
#  '1,3,male,44.0,0,0,7.925,S,\n',
#  '0,3,female,,0,0,8.05,S,\n',
#  '1,2,female,34.0,1,1,32.5,S,\n',
#  '1,2,female,18.0,0,2,13.0,S,\n',
#  '0,2,male,30.0,0,0,13.0,S,\n',
#  '0,3,female,10.0,0,2,24.15,S,\n',
#  '0,3,male,,0,0,7.8958,C,\n',
#  '0,3,male,21.0,0,0,7.7333,Q,\n',
#  '0,3,male,29.0,0,0,7.875,S,\n',
#  '0,3,female,28.0,1,1,14.4,S,\n',
#  '0,3,male,18.0,1,1,20.2125,S,\n',
#  '0,3,male,,0,0,7.25,S,\n',
#  '1,2,female,28.0,1,0,26.0,S,\n',
#  '1,2,female,19.0,0,0,26.0,S,\n',
#  '0,3,male,,0,0,7.75,Q,\n',
#  '1,3,male,32.0,0,0,8.05,S,E\n',
#  '1,1,male,28.0,0,0,26.55,S,C\n',
#  '1,3,female,,1,0,16.1,S,\n',
#  '1,2,female,42.0,1,0,26.0,S,\n',
#  '0,3,male,17.0,0,0,7.125,S,\n',
#  '0,1,male,50.0,1,0,55.9,S,E\n',
#  '1,1,female,14.0,1,2,120.0,S,B\n',
#  '0,3,female,21.0,2,2,34.375,S,\n',
#  '1,2,female,24.0,2,3,18.75,S,\n',
#  '0,1,male,64.0,1,4,263.0,S,C\n',
#  '0,2,male,31.0,0,0,10.5,S,\n',
#  '1,2,female,45.0,1,1,26.25,S,\n',
#  '0,3,male,20.0,0,0,9.5,S,\n',
#  '0,3,male,25.0,1,0,7.775,S,\n',
#  '1,2,female,28.0,0,0,13.0,S,\n',
#  '1,3,male,,0,0,8.1125,S,\n',
#  '1,1,male,4.0,0,2,81.8583,S,A\n',
#  '1,2,female,13.0,0,1,19.5,S,\n',
#  '1,1,male,34.0,0,0,26.55,S,\n',
#  '1,3,female,5.0,2,1,19.2583,C,\n',
#  '1,1,male,52.0,0,0,30.5,S,C\n',
#  '0,2,male,36.0,1,2,27.75,S,\n',
#  '0,3,male,,1,0,19.9667,S,\n',
#  '0,1,male,30.0,0,0,27.75,C,C\n',
#  '1,1,male,49.0,1,0,89.1042,C,C\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '1,3,male,29.0,0,0,7.8958,C,\n',
#  '0,1,male,65.0,0,0,26.55,S,E\n',
#  '1,1,female,,1,0,51.8625,S,D\n',
#  '1,2,female,50.0,0,0,10.5,S,\n',
#  '0,3,male,,0,0,7.75,Q,\n',
#  '1,1,male,48.0,0,0,26.55,S,E\n',
#  '0,3,male,34.0,0,0,8.05,S,\n',
#  '0,1,male,47.0,0,0,38.5,S,E\n',
#  '0,2,male,48.0,0,0,13.0,S,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '0,3,male,38.0,0,0,7.05,S,\n',
#  '0,2,male,,0,0,0.0,S,\n',
#  '0,1,male,56.0,0,0,26.55,S,\n',
#  '0,3,male,,0,0,7.725,Q,\n',
#  '1,3,female,0.75,2,1,19.2583,C,\n',
#  '0,3,male,,0,0,7.25,S,\n',
#  '0,3,male,38.0,0,0,8.6625,S,\n',
#  '1,2,female,33.0,1,2,27.75,S,\n',
#  '1,2,female,23.0,0,0,13.7917,C,D\n',
#  '0,3,female,22.0,0,0,9.8375,S,\n',
#  '0,1,male,,0,0,52.0,S,A\n',
#  '0,2,male,34.0,1,0,21.0,S,\n',
#  '0,3,male,29.0,1,0,7.0458,S,\n',
#  '0,3,male,22.0,0,0,7.5208,S,\n',
#  '1,3,female,2.0,0,1,12.2875,S,\n',
#  '0,3,male,9.0,5,2,46.9,S,\n',
#  '0,2,male,,0,0,0.0,S,\n',
#  '0,3,male,50.0,0,0,8.05,S,\n',
#  '1,3,female,63.0,0,0,9.5875,S,\n',
#  '1,1,male,25.0,1,0,91.0792,C,B\n',
#  '0,3,female,,3,1,25.4667,S,\n',
#  '1,1,female,35.0,1,0,90.0,S,C\n',
#  '0,1,male,58.0,0,0,29.7,C,B\n',
#  '0,3,male,30.0,0,0,8.05,S,\n',
#  '1,3,male,9.0,1,1,15.9,S,\n',
#  '0,3,male,,1,0,19.9667,S,\n',
#  '0,3,male,21.0,0,0,7.25,S,\n',
#  '0,1,male,55.0,0,0,30.5,S,C\n',
#  '0,1,male,71.0,0,0,49.5042,C,\n',
#  '0,3,male,21.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,14.4583,C,\n',
#  '1,1,female,54.0,1,0,78.2667,C,D\n',
#  '0,3,male,,0,0,15.1,S,\n',
#  '0,1,female,25.0,1,2,151.55,S,C\n',
#  '0,3,male,24.0,0,0,7.7958,S,\n',
#  '0,3,male,17.0,0,0,8.6625,S,\n',
#  '0,3,female,21.0,0,0,7.75,Q,\n',
#  '0,3,female,,0,0,7.6292,Q,\n',
#  '0,3,female,37.0,0,0,9.5875,S,\n',
#  '1,1,female,16.0,0,0,86.5,S,B\n',
#  '0,1,male,18.0,1,0,108.9,C,C\n',
#  '1,2,female,33.0,0,2,26.0,S,\n',
#  '1,1,male,,0,0,26.55,S,\n',
#  '0,3,male,28.0,0,0,22.525,S,\n',
#  '1,3,male,26.0,0,0,56.4958,S,\n',
#  '1,3,male,29.0,0,0,7.75,Q,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '1,1,male,36.0,0,0,26.2875,S,E\n',
#  '1,1,female,54.0,1,0,59.4,C,\n',
#  '0,3,male,24.0,0,0,7.4958,S,\n',
#  '0,1,male,47.0,0,0,34.0208,S,D\n',
#  '1,2,female,34.0,0,0,10.5,S,F\n',
#  '0,3,male,,0,0,24.15,Q,\n',
#  '1,2,female,36.0,1,0,26.0,S,\n',
#  '0,3,male,32.0,0,0,7.8958,S,\n',
#  '1,1,female,30.0,0,0,93.5,S,B\n',
#  '0,3,male,22.0,0,0,7.8958,S,\n',
#  '0,3,male,,0,0,7.225,C,\n',
#  '1,1,female,44.0,0,1,57.9792,C,B\n',
#  '0,3,male,,0,0,7.2292,C,\n',
#  '0,3,male,40.5,0,0,7.75,Q,\n',
#  '1,2,female,50.0,0,0,10.5,S,\n',
#  '0,1,male,,0,0,221.7792,S,C\n',
#  '0,3,male,39.0,0,0,7.925,S,\n',
#  '0,2,male,23.0,2,1,11.5,S,\n',
#  '1,2,female,2.0,1,1,26.0,S,\n',
#  '0,3,male,,0,0,7.2292,C,\n',
#  '0,3,male,17.0,1,1,7.2292,C,\n',
#  '1,3,female,,0,2,22.3583,C,\n',
#  '0,3,female,30.0,0,0,8.6625,S,\n',
#  '1,2,female,7.0,0,2,26.25,S,\n',
#  '0,1,male,45.0,0,0,26.55,S,B\n',
#  '1,1,female,30.0,0,0,106.425,C,\n',
#  '0,3,male,,0,0,14.5,S,\n',
#  '1,1,female,22.0,0,2,49.5,C,B\n',
#  '1,1,female,36.0,0,2,71.0,S,B\n',
#  '0,3,female,9.0,4,2,31.275,S,\n',
#  '0,3,female,11.0,4,2,31.275,S,\n',
#  '1,2,male,32.0,1,0,26.0,S,\n',
#  '0,1,male,50.0,1,0,106.425,C,C\n',
#  '0,1,male,64.0,0,0,26.0,S,\n',
#  '1,2,female,19.0,1,0,26.0,S,\n',
#  '1,2,male,,0,0,13.8625,C,\n',
#  '0,3,male,33.0,1,1,20.525,S,\n',
#  '1,2,male,8.0,1,1,36.75,S,\n',
#  '1,1,male,17.0,0,2,110.8833,C,C\n',
#  '0,2,male,27.0,0,0,26.0,S,\n',
#  '0,3,male,,0,0,7.8292,Q,\n',
#  '1,3,male,22.0,0,0,7.225,C,\n',
#  '1,3,female,22.0,0,0,7.775,S,\n',
#  '0,1,male,62.0,0,0,26.55,S,\n',
#  '1,1,female,48.0,1,0,39.6,C,A\n',
#  '0,1,male,,0,0,227.525,C,\n',
#  '1,1,female,39.0,1,1,79.65,S,E\n',
#  '1,3,female,36.0,1,0,17.4,S,\n',
#  '0,3,male,,0,0,7.75,Q,\n',
#  '0,3,male,40.0,0,0,7.8958,S,\n',
#  '0,2,male,28.0,0,0,13.5,S,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '0,3,female,,0,0,8.05,S,\n',
#  '0,3,male,24.0,2,0,24.15,S,\n',
#  '0,3,male,19.0,0,0,7.8958,S,\n',
#  '0,3,female,29.0,0,4,21.075,S,\n',
#  '0,3,male,,0,0,7.2292,C,\n',
#  '1,3,male,32.0,0,0,7.8542,S,\n',
#  '1,2,male,62.0,0,0,10.5,S,\n',
#  '1,1,female,53.0,2,0,51.4792,S,C\n',
#  '1,1,male,36.0,0,0,26.3875,S,E\n',
#  '1,3,female,,0,0,7.75,Q,\n',
#  '0,3,male,16.0,0,0,8.05,S,\n',
#  '0,3,male,19.0,0,0,14.5,S,\n',
#  '1,2,female,34.0,0,0,13.0,S,\n',
#  '1,1,female,39.0,1,0,55.9,S,E\n',
#  '0,3,female,,1,0,14.4583,C,\n',
#  '1,3,male,32.0,0,0,7.925,S,\n',
#  '1,2,female,25.0,1,1,30.0,S,\n',
#  '1,1,female,39.0,1,1,110.8833,C,C\n',
#  '0,2,male,54.0,0,0,26.0,S,\n',
#  '0,1,male,36.0,0,0,40.125,C,A\n',
#  '0,3,male,,0,0,8.7125,C,\n',
#  '1,1,female,18.0,0,2,79.65,S,E\n',
#  '0,2,male,47.0,0,0,15.0,S,\n',
#  '1,1,male,60.0,1,1,79.2,C,B\n',
#  '0,3,male,22.0,0,0,8.05,S,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '0,3,male,35.0,0,0,7.125,S,\n',
#  '1,1,female,52.0,1,0,78.2667,C,D\n',
#  '0,3,male,47.0,0,0,7.25,S,\n',
#  '0,3,female,,0,2,7.75,Q,\n',
#  '0,2,male,37.0,1,0,26.0,S,\n',
#  '0,3,male,36.0,1,1,24.15,S,\n',
#  '1,2,female,,0,0,33.0,S,\n',
#  '0,3,male,49.0,0,0,0.0,S,\n',
#  '0,3,male,,0,0,7.225,C,\n',
#  '1,1,male,49.0,1,0,56.9292,C,A\n',
#  '1,2,female,24.0,2,1,27.0,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '0,1,male,,0,0,42.4,S,\n',
#  '0,3,male,44.0,0,0,8.05,S,\n',
#  '1,1,male,35.0,0,0,26.55,C,\n',
#  '0,3,male,36.0,1,0,15.55,S,\n',
#  '0,3,male,30.0,0,0,7.8958,S,\n',
#  '1,1,male,27.0,0,0,30.5,S,\n',
#  '1,2,female,22.0,1,2,41.5792,C,\n',
#  '1,1,female,40.0,0,0,153.4625,S,C\n',
#  '0,3,female,39.0,1,5,31.275,S,\n',
#  '0,3,male,,0,0,7.05,S,\n',
#  '1,3,female,,1,0,15.5,Q,\n',
#  '0,3,male,,0,0,7.75,Q,\n',
#  '0,3,male,35.0,0,0,8.05,S,\n',
#  '1,2,female,24.0,1,2,65.0,S,\n',
#  '0,3,male,34.0,1,1,14.4,S,\n',
#  '0,3,female,26.0,1,0,16.1,S,\n',
#  '1,2,female,4.0,2,1,39.0,S,F\n',
#  '0,2,male,26.0,0,0,10.5,S,\n',
#  '0,3,male,27.0,1,0,14.4542,C,\n',
#  '1,1,male,42.0,1,0,52.5542,S,D\n',
#  '1,3,male,20.0,1,1,15.7417,C,\n',
#  '0,3,male,21.0,0,0,7.8542,S,\n',
#  '0,3,male,21.0,0,0,16.1,S,\n',
#  '0,1,male,61.0,0,0,32.3208,S,D\n',
#  '0,2,male,57.0,0,0,12.35,Q,\n',
#  '1,1,female,21.0,0,0,77.9583,S,D\n',
#  '0,3,male,26.0,0,0,7.8958,S,\n',
#  '0,3,male,,0,0,7.7333,Q,\n',
#  '1,1,male,80.0,0,0,30.0,S,A\n',
#  '0,3,male,51.0,0,0,7.0542,S,\n',
#  '1,1,male,32.0,0,0,30.5,C,B\n',
#  '0,1,male,,0,0,0.0,S,\n',
#  '0,3,female,9.0,3,2,27.9,S,\n',
#  '1,2,female,28.0,0,0,13.0,S,\n',
#  '0,3,male,32.0,0,0,7.925,S,\n',
#  '0,2,male,31.0,1,1,26.25,S,\n',
#  '0,3,female,41.0,0,5,39.6875,S,\n',
#  '0,3,male,,1,0,16.1,S,\n',
#  '0,3,male,20.0,0,0,7.8542,S,\n',
#  '1,1,female,24.0,0,0,69.3,C,B\n',
#  '0,3,female,2.0,3,2,27.9,S,\n',
#  '1,3,male,,0,0,56.4958,S,\n',
#  '1,3,female,0.75,2,1,19.2583,C,\n',
#  '1,1,male,48.0,1,0,76.7292,C,D\n',
#  '0,3,male,19.0,0,0,7.8958,S,\n',
#  '1,1,male,56.0,0,0,35.5,C,A\n',
#  '0,3,male,,0,0,7.55,S,\n',
#  '1,3,female,23.0,0,0,7.55,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '1,2,female,18.0,0,1,23.0,S,\n',
#  '0,3,male,21.0,0,0,8.4333,S,\n',
#  '1,3,female,,0,0,7.8292,Q,\n',
#  '0,3,female,18.0,0,0,6.75,Q,\n',
#  '0,2,male,24.0,2,0,73.5,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '0,3,female,32.0,1,1,15.5,Q,\n',
#  '0,2,male,23.0,0,0,13.0,S,\n',
#  '0,1,male,58.0,0,2,113.275,C,D\n',
#  '1,1,male,50.0,2,0,133.65,S,\n',
#  '0,3,male,40.0,0,0,7.225,C,\n',
#  '0,1,male,47.0,0,0,25.5875,S,E\n',
#  '0,3,male,36.0,0,0,7.4958,S,\n',
#  '1,3,male,20.0,1,0,7.925,S,\n',
#  '0,2,male,32.0,2,0,73.5,S,\n',
#  '0,2,male,25.0,0,0,13.0,S,\n',
#  '0,3,male,,0,0,7.775,S,\n',
#  '0,3,male,43.0,0,0,8.05,S,\n',
#  '1,1,female,,1,0,52.0,S,C\n',
#  '1,2,female,40.0,1,1,39.0,S,\n',
#  '0,1,male,31.0,1,0,52.0,S,B\n',
#  '0,2,male,70.0,0,0,10.5,S,\n',
#  '1,2,male,31.0,0,0,13.0,S,\n',
#  '0,2,male,,0,0,0.0,S,\n',
#  '0,3,male,18.0,0,0,7.775,S,\n',
#  '0,3,male,24.5,0,0,8.05,S,\n',
#  '1,3,female,18.0,0,0,9.8417,S,\n',
#  '0,3,female,43.0,1,6,46.9,S,\n',
#  '1,1,male,36.0,0,1,512.3292,C,B\n',
#  '0,3,female,,0,0,8.1375,Q,\n',
#  '1,1,male,27.0,0,0,76.7292,C,D\n',
#  '0,3,male,20.0,0,0,9.225,S,\n',
#  '0,3,male,14.0,5,2,46.9,S,\n',
#  '0,2,male,60.0,1,1,39.0,S,\n',
#  '0,2,male,25.0,1,2,41.5792,C,\n',
#  '0,3,male,14.0,4,1,39.6875,S,\n',
#  '0,3,male,19.0,0,0,10.1708,S,\n',
#  '0,3,male,18.0,0,0,7.7958,S,\n',
#  '1,1,female,15.0,0,1,211.3375,S,B\n',
#  '1,1,male,31.0,1,0,57.0,S,B\n',
#  '1,3,female,4.0,0,1,13.4167,C,\n',
#  '1,3,male,,0,0,56.4958,S,\n',
#  '0,3,male,25.0,0,0,7.225,C,\n',
#  '0,1,male,60.0,0,0,26.55,S,\n',
#  '0,2,male,52.0,0,0,13.5,S,\n',
#  '0,3,male,44.0,0,0,8.05,S,\n',
#  '1,3,female,,0,0,7.7333,Q,\n',
#  '0,1,male,49.0,1,1,110.8833,C,C\n',
#  '0,3,male,42.0,0,0,7.65,S,F\n',
#  '1,1,female,18.0,1,0,227.525,C,C\n',
#  '1,1,male,35.0,0,0,26.2875,S,E\n',
#  '0,3,female,18.0,0,1,14.4542,C,\n',
#  '0,3,male,25.0,0,0,7.7417,Q,\n',
#  '0,3,male,26.0,1,0,7.8542,S,\n',
#  '0,2,male,39.0,0,0,26.0,S,\n',
#  '1,2,female,45.0,0,0,13.5,S,\n',
#  '1,1,male,42.0,0,0,26.2875,S,E\n',
#  '1,1,female,22.0,0,0,151.55,S,\n',
#  '1,3,male,,1,1,15.2458,C,\n',
#  '1,1,female,24.0,0,0,49.5042,C,C\n',
#  '0,1,male,,0,0,26.55,S,C\n',
#  '1,1,male,48.0,1,0,52.0,S,C\n',
#  '0,3,male,29.0,0,0,9.4833,S,\n',
#  '0,2,male,52.0,0,0,13.0,S,\n',
#  '0,3,male,19.0,0,0,7.65,S,F\n',
#  '1,1,female,38.0,0,0,227.525,C,C\n',
#  '1,2,female,27.0,0,0,10.5,S,E\n',
#  '0,3,male,,0,0,15.5,Q,\n',
#  '0,3,male,33.0,0,0,7.775,S,\n',
#  '1,2,female,6.0,0,1,33.0,S,\n',
#  '0,3,male,17.0,1,0,7.0542,S,\n',
#  '0,2,male,34.0,0,0,13.0,S,\n',
#  '0,2,male,50.0,0,0,13.0,S,\n',
#  '1,1,male,27.0,1,0,53.1,S,E\n',
#  '0,3,male,20.0,0,0,8.6625,S,\n',
#  '1,2,female,30.0,3,0,21.0,S,\n',
#  '1,3,female,,0,0,7.7375,Q,\n',
#  '0,2,male,25.0,1,0,26.0,S,\n',
#  '0,3,female,25.0,1,0,7.925,S,\n',
#  '1,1,female,29.0,0,0,211.3375,S,B\n',
#  '0,3,male,11.0,0,0,18.7875,C,\n',
#  '0,2,male,,0,0,0.0,S,\n',
#  '0,2,male,23.0,0,0,13.0,S,\n',
#  '0,2,male,23.0,0,0,13.0,S,\n',
#  '0,3,male,28.5,0,0,16.1,S,\n',
#  '0,3,female,48.0,1,3,34.375,S,\n',
#  '1,1,male,35.0,0,0,512.3292,C,B\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '1,1,male,,0,0,30.0,S,D\n',
#  '0,1,male,36.0,1,0,78.85,S,C\n',
#  '1,1,female,21.0,2,2,262.375,C,B\n',
#  '0,3,male,24.0,1,0,16.1,S,\n',
#  '1,3,male,31.0,0,0,7.925,S,\n',
#  '0,1,male,70.0,1,1,71.0,S,B\n',
#  '0,3,male,16.0,1,1,20.25,S,\n',
#  '1,2,female,30.0,0,0,13.0,S,\n',
#  '0,1,male,19.0,1,0,53.1,S,D\n',
#  '0,3,male,31.0,0,0,7.75,Q,\n',
#  '1,2,female,4.0,1,1,23.0,S,\n',
#  '1,3,male,6.0,0,1,12.475,S,E\n',
#  '0,3,male,33.0,0,0,9.5,S,\n',
#  '0,3,male,23.0,0,0,7.8958,S,\n',
#  '1,2,female,48.0,1,2,65.0,S,\n',
#  '1,2,male,0.67,1,1,14.5,S,\n',
#  '0,3,male,28.0,0,0,7.7958,S,\n',
#  '0,2,male,18.0,0,0,11.5,S,\n',
#  '0,3,male,34.0,0,0,8.05,S,\n',
#  '1,1,female,33.0,0,0,86.5,S,B\n',
#  '0,3,male,,0,0,14.5,S,\n',
#  '0,3,male,41.0,0,0,7.125,S,\n',
#  '1,3,male,20.0,0,0,7.2292,C,\n',
#  '1,1,female,36.0,1,2,120.0,S,B\n',
#  '0,3,male,16.0,0,0,7.775,S,\n',
#  '1,1,female,51.0,1,0,77.9583,S,D\n',
#  '0,1,male,,0,0,39.6,C,\n',
#  '0,3,female,30.5,0,0,7.75,Q,\n',
#  '0,3,male,,1,0,24.15,Q,\n',
#  '0,3,male,32.0,0,0,8.3625,S,\n',
#  '0,3,male,24.0,0,0,9.5,S,\n',
#  '0,3,male,48.0,0,0,7.8542,S,\n',
#  '0,2,female,57.0,0,0,10.5,S,E\n',
#  '0,3,male,,0,0,7.225,C,\n',
#  '1,2,female,54.0,1,3,23.0,S,\n',
#  '0,3,male,18.0,0,0,7.75,S,\n',
#  '0,3,male,,0,0,7.75,Q,F\n',
#  '1,3,female,5.0,0,0,12.475,S,\n',
#  '0,3,male,,0,0,7.7375,Q,\n',
#  '1,1,female,43.0,0,1,211.3375,S,B\n',
#  '1,3,female,13.0,0,0,7.2292,C,\n',
#  '1,1,female,17.0,1,0,57.0,S,B\n',
#  '0,1,male,29.0,0,0,30.0,S,D\n',
#  '0,3,male,,1,2,23.45,S,\n',
#  '0,3,male,25.0,0,0,7.05,S,\n',
#  '0,3,male,25.0,0,0,7.25,S,\n',
#  '1,3,female,18.0,0,0,7.4958,S,\n',
#  '0,3,male,8.0,4,1,29.125,Q,\n',
#  '1,3,male,1.0,1,2,20.575,S,\n',
#  '0,1,male,46.0,0,0,79.2,C,B\n',
#  '0,3,male,,0,0,7.75,Q,\n',
#  '0,2,male,16.0,0,0,26.0,S,\n',
#  '0,3,female,,8,2,69.55,S,\n',
#  '0,1,male,,0,0,30.6958,C,\n',
#  '0,3,male,25.0,0,0,7.8958,S,\n',
#  '0,2,male,39.0,0,0,13.0,S,\n',
#  '1,1,female,49.0,0,0,25.9292,S,D\n',
#  '1,3,female,31.0,0,0,8.6833,S,\n',
#  '0,3,male,30.0,0,0,7.2292,C,\n',
#  '0,3,female,30.0,1,1,24.15,S,\n',
#  '0,2,male,34.0,0,0,13.0,S,\n',
#  '1,2,female,31.0,1,1,26.25,S,\n',
#  '1,1,male,11.0,1,2,120.0,S,B\n',
#  '1,3,male,0.42,0,1,8.5167,C,\n',
#  '1,3,male,27.0,0,0,6.975,S,\n',
#  '0,3,male,31.0,0,0,7.775,S,\n',
#  '0,1,male,39.0,0,0,0.0,S,A\n',
#  '0,3,female,18.0,0,0,7.775,S,\n',
#  '0,2,male,39.0,0,0,13.0,S,\n',
#  '1,1,female,33.0,1,0,53.1,S,E\n',
#  '0,3,male,26.0,0,0,7.8875,S,\n',
#  '0,3,male,39.0,0,0,24.15,S,\n',
#  '0,2,male,35.0,0,0,10.5,S,\n',
#  '0,3,female,6.0,4,2,31.275,S,\n',
#  '0,3,male,30.5,0,0,8.05,S,\n',
#  '0,1,male,,0,0,0.0,S,B\n',
#  '0,3,female,23.0,0,0,7.925,S,\n',
#  '0,2,male,31.0,1,1,37.0042,C,\n',
#  '0,3,male,43.0,0,0,6.45,S,\n',
#  '0,3,male,10.0,3,2,27.9,S,\n',
#  '1,1,female,52.0,1,1,93.5,S,B\n',
#  '1,3,male,27.0,0,0,8.6625,S,\n',
#  '0,1,male,38.0,0,0,0.0,S,\n',
#  '1,3,female,27.0,0,1,12.475,S,E\n',
#  '0,3,male,2.0,4,1,39.6875,S,\n',
#  '0,3,male,,0,0,6.95,Q,\n',
#  '0,3,male,,0,0,56.4958,S,\n',
#  '1,2,male,1.0,0,2,37.0042,C,\n',
#  '1,3,male,,0,0,7.75,Q,\n',
#  '1,1,female,62.0,0,0,80.0,,B\n',
#  '1,3,female,15.0,1,0,14.4542,C,\n',
#  '1,2,male,0.83,1,1,18.75,S,\n',
#  '0,3,male,,0,0,7.2292,C,\n',
#  '0,3,male,23.0,0,0,7.8542,S,\n',
#  '0,3,male,18.0,0,0,8.3,S,\n',
#  '1,1,female,39.0,1,1,83.1583,C,E\n',
#  '0,3,male,21.0,0,0,8.6625,S,\n',
#  '0,3,male,,0,0,8.05,S,\n',
#  '1,3,male,32.0,0,0,56.4958,S,\n',
#  '1,1,male,,0,0,29.7,C,C\n',
#  '0,3,male,20.0,0,0,7.925,S,\n',
#  '0,2,male,16.0,0,0,10.5,S,\n',
#  '1,1,female,30.0,0,0,31.0,C,\n',
#  '0,3,male,34.5,0,0,6.4375,C,\n',
#  '0,3,male,17.0,0,0,8.6625,S,\n',
#  '0,3,male,42.0,0,0,7.55,S,\n',
#  '0,3,male,,8,2,69.55,S,\n',
#  '0,3,male,35.0,0,0,7.8958,C,\n',
#  '0,2,male,28.0,0,1,33.0,S,\n',
#  '1,1,female,,1,0,89.1042,C,C\n',
#  '0,3,male,4.0,4,2,31.275,S,\n',
#  '0,3,male,74.0,0,0,7.775,S,\n',
#  '0,3,female,9.0,1,1,15.2458,C,\n',
#  '1,1,female,16.0,0,1,39.4,S,D\n',
#  '0,2,female,44.0,1,0,26.0,S,\n',
#  '1,3,female,18.0,0,1,9.35,S,\n',
#  '1,1,female,45.0,1,1,164.8667,S,\n',
#  '1,1,male,51.0,0,0,26.55,S,E\n',
#  '1,3,female,24.0,0,3,19.2583,C,\n',
#  '0,3,male,,0,0,7.2292,C,\n',
#  '0,3,male,41.0,2,0,14.1083,S,\n',
#  '0,2,male,21.0,1,0,11.5,S,\n',
#  '1,1,female,48.0,0,0,25.9292,S,D\n',
#  '0,3,female,,8,2,69.55,S,\n',
#  '0,2,male,24.0,0,0,13.0,S,\n',
#  '1,2,female,42.0,0,0,13.0,S,\n',
#  '1,2,female,27.0,1,0,13.8583,C,\n',
#  '0,1,male,31.0,0,0,50.4958,S,A\n',
#  '0,3,male,,0,0,9.5,S,\n',
#  '1,3,male,4.0,1,1,11.1333,S,\n',
#  '0,3,male,26.0,0,0,7.8958,S,\n',
#  '1,1,female,47.0,1,1,52.5542,S,D\n',
#  '0,1,male,33.0,0,0,5.0,S,B\n',
#  '0,3,male,47.0,0,0,9.0,S,\n',
#  '1,2,female,28.0,1,0,24.0,C,\n',
#  '1,3,female,15.0,0,0,7.225,C,\n',
#  '0,3,male,20.0,0,0,9.8458,S,\n',
#  '0,3,male,19.0,0,0,7.8958,S,\n',
#  '0,3,male,,0,0,7.8958,S,\n',
#  '1,1,female,56.0,0,1,83.1583,C,C\n',
#  '1,2,female,25.0,0,1,26.0,S,\n',
#  '0,3,male,33.0,0,0,7.8958,S,\n',
#  '0,3,female,22.0,0,0,10.5167,S,\n',
#  '0,2,male,28.0,0,0,10.5,S,\n',
#  '0,3,male,25.0,0,0,7.05,S,\n',
#  '0,3,female,39.0,0,5,29.125,Q,\n',
#  '0,2,male,27.0,0,0,13.0,S,\n',
#  '1,1,female,19.0,0,0,30.0,S,B\n',
#  '0,3,female,,1,2,23.45,S,\n',
#  '1,1,male,26.0,0,0,30.0,C,C\n',
#  '0,3,male,32.0,0,0,7.75,Q,\n']

# %%
f.close()

# %%
with open('titanic.csv','r') as f:
    text = f.readlines()

# %%
len(text)
# Out:
# 892

# %%
titanic = pd.read_csv('titanic.csv',header = 0, names =)

# %%
pd.read_csv('titanic.csv', usecols = ['survived'],engine = 'python')
# Out:
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
import pandas as pd

# %%
sales = pd.read_excel("sales.xls", index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 sales = pd.read_excel("sales.xls", index_col = 0)
#
# File c:\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File c:\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File c:\anaconda3\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sales.xls'

# %%
import pandas as pd

# %%
sales = pd.read_excel("sales.xls", index_col = 0)

# %%
sales
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25   2.50
# Jim       Boston     USA     43   4.30
# Steven    London      UK     76   7.60
# Joe       Madrid   Spain     12   1.80
# Tom        Paris  France     89  13.35

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Mike to Tom
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     5 non-null      object
#  1   Country  5 non-null      object
#  2   Sales    5 non-null      int64
#  3   Bonus    5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
sales.describe()
# Out:
#            Sales      Bonus
# count   5.000000   5.000000
# mean   49.000000   5.910000
# std    32.825295   4.725516
# min    12.000000   1.800000
# 25%    25.000000   2.500000
# 50%    43.000000   4.300000
# 75%    76.000000   7.600000
# max    89.000000  13.350000

# %%
url = "https://en.wikipedia.org/wiki/1976_Summer_Olympics_medal_table"

# %%
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 pd.read_html(url)
#
# File c:\anaconda3\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File c:\anaconda3\Lib\site-packages\pandas\io\html.py:983, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     972 p = parser(
#     973     io,
#     974     compiled_match,
#    (...)
#     979     storage_options,
#     980 )
#     982 try:
# --> 983     tables = p.parse_tables()
#     984 except ValueError as caught:
#     985     # if `io` is an io-like object, check if it's seekable
#     986     # and try to rewind it before trying the next parser
#     987     if hasattr(io, "seekable") and io.seekable():
#
# File c:\anaconda3\Lib\site-packages\pandas\io\html.py:249, in _HtmlFrameParser.parse_tables(self)
#     241 def parse_tables(self):
#     242     """
#     243     Parse and return all tables from the DOM.
#     244
#    (...)
#     247     list of parsed (header, body, footer) tuples from tables.
#     248     """
# --> 249     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     250     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File c:\anaconda3\Lib\site-packages\pandas\io\html.py:806, in _LxmlFrameParser._build_doc(self)
#     804             pass
#     805     else:
# --> 806         raise e
#     807 else:
#     808     if not hasattr(r, "text_content"):
#
# File c:\anaconda3\Lib\site-packages\pandas\io\html.py:785, in _LxmlFrameParser._build_doc(self)
#     783 try:
#     784     if is_url(self.io):
# --> 785         with get_handle(
#     786             self.io, "r", storage_options=self.storage_options
#     787         ) as f:
#     788             r = parse(f.handle, parser=parser)
#     789     else:
#     790         # try to parse the input in the simplest way
#
# File c:\anaconda3\Lib\site-packages\pandas\io\common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     725     codecs.lookup_error(errors)
#     727 # open URLs
# --> 728 ioargs = _get_filepath_or_buffer(
#     729     path_or_buf,
#     730     encoding=encoding,
#     731     compression=compression,
#     732     mode=mode,
#     733     storage_options=storage_options,
#     734 )
#     736 handle = ioargs.filepath_or_buffer
#     737 handles: list[BaseBuffer]
#
# File c:\anaconda3\Lib\site-packages\pandas\io\common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382 # assuming storage_options is to be interpreted as headers
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384 with urlopen(req_info) as req:
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#     386     if content_encoding == "gzip":
#     387         # Override compression based on Content-Encoding header
#
# File c:\anaconda3\Lib\site-packages\pandas\io\common.py:289, in urlopen(*args, **kwargs)
#     283 """
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     285 the stdlib.
#     286 """
#     287 import urllib.request
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\anaconda3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File c:\anaconda3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File c:\anaconda3\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File c:\anaconda3\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File c:\anaconda3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File c:\anaconda3\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
#Cleaning Data

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.sibsp.value_counts()
# Out:
# sibsp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
titanic.parch.value_counts()
# Out:
# parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
titanic.describe(include = 'O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
titanic.loc[:, 'survived'].replace({0: 'No', 1: 'Yes'}, inplace = True)
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_32072\2128642356.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic.loc[:, 'survived'].replace({0: 'No', 1: 'Yes'}, inplace = True)

# %%
titanic
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         No       3    male  22.0      1      0   7.2500        S  NaN
# 1        Yes       1  female  38.0      1      0  71.2833        C    C
# 2        Yes       3  female  26.0      0      0   7.9250        S  NaN
# 3        Yes       1  female  35.0      1      0  53.1000        S    C
# 4         No       3    male  35.0      0      0   8.0500        S  NaN
# ..       ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886       No       2    male  27.0      0      0  13.0000        S  NaN
# 887      Yes       1  female  19.0      0      0  30.0000        S    B
# 888       No       3  female   NaN      1      2  23.4500        S  NaN
# 889      Yes       1    male  26.0      0      0  30.0000        C    C
# 890       No       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
summer = pd.read_csv('summer_imp.csv')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender                       Event  \
# 0                   HAJOS, Alfred      HUN    Men              100M Freestyle
# 1                HERSCHMANN, Otto      AUT    Men              100M Freestyle
# 2               DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors
# 3              Malokinis, Ioannis      GRE    Men  100M Freestyle For Sailors
# 4              Chasapis, Spiridon      GRE    Men  100M Freestyle For Sailors
# ...                            ...     ...    ...                         ...
# 31165          JANIKOWSKI, Damian      POL    Men                    Wg 84 KG
# 31166   REZAEI, Ghasem Gholamreza      IRI    Men                    Wg 96 KG
# 31167              TOTROV, Rustam      RUS    Men                    Wg 96 KG
# 31168           ALEKSANYAN, Artur      ARM    Men                    Wg 96 KG
# 31169              LIDBERG, Jimmy      SWE    Men                    Wg 96 KG
#
#             Medal
# 0      Gold Medal
# 1          Silver
# 2          Bronze
# 3      Gold Medal
# 4          Silver
# ...           ...
# 31165      Bronze
# 31166        Gold
# 31167      Silver
# 31168      Bronze
# 31169      Bronze
#
# [31170 rows x 9 columns]

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31170 non-null  int64
#  1   City          31170 non-null  object
#  2   Sport         31170 non-null  object
#  3   Discipline    31170 non-null  object
#  4   Athlete Name  31170 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31170 non-null  object
#  7   Event         31170 non-null  object
#  8   Medal         31170 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.index
# Out:
# RangeIndex(start=0, stop=31170, step=1)

# %%
summer.Medal.value_counts()
# Out:
# Medal
# Gold          10483
# Bronze        10372
# Silver        10311
# Gold Medal        4
# Name: count, dtype: int64

# %%
for i in summer.columns:
    print(summer[i].value_counts())
# Out:
# Year
# 2008    2043
# 2000    2015
# 2004    1998
# 2012    1949
# 1996    1860
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1388
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1032
# 1964    1010
# 1952     889
# 1912     886
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: count, dtype: int64
# City
# London                   3567
# Athens                   2149
# Los Angeles              2074
# Beijing                  2043
# Sydney                   2015
# Atlanta                  1860
# Barcelona                1705
# Seoul                    1546
# Paris                    1396
# Moscow                   1388
# Montreal                 1305
# Antwerp                  1298
# Munich                   1185
# Mexico                   1032
# Tokyo                    1010
# Helsinki                  889
# Stockholm                 886
# Melbourne / Stockholm     885
# Rome                      882
# Berlin                    875
# Amsterdam                 710
# St Louis                  470
# Name: count, dtype: int64
# Sport
# Aquatics             4170
# Athletics            3639
# Rowing               2668
# Gymnastics           2307
# Fencing              1614
# Football             1497
# Hockey               1422
# Wrestling            1212
# Shooting             1150
# Sailing              1109
# Cycling              1105
# Basketball           1012
# Canoe / Kayak        1002
# Volleyball            994
# Handball              973
# Equestrian            939
# Boxing                895
# Weightlifting         593
# Judo                  491
# Baseball              336
# Archery               329
# Tennis                296
# Rugby                 192
# Softball              180
# Modern Pentathlon     180
# Badminton             144
# Table Tennis          144
# Taekwondo             112
# Tug of War             94
# Canoe                  81
# Polo                   66
# Lacrosse               59
# Golf                   30
# Skating                27
# Ice Hockey             27
# Cricket                24
# Triathlon              24
# Rackets                10
# Croquet                 8
# Water Motorsports       5
# Basque Pelota           4
# Jeu de paume            3
# Roque                   3
# Name: count, dtype: int64
# Discipline
# Athletics          3639
# Rowing             2668
# Swimming           2628
# Artistic G.        2103
# Fencing            1614
#                    ...
# Cycling BMX           6
# Water Motorspor       5
# Basque Pelota         4
# Jeu de Paume          3
# Roque                 3
# Name: count, Length: 67, dtype: int64
# Athlete Name
# PHELPS, Michael           22
# LATYNINA, Larisa          18
# ANDRIANOV, Nikolay        15
# MANGIAROTTI, Edoardo      13
# SHAKHLIN, Boris           13
#                           ..
# ZAKA, Uddin                1
# ZAFAR, Hayat               1
# MUHAMMAD, Rashid           1
# MANNA, Muhammad Afzal      1
# LIDBERG, Jimmy             1
# Name: count, Length: 22763, dtype: int64
# Country
# USA    4586
# URS    2049
# GBR    1720
# FRA    1397
# GER    1305
#        ...
# CIV       1
# BDI       1
# SEN       1
# DJI       1
# GAB       1
# Name: count, Length: 147, dtype: int64
# Gender
# Men      22751
# Women     8419
# Name: count, dtype: int64
# Event
# Football                   1497
# Hockey                     1422
# Team Competition           1147
# Basketball                 1012
# Handball                    973
#                            ...
# Moving Bird Target, 33M       2
# Class B Up To 60 Feet         2
# - 47.63KG (Flyweight)         2
# Moving Bird Target, 50M       2
# Open Class A                  1
# Name: count, Length: 666, dtype: int64
# Medal
# Gold          10483
# Bronze        10372
# Silver        10311
# Gold Medal        4
# Name: count, dtype: int64

# %%
summer.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'Country',
#        'Gender', 'Event', 'Medal'],
#       dtype='object')

# %%
summer.rename(columns={'Athlete Name': 'athlete_name'}, inplace = True)

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       athlete_name Country Gender                       Event  \
# 0                   HAJOS, Alfred      HUN    Men              100M Freestyle
# 1                HERSCHMANN, Otto      AUT    Men              100M Freestyle
# 2               DRIVAS, Dimitrios      GRE    Men  100M Freestyle For Sailors
# 3              Malokinis, Ioannis      GRE    Men  100M Freestyle For Sailors
# 4              Chasapis, Spiridon      GRE    Men  100M Freestyle For Sailors
# ...                            ...     ...    ...                         ...
# 31165          JANIKOWSKI, Damian      POL    Men                    Wg 84 KG
# 31166   REZAEI, Ghasem Gholamreza      IRI    Men                    Wg 96 KG
# 31167              TOTROV, Rustam      RUS    Men                    Wg 96 KG
# 31168           ALEKSANYAN, Artur      ARM    Men                    Wg 96 KG
# 31169              LIDBERG, Jimmy      SWE    Men                    Wg 96 KG
#
#             Medal
# 0      Gold Medal
# 1          Silver
# 2          Bronze
# 3      Gold Medal
# 4          Silver
# ...           ...
# 31165      Bronze
# 31166        Gold
# 31167      Silver
# 31168      Bronze
# 31169      Bronze
#
# [31170 rows x 9 columns]

# %%
summer.Medal.value_counts()
# Out:
# Medal
# Gold      10487
# Bronze    10372
# Silver    10311
# Name: count, dtype: int64

# %%
summer.Medal.replace({'Gold Medal': 'Gold'}, inplace = True)

# %%
summer.describe(include = 'O')
# Out:
#           City     Sport Discipline       athlete_name Country Gender  \
# count    31170     31170      31170              31170   31166  31170
# unique      22        43         67              22763     147      2
# top     London  Aquatics  Athletics   PHELPS, Michael      USA    Men
# freq      3567      4170       3639                 22    4586  22751
#
#            Event  Medal
# count      31170  31170
# unique       666      3
# top     Football   Gold
# freq        1497  10487

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 62.8+ KB

# %%
titanic.Fare = titanic.Fare.str.replace('$','')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32072\3758010811.py in ?()
# ----> 1 titanic.Fare = titanic.Fare.str.replace('$','')
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Fare'

# %%
pd.read_csv('titanic_imp.csv')
# Out:
#     Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0          0      3    male  22.0      1      0     $7.25   S  NaN
# 1          1      1  female  38.0      1      0  $71.2833   C    C
# 2          1      3  female  26.0      0      0    $7.925   S  NaN
# 3          1      1  female  35.0      1      0     $53.1   S    C
# 4          0      3    male  35.0      0      0     $8.05   S  NaN
# ..       ...    ...     ...   ...    ...    ...       ...  ..  ...
# 889        1      1    male  26.0      0      0     $30.0   C    C
# 890        0      3    male  32.0      0      0     $7.75   Q  NaN
# 891        0      2    male  24.0      0      0     $10.5   S  NaN
# 892        0      3    male  34.0      1      1     $14.4   S  NaN
# 893        0      3    male  36.0      0      0   $7.8958   S  NaN
#
# [894 rows x 9 columns]

# %%
titanic.survived.replace({0:'No', 1:'Yes'}, inplace = True )

# %%
titanic
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         No       3    male  22.0      1      0   7.2500        S  NaN
# 1        Yes       1  female  38.0      1      0  71.2833        C    C
# 2        Yes       3  female  26.0      0      0   7.9250        S  NaN
# 3        Yes       1  female  35.0      1      0  53.1000        S    C
# 4         No       3    male  35.0      0      0   8.0500        S  NaN
# ..       ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886       No       2    male  27.0      0      0  13.0000        S  NaN
# 887      Yes       1  female  19.0      0      0  30.0000        S    B
# 888       No       3  female   NaN      1      2  23.4500        S  NaN
# 889      Yes       1    male  26.0      0      0  30.0000        C    C
# 890       No       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.fare.replace({'$':''}, inplace = True)
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_32072\3851408766.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic.fare.replace({'$':''}, inplace = True)

# %%
titanic
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         No       3    male  22.0      1      0   7.2500        S  NaN
# 1        Yes       1  female  38.0      1      0  71.2833        C    C
# 2        Yes       3  female  26.0      0      0   7.9250        S  NaN
# 3        Yes       1  female  35.0      1      0  53.1000        S    C
# 4         No       3    male  35.0      0      0   8.0500        S  NaN
# ..       ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886       No       2    male  27.0      0      0  13.0000        S  NaN
# 887      Yes       1  female  19.0      0      0  30.0000        S    B
# 888       No       3  female   NaN      1      2  23.4500        S  NaN
# 889      Yes       1    male  26.0      0      0  30.0000        C    C
# 890       No       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 62.8+ KB

# %%
titanic.fare.to_numeric()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32072\1515723146.py in ?()
# ----> 1 titanic.fare.to_numeric()
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_numeric'

# %%
pd.to_numeric(titanic.fare, errors = 'raise')
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
pd.to_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 pd.to_object(titanic.fare, errors = 'raise')
#
# AttributeError: module 'pandas' has no attribute 'to_object'

# %%
summer.loc[:,'athlete_name'] = summer.athlete_name.str.title()

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       athlete_name Country Gender                       Event  \
# 0                   Hajos, Alfred      HUN    Men              100M Freestyle
# 1                Herschmann, Otto      AUT    Men              100M Freestyle
# 2               Drivas, Dimitrios      GRE    Men  100M Freestyle For Sailors
# 3              Malokinis, Ioannis      GRE    Men  100M Freestyle For Sailors
# 4              Chasapis, Spiridon      GRE    Men  100M Freestyle For Sailors
# ...                            ...     ...    ...                         ...
# 31165          Janikowski, Damian      POL    Men                    Wg 84 KG
# 31166   Rezaei, Ghasem Gholamreza      IRI    Men                    Wg 96 KG
# 31167              Totrov, Rustam      RUS    Men                    Wg 96 KG
# 31168           Aleksanyan, Artur      ARM    Men                    Wg 96 KG
# 31169              Lidberg, Jimmy      SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31165  Bronze
# 31166    Gold
# 31167  Silver
# 31168  Bronze
# 31169  Bronze
#
# [31170 rows x 9 columns]

# %%
titanic
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         No       3    male  22.0      1      0   7.2500        S  NaN
# 1        Yes       1  female  38.0      1      0  71.2833        C    C
# 2        Yes       3  female  26.0      0      0   7.9250        S  NaN
# 3        Yes       1  female  35.0      1      0  53.1000        S    C
# 4         No       3    male  35.0      0      0   8.0500        S  NaN
# ..       ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886       No       2    male  27.0      0      0  13.0000        S  NaN
# 887      Yes       1  female  19.0      0      0  30.0000        S    B
# 888       No       3  female   NaN      1      2  23.4500        S  NaN
# 889      Yes       1    male  26.0      0      0  30.0000        C    C
# 890       No       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       athlete_name Country Gender                       Event  \
# 0                   Hajos, Alfred      HUN    Men              100M Freestyle
# 1                Herschmann, Otto      AUT    Men              100M Freestyle
# 2               Drivas, Dimitrios      GRE    Men  100M Freestyle For Sailors
# 3              Malokinis, Ioannis      GRE    Men  100M Freestyle For Sailors
# 4              Chasapis, Spiridon      GRE    Men  100M Freestyle For Sailors
# ...                            ...     ...    ...                         ...
# 31165          Janikowski, Damian      POL    Men                    Wg 84 KG
# 31166   Rezaei, Ghasem Gholamreza      IRI    Men                    Wg 96 KG
# 31167              Totrov, Rustam      RUS    Men                    Wg 96 KG
# 31168           Aleksanyan, Artur      ARM    Men                    Wg 96 KG
# 31169              Lidberg, Jimmy      SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31165  Bronze
# 31166    Gold
# 31167  Silver
# 31168  Bronze
# 31169  Bronze
#
# [31170 rows x 9 columns]

# %%
summer.Medal.value_counts()
# Out:
# Medal
# Gold      10487
# Bronze    10372
# Silver    10311
# Name: count, dtype: int64

# %%
summer.Medal.str.contains('Gold').value_counts()
# Out:
# Medal
# False    20683
# True     10487
# Name: count, dtype: int64

# %%
summer.loc[summer.loc[:,'athlete_name'].str.contains('Hajos')]
# Out:
#    Year    City     Sport Discipline     athlete_name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
# 6  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
summer.loc[summer.athlete_name == "Janikowski, Damian"]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, athlete_name, Country, Gender, Event, Medal]
# Index: []

# %%
summer.loc[summer.athlete_name == "Janikowski, Damian"]
# Out:
#        Year    City      Sport           Discipline        athlete_name  \
# 31165  2012  London  Wrestling  Wrestling Freestyle  Janikowski, Damian
#
#       Country Gender     Event   Medal
# 31165     POL    Men  Wg 84 KG  Bronze

# %%
summer.athlete_name = summer.athlete_name.str.strip()

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 62.8+ KB

# %%
titanic.fare = titanic.fare.astype(dtype=object)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    object
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 62.8+ KB

# %%
sales
# Out:
#             City Country  Sales  Bonus
# Mike    New York     USA     25   2.50
# Jim       Boston     USA     43   4.30
# Steven    London      UK     76   7.60
# Joe       Madrid   Spain     12   1.80
# Tom        Paris  France     89  13.35

# %%
sales = pd.read_csv('sales.csv', index_col = 0)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.loc['Steven','Thu']
# Out:
# nan

# %%
sales.loc['Mike','Tue'] = None

# %%
sales
# Out:
#         Mon   Tue  Wed   Thu   Fri
# Steven   34  27.0   15   NaN   NaN
# Mike     45   NaN   74  87.0  12.0
# Andi     17  33.0   54   8.0  29.0
# Paul     87  67.0   27  45.0   7.0

# %%
import numpy as np

# %%
sales.loc['Steven','Fri'] = np.nan

# %%
sales.isna().sum(axis = 0)
# Out:
# Mon    0
# Tue    1
# Wed    0
# Thu    1
# Fri    1
# dtype: int64

# %%
sales.notna().sum()
# Out:
# Mon    4
# Tue    3
# Wed    4
# Thu    3
# Fri    3
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (12,8))
sns.heatmap(sales.notna())
# Out:
# <Axes: >

# %%
titanic.age.value_counts(dropna = True)
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
titanic.age = titanic.age.replace(to_replace = np.nan, value = 23)
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_32072\1404440337.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   titanic.age = titanic.age.replace(to_replace = np.nan, value = 23)

# %%
titanic.age.value_counts()
# Out:
# age
# 23    891
# Name: count, dtype: int64

# %%
titanic
# Out:
#     survived  pclass     sex  age  sibsp  parch     fare embarked deck
# 0         No       3    male   23      1      0     7.25        S  NaN
# 1        Yes       1  female   23      1      0  71.2833        C    C
# 2        Yes       3  female   23      0      0    7.925        S  NaN
# 3        Yes       1  female   23      1      0     53.1        S    C
# 4         No       3    male   23      0      0     8.05        S  NaN
# ..       ...     ...     ...  ...    ...    ...      ...      ...  ...
# 886       No       2    male   23      0      0     13.0        S  NaN
# 887      Yes       1  female   23      0      0     30.0        S    B
# 888       No       3  female   23      1      2    23.45        S  NaN
# 889      Yes       1    male   23      0      0     30.0        C    C
# 890       No       3    male   23      0      0     7.75        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['sex'] = titanic['sex'].replace(to_replace = 'male', value = 'bechara')

# %%
titanic.sex.value_counts()
# Out:
# sex
# bechara    577
# female     314
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,7))
sns.histplot(titanic.sex)
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
titanic
# Out:
#     survived  pclass      sex  age  sibsp  parch     fare embarked deck
# 0         No       3  bechara   23      1      0     7.25        S  NaN
# 1        Yes       1   female   23      1      0  71.2833        C    C
# 2        Yes       3   female   23      0      0    7.925        S  NaN
# 3        Yes       1   female   23      1      0     53.1        S    C
# 4         No       3  bechara   23      0      0     8.05        S  NaN
# ..       ...     ...      ...  ...    ...    ...      ...      ...  ...
# 886       No       2  bechara   23      0      0     13.0        S  NaN
# 887      Yes       1   female   23      0      0     30.0        S    B
# 888       No       3   female   23      1      2    23.45        S  NaN
# 889      Yes       1  bechara   23      0      0     30.0        C    C
# 890       No       3  bechara   23      0      0     7.75        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.dropna(axis = 0, thresh =6 ).shape
# Out:
# (891, 9)

# %%
titanic.deck.isna().sum()
# Out:
# 688

# %%
titanic.loc[titanic.embarked.isna(),'deck'] = np.nan

# %%
titanic[(titanic.embarked.isna())].loc['deck'] = np.nan
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_32072\344216781.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   titanic[(titanic.embarked.isna())].loc['deck'] = np.nan
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_32072\344216781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic[(titanic.embarked.isna())].loc['deck'] = np.nan

# %%
titanic[(titanic.embarked.isna())]
# Out:
#     survived  pclass     sex  age  sibsp  parch  fare embarked deck
# 61       Yes       1  female   23      0      0  80.0      NaN  NaN
# 829      Yes       1  female   23      0      0  80.0      NaN  NaN

# %%
titanic.embarked.value_counts(dropna = False)
# Out:
# embarked
# S      644
# C      168
# Q       77
# NaN      2
# Name: count, dtype: int64

# %%
titanic['deck'].fillna(titanic.deck.mode()[0], inplace = True)

# %%
titanic.deck.value_counts(dropna = False)
# Out:
# deck
# deck    689
# C        60
# B        45
# D        33
# E        32
# A        15
# F        13
# G         4
# Name: count, dtype: int64

# %%
titanic.deck.mode()
# Out:
# 0    C
# Name: deck, dtype: object

# %%
alphabet = pd.DataFrame(['a','b','c','c','d','d','e'], columns = ["alphabet"])

# %%
alphabet
# Out:
#   alphabet
# 0        a
# 1        b
# 2        c
# 3        c
# 4        d
# 5        d
# 6        e

# %%
alphabet.duplicated(keep = 'first')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
alphabet.drop(alphabet.duplicated(keep = 'first'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[352], line 1
# ----> 1 alphabet.drop(alphabet.duplicated(keep = 'first'))
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: '[False, False, False, True, False, True, False] not found in axis'

# %%
titanic[titanic.duplicated(keep = 'first')].shape
# Out:
# (364, 9)

# %%
titanic
# Out:
#     survived  pclass      sex  age  sibsp  parch     fare embarked  deck
# 0         No       3  bechara   23      1      0     7.25        S     C
# 1        Yes       1   female   23      1      0  71.2833        C     C
# 2        Yes       3   female   23      0      0    7.925        S  deck
# 3        Yes       1   female   23      1      0     53.1        S     C
# 4         No       3  bechara   23      0      0     8.05        S  deck
# ..       ...     ...      ...  ...    ...    ...      ...      ...   ...
# 886       No       2  bechara   23      0      0     13.0        S  deck
# 887      Yes       1   female   23      0      0     30.0        S     B
# 888       No       3   female   23      1      2    23.45        S  deck
# 889      Yes       1  bechara   23      0      0     30.0        C     C
# 890       No       3  bechara   23      0      0     7.75        Q  deck
#
# [891 rows x 9 columns]

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic[~titanic.duplicated(keep = 'first')].shape
# Out:
# (784, 9)

# %%
titanic[titanic.duplicated(keep = 'first')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 47          1       3  female   NaN      0      0   7.7500        Q  NaN
# 76          0       3    male   NaN      0      0   7.8958        S  NaN
# 77          0       3    male   NaN      0      0   8.0500        S  NaN
# 87          0       3    male   NaN      0      0   8.0500        S  NaN
# 95          0       3    male   NaN      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 870         0       3    male  26.0      0      0   7.8958        S  NaN
# 877         0       3    male  19.0      0      0   7.8958        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
#
# [107 rows x 9 columns]

# %%
titanic.drop(index = titanic.duplicated(keep = False).index)
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, deck]
# Index: []

# %%
titanic.shape
# Out:
# (784, 9)

# %%
titanic.drop_duplicates(keep = 'last', inplace = True, ignore_index = True)

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=784, step=1)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male   NaN      0      0   8.4583        Q  NaN

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  784.000000  784.000000  678.000000  784.000000  784.000000  784.000000
# mean     0.411990    2.243622   29.869351    0.522959    0.415816   34.711740
# std      0.492507    0.855056   14.759076    0.986231    0.836922   52.160151
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    3.000000   28.250000    0.000000    0.000000   15.900000
# 75%      1.000000    3.000000   39.000000    1.000000    1.000000   34.109350
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
plt.figure(figsize = (12,8))
sns.boxplot(titanic.age)
# Out:
# <Axes: ylabel='age'>

# %%
plt.figure(figsize = (12,6))
titanic.age.plot()
# Out:
# <Axes: >

# %%
titanic[titanic.age> 70]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 77          0       1  male  71.0      0      0  34.6542        C    A
# 93          0       3  male  70.5      0      0   7.7500        Q  NaN
# 416         0       1  male  71.0      0      0  49.5042        C  NaN
# 537         1       1  male  80.0      0      0  30.0000        S    A
# 744         0       3  male  74.0      0      0   7.7750        S  NaN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.git', 'cars.csv', 'eda_ytube.ipynb', 'men2004.csv', 'men2004_det.csv', 'men2008.csv', 'men2008_det.csv', 'NB_02_Pandas_Series.ipynb', 'NB_03_Pandas_Index_Objects.ipynb', 'NB_04_DataFrame_Basics_II.ipynb', 'NB_05_Manipulating_Values_in_DataFrame.ipynb', 'NB_06_DataFrame_Basics_III.ipynb', 'NB_07_Visualization_with_Matplotlib.ipynb', 'numpy_pandas_basics_session.ipynb', 'pandas_series.ipynb', 'README.md', 'sales.csv', 'sales.xls', 'summer.csv', 'summer_2012.csv', 'summer_clean.csv', 'summer_imp.csv', 'summer_imp.xls', 'summer_raw.xls', 'table1.csv', 'table2.csv', 'table_2012.csv', 'titanic.csv', 'titanic_clean.csv', 'titanic_imp.csv', 'titanic_raw.csv', 'topfive_2004.csv', 'topfive_2008.csv', 'wik_1976.csv', 'wik_1996.csv']

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
CLeaning Data
# Out:
#   Cell In[14], line 1
#     CLeaning Data
#              ^
# SyntaxError: invalid syntax

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.Survived
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24580\1518254680.py in ?()
# ----> 1 titanic.Survived
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Survived'

# %%
titanic.survived.value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
for i in titanic.columns:
    print(titanic[i].value_counts(dropna = False))
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# sex
# male      577
# female    314
# Name: count, dtype: int64
# age
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: count, Length: 89, dtype: int64
# sibsp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64
# parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64
# fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: count, Length: 248, dtype: int64
# embarked
# S      644
# C      168
# Q       77
# NaN      2
# Name: count, dtype: int64
# deck
# NaN    688
# C       59
# B       47
# D       33
# E       32
# A       15
# F       13
# G        4
# Name: count, dtype: int64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['deck'] = titanic['deck'].replace(to_replace = 'C', value = 'See')

# %%
titanic.deck.value_counts()
# Out:
# deck
# See    59
# B      47
# D      33
# E      32
# A      15
# F      13
# G       4
# Name: count, dtype: int64

# %%
titanic.deck.fillna(value = titanic.deck.median()[0], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 titanic.deck.fillna(value = titanic.deck.median()[0], inplace = True)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\series.py:6559, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6551 @doc(make_doc("median", ndim=1))
#    6552 def median(
#    6553     self,
#    (...)
#    6557     **kwargs,
#    6558 ):
# -> 6559     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
#   12430 ) -> Series | float:
# > 12431     return self._stat_function(
#   12432         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433     )
#
# File c:\anaconda3\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\anaconda3\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\anaconda3\Lib\site-packages\pandas\core\nanops.py:787, in nanmedian(values, axis, skipna, mask)
#     785     inferred = lib.infer_dtype(values)
#     786     if inferred in ["string", "mixed"]:
# --> 787         raise TypeError(f"Cannot convert {values} to numeric")
#     788 try:
#     789     values = values.astype("f8")
#
# TypeError: Cannot convert ['See' 'See' 'See' 'See' 'See' 'See' 'E' 'See' 'See' 'See' 'G' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'D' 'See' 'A' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'B' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'D' 'See' 'B' 'See' 'See' 'See' 'See' 'See' 'See' 'B' 'See'
#  'See' 'See' 'See' 'F' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'F'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'E' 'See' 'See' 'See' 'A' 'D' 'See' 'See' 'See'
#  'See' 'D' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'B' 'See' 'See' 'See' 'See' 'E' 'D' 'See'
#  'See' 'See' 'F' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'D' 'See' 'See'
#  'B' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'F' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'E' 'See' 'See' 'See' 'B' 'See' 'See' 'See' 'A' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'F' 'See' 'A' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'F' 'B' 'B' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'G' 'See' 'See' 'See' 'A' 'See' 'See' 'See' 'See' 'See' 'D'
#  'See' 'See' 'D' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'D' 'See' 'See' 'G' 'See'
#  'See' 'See' 'See' 'See' 'B' 'See' 'See' 'See' 'See' 'E' 'B' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'D' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'A' 'See' 'See' 'See' 'See' 'See'
#  'See' 'B' 'D' 'See' 'See' 'See' 'See' 'See' 'See' 'B' 'See' 'See' 'See'
#  'E' 'See' 'See' 'See' 'See' 'See' 'E' 'See' 'B' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'E' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'D' 'See'
#  'B' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'E' 'See' 'See' 'F' 'See'
#  'See' 'See' 'See' 'F' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'E' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'D'
#  'See' 'See' 'B' 'E' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'B' 'See'
#  'See' 'D' 'G' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'E' 'See' 'See' 'See' 'See' 'E' 'B' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'A' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'E' 'D' 'See' 'See' 'E' 'See' 'E' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'D' 'See' 'A' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'B' 'See' 'See' 'B' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'D' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'B' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'E' 'See' 'See' 'D' 'F' 'See' 'See'
#  'See' 'B' 'See' 'See' 'B' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'B' 'See' 'See' 'B' 'B' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'A'
#  'See' 'E' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'E' 'See' 'See' 'See' 'See' 'E' 'See' 'See' 'See' 'See'
#  'See' 'A' 'See' 'E' 'See' 'B' 'See' 'See' 'See' 'D' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'A' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'F'
#  'See' 'See' 'D' 'See' 'See' 'See' 'D' 'See' 'D' 'See' 'See' 'A' 'See' 'B'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'B' 'See' 'See' 'See' 'D'
#  'See' 'A' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'D' 'See' 'See' 'E' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'B' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'B' 'See' 'D' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'B' 'B' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'F' 'See' 'E' 'See' 'See' 'See' 'See' 'See' 'E' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'F' 'See' 'E' 'See' 'See' 'See' 'See' 'See'
#  'See' 'E' 'See' 'See' 'See' 'See' 'See' 'B' 'See' 'See' 'See' 'See' 'See'
#  'See' 'B' 'See' 'See' 'D' 'See' 'B' 'See' 'See' 'B' 'See' 'See' 'D' 'See'
#  'See' 'E' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'B' 'See' 'See' 'See'
#  'B' 'See' 'D' 'See' 'See' 'See' 'See' 'See' 'See' 'E' 'See' 'See' 'See'
#  'F' 'See' 'See' 'B' 'See' 'B' 'D' 'See' 'See' 'See' 'See' 'See' 'See' 'B'
#  'See' 'See' 'See' 'See' 'See' 'See' 'D' 'See' 'See' 'See' 'See' 'See' 'B'
#  'See' 'See' 'See' 'A' 'See' 'See' 'E' 'See' 'See' 'See' 'See' 'See' 'B'
#  'See' 'See' 'See' 'See' 'B' 'See' 'See' 'E' 'See' 'See' 'See' 'See' 'See'
#  'B' 'See' 'See' 'See' 'See' 'See' 'E' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'See' 'D'
#  'See' 'See' 'See' 'E' 'See' 'See' 'See' 'See' 'D' 'See' 'See' 'See' 'See'
#  'A' 'See' 'See' 'See' 'D' 'B' 'See' 'See' 'See' 'See' 'See' 'See' 'See'
#  'See' 'See' 'See' 'See' 'See' 'See' 'See' 'B' 'See' 'See' 'See'] to numeric

# %%
titanic.deck.value_counts()
# Out:
# deck
# See    747
# B       47
# D       33
# E       32
# A       15
# F       13
# G        4
# Name: count, dtype: int64

# %%
titanic.rename(columns = {'deck':'dj'}, inplace = True)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'dj'],
#       dtype='object')

# %%
summer = pd.read_csv('summer.csv')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
summer[summer['Athlete'].str.contains('HAJOS')]
# Out:
#    Year    City     Sport Discipline        Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming  HAJOS, Alfred     HUN    Men
# 6  1896  Athens  Aquatics   Swimming  HAJOS, Alfred     HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
summer.Athlete.str.strip('d')
# Out:
# 0                     HAJOS, Alfre
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
titanic.fare.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: fare
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
titanic.fare.astype('str')
# Out:
# 0         7.25
# 1      71.2833
# 2        7.925
# 3         53.1
# 4         8.05
#         ...
# 886       13.0
# 887       30.0
# 888      23.45
# 889       30.0
# 890       7.75
# Name: fare, Length: 891, dtype: object

# %%
#Intro to NA values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.git', 'cars.csv', 'eda_ytube.ipynb', 'men2004.csv', 'men2004_det.csv', 'men2008.csv', 'men2008_det.csv', 'NB_02_Pandas_Series.ipynb', 'NB_03_Pandas_Index_Objects.ipynb', 'NB_04_DataFrame_Basics_II.ipynb', 'NB_05_Manipulating_Values_in_DataFrame.ipynb', 'NB_06_DataFrame_Basics_III.ipynb', 'NB_07_Visualization_with_Matplotlib.ipynb', 'numpy_pandas_basics_session.ipynb', 'pandas_series.ipynb', 'README.md', 'sales.csv', 'sales.xls', 'summer.csv', 'summer_2012.csv', 'summer_clean.csv', 'summer_imp.csv', 'summer_imp.xls', 'summer_raw.xls', 'table1.csv', 'table2.csv', 'table_2012.csv', 'titanic.csv', 'titanic_clean.csv', 'titanic_imp.csv', 'titanic_raw.csv', 'topfive_2004.csv', 'topfive_2008.csv', 'wik_1976.csv', 'wik_1996.csv']

# %%
sales = pd.read_csv('sales.csv', index_col = 0)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.isna().sum(axis = 1)
# Out:
# Steven    1
# Mike      0
# Andi      0
# Paul      0
# dtype: int64

# %%
sales.dropna(how = 'any', inplace = True)

# %%
sales
# Out:
#       Mon  Tue  Wed   Thu  Fri
# Mike   45    9   74  87.0   12
# Andi   17   33   54   8.0   29
# Paul   87   67   27  45.0    7

# %%
sales.iloc[2,:] = np.nan

# %%
sales
# Out:
#        Mon   Tue   Wed   Thu   Fri
# Mike  45.0   9.0  74.0  87.0  12.0
# Andi  17.0  33.0  54.0   8.0  29.0
# Paul   NaN   NaN   NaN   NaN   NaN
# 2      NaN   NaN   NaN   NaN   NaN

# %%
titanic.age.mean(skipna = True)
# Out:
# 29.69911764705882

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.age.fillna(value = titanic.age.mean(skipna = True), inplace = True)
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_30480\2356108592.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic.age.fillna(value = titanic.age.mean(skipna = True), inplace = True)

# %%
titanic.age.value_counts()
# Out:
# age
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: count, Length: 89, dtype: int64

# %%
titanic['age'] = titanic['age'].fillna(value = titanic['age'].mean())

# %%
titanic.age.value_counts(dropna = False)
# Out:
# age
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: count, Length: 89, dtype: int64

# %%
titanic.age.shape
# Out:
# (891,)

# %%
titanic.dropna(axis=0, how='any', inplace=True)

# %%
titanic[titanic.age.duplicated(keep = 'first')]
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked deck
# 55          1       1    male  29.699118      0      0  35.5000        S    C
# 97          1       1    male  23.000000      0      1  63.3583        C    D
# 124         0       1    male  54.000000      0      1  77.2875        S    D
# 128         1       3  female  29.699118      1      1  22.3583        C    F
# 136         1       1  female  19.000000      0      2  26.2833        S    D
# ..        ...     ...     ...        ...    ...    ...      ...      ...  ...
# 867         0       1    male  31.000000      0      0  50.4958        S    A
# 871         1       1  female  47.000000      1      1  52.5542        S    D
# 872         0       1    male  33.000000      0      0   5.0000        S    B
# 879         1       1  female  56.000000      0      1  83.1583        C    C
# 887         1       1  female  19.000000      0      0  30.0000        S    B
#
# [137 rows x 9 columns]

# %%
titanic.age.drop_duplicates(keep = 'first', ignore_index = True)
# Out:
# 0     38.0
# 1     35.0
# 2     54.0
# 3      4.0
# 4     58.0
#       ...
# 59    51.0
# 60    57.0
# 61    43.0
# 62    11.0
# 63    26.0
# Name: age, Length: 64, dtype: float64

# %%
titanic.shape
# Out:
# (201, 9)

# %%
plt.figure(figsize = (12,8))
titanic.age.plot()
titanic.boxplot('age')
plt.show()

# %%
plt.figure(figsize = (12,8))

titanic.boxplot('age')
plt.show()

# %%
## Merging, Appending, concatinating, Joining

# %%
import os

# %%
os.listdir()
# Out:
# ['.git',
#  'cars.csv',
#  'eda_ytube.ipynb',
#  'men2004.csv',
#  'men2004_det.csv',
#  'men2008.csv',
#  'men2008_det.csv',
#  'NB_02_Pandas_Series.ipynb',
#  'NB_03_Pandas_Index_Objects.ipynb',
#  'NB_04_DataFrame_Basics_II.ipynb',
#  'NB_05_Manipulating_Values_in_DataFrame.ipynb',
#  'NB_06_DataFrame_Basics_III.ipynb',
#  'NB_07_Visualization_with_Matplotlib.ipynb',
#  'numpy_pandas_basics_session.ipynb',
#  'pandas_series.ipynb',
#  'README.md',
#  'sales.csv',
#  'sales.xls',
#  'summer.csv',
#  'summer_2012.csv',
#  'summer_clean.csv',
#  'summer_imp.csv',
#  'summer_imp.xls',
#  'summer_raw.xls',
#  'table1.csv',
#  'table2.csv',
#  'table_2012.csv',
#  'titanic.csv',
#  'titanic_clean.csv',
#  'titanic_imp.csv',
#  'titanic_raw.csv',
#  'topfive_2004.csv',
#  'topfive_2008.csv',
#  'wik_1976.csv',
#  'wik_1996.csv']

# %%
men2008 = pd.read_csv('men2008.csv')

# %%
men2004 = pd.read_csv('men2004.csv')

# %%
men2008.shape
# Out:
# (62, 2)

# %%
men2004.shape
# Out:
# (59, 2)

# %%
men0408 = pd.concat([men2004, men2008], ignore_index = False, keys = [2004, 2008])

# %%
men0408.shape
# Out:
# (121, 2)

# %%
men0408
# Out:
#                   Athlete  Medals
# 2004 0    PHELPS, Michael       8
#      1        THORPE, Ian       4
#      2   SCHOEMAN, Roland       3
#      3     PEIRSOL, Aaron       3
#      4       CROCKER, Ian       3
# ...                   ...     ...
# 2008 57  LAGUNOV, Evgeniy       1
#      58     BERENS, Ricky       1
#      59      LURZ, Thomas       1
#      60   MALLET, Gregory       1
#      61        ZHANG, Lin       1
#
# [121 rows x 2 columns]

# %%
men20042208 = pd.concat([men2004,men2008], axis = 1, ignore_index = False, keys = [2004,2008])

# %%
men20042208
# Out:
#                    2004                        2008
#                 Athlete Medals              Athlete Medals
# 0       PHELPS, Michael    8.0      PHELPS, Michael      8
# 1           THORPE, Ian    4.0         LOCHTE, Ryan      4
# 2      SCHOEMAN, Roland    3.0       BERNARD, Alain      3
# 3        PEIRSOL, Aaron    3.0      SULLIVAN, Eamon      3
# 4          CROCKER, Ian    3.0  LAUTERSTEIN, Andrew      3
# ..                  ...    ...                  ...    ...
# 57     MAGNINI, Filippo    1.0     LAGUNOV, Evgeniy      1
# 58  ZWERING, Klaas-Erik    1.0        BERENS, Ricky      1
# 59                  NaN    NaN         LURZ, Thomas      1
# 60                  NaN    NaN      MALLET, Gregory      1
# 61                  NaN    NaN           ZHANG, Lin      1
#
# [62 rows x 4 columns]

# %%
men04 = pd.read_csv('men2004_det.csv')

# %%
men04
# Out:
#                   Athlete   Medal  Count
# 0          BOVELL, George  Bronze      1
# 1     BREMBILLA, Emiliano  Bronze      1
# 2   CAPPELLAZZO, Federico  Bronze      1
# 3         CERCATO, Simone  Bronze      1
# 4            CONRAD, Lars  Silver      1
# ..                    ...     ...    ...
# 72         WOODWARD, Gabe  Bronze      1
# 73      YAMAMOTO, Takashi  Bronze      1
# 74      YAMAMOTO, Takashi  Silver      1
# 75         ZASTROW, Mitja  Silver      1
# 76    ZWERING, Klaas-Erik  Silver      1
#
# [77 rows x 3 columns]

# %%
men2004.columns = ['rename1','rename2']

# %%
men2004
# Out:
#                        rename1  rename2
# 0              PHELPS, Michael        8
# 1                  THORPE, Ian        4
# 2             SCHOEMAN, Roland        3
# 3               PEIRSOL, Aaron        3
# 4                 CROCKER, Ian        3
# 5             KITAJIMA, Kosuke        3
# 6              HANSEN, Brendan        3
# 7   VAN DEN HOOGENBAND, Pieter        3
# 8               HACKETT, Grant        3
# 9               MORITA, Tomomi        2
# 10                LEZAK, Jason        2
# 11               ROGAN, Markus        2
# 12               KELLER, Klete        2
# 13              HALL, Gary Jr.        2
# 14                LOCHTE, Ryan        2
# 15                WALKER, Neil        2
# 16           YAMAMOTO, Takashi        2
# 17          SPRENGER, Nicholas        1
# 18          OKUMURA, Yoshihiro        1
# 19              PARRY, Stephen        1
# 20               PEARSON, Todd        1
# 21              ZASTROW, Mitja        1
# 22          PELLICIARI, Matteo        1
# 23              WOODWARD, Gabe        1
# 24            SERDINOV, Andriy        1
# 25                 VENDT, Erik        1
# 26      ROSOLINO, Massimiliano        1
# 27        VEENS, Mark Hermanus        1
# 28            RUPPRATH, Thomas        1
# 29           VANDERKAAY, Peter        1
# 30            TOWNSEND, Darian        1
# 31              STEVENS, Craig        1
# 32              NEETHLING, Ryk        1
# 33              BOVELL, George        1
# 34                MEEUW, Helge        1
# 35        FLOREA, Razvan Ionut        1
# 36       CAPPELLAZZO, Federico        1
# 37             CERCATO, Simone        1
# 38                CONRAD, Lars        1
# 39                CSEH, Laszlo        1
# 40               DAVIES, David        1
# 41              DRAGANJA, Duje        1
# 42            DRIESEN, Steffen        1
# 43             DUBOSCQ, Hugues        1
# 44                DUSING, Nate        1
# 45               FERNS, Lyndon        1
# 46              GANGLOFF, Mark        1
# 47           MATKOVICH, Antony        1
# 48            GOLDBLATT, Scott        1
# 49              GYURTA, Daniel        1
# 50              JENSEN, Larsen        1
# 51             KENKHUIS, Johan        1
# 52                KETCHUM, Dan        1
# 53               KLIM, Michael        1
# 54          KRAYZELBURG, Lenny        1
# 55                KRUPPA, Jens        1
# 56         BREMBILLA, Emiliano        1
# 57            MAGNINI, Filippo        1
# 58         ZWERING, Klaas-Erik        1

# %%
os.listdir()
# Out:
# ['.git',
#  'cars.csv',
#  'eda_ytube.ipynb',
#  'men2004.csv',
#  'men2004_det.csv',
#  'men2008.csv',
#  'men2008_det.csv',
#  'NB_02_Pandas_Series.ipynb',
#  'NB_03_Pandas_Index_Objects.ipynb',
#  'NB_04_DataFrame_Basics_II.ipynb',
#  'NB_05_Manipulating_Values_in_DataFrame.ipynb',
#  'NB_06_DataFrame_Basics_III.ipynb',
#  'NB_07_Visualization_with_Matplotlib.ipynb',
#  'numpy_pandas_basics_session.ipynb',
#  'pandas_series.ipynb',
#  'README.md',
#  'sales.csv',
#  'sales.xls',
#  'summer.csv',
#  'summer_2012.csv',
#  'summer_clean.csv',
#  'summer_imp.csv',
#  'summer_imp.xls',
#  'summer_raw.xls',
#  'table1.csv',
#  'table2.csv',
#  'table_2012.csv',
#  'titanic.csv',
#  'titanic_clean.csv',
#  'titanic_imp.csv',
#  'titanic_raw.csv',
#  'topfive_2004.csv',
#  'topfive_2008.csv',
#  'wik_1976.csv',
#  'wik_1996.csv']

# %%
top5 = pd.read_csv('topfive_2004.csv')

# %%
top5
# Out:
#             Athlete  Gold  Silver  Bronze
# 0   PHELPS, Michael   6.0     0.0     2.0
# 1    PEIRSOL, Aaron   3.0     0.0     0.0
# 2       THORPE, Ian   2.0     1.0     1.0
# 3  KITAJIMA, Kosuke   2.0     0.0     1.0
# 4    HACKETT, Grant   1.0     2.0     0.0

# %%
top8 =  pd.read_csv('topfive_2008.csv')

# %%
top8
# Out:
#             Athlete  Gold  Silver  bronze
# 0   PHELPS, Michael   8.0     0.0     0.0
# 1     GREVERS, Matt   2.0     1.0     0.0
# 2    PEIRSOL, Aaron   2.0     1.0     0.0
# 3      LOCHTE, Ryan   2.0     0.0     2.0
# 4  KITAJIMA, Kosuke   2.0     0.0     1.0

# %%
top5 + top8
# Out:
#                           Athlete  Bronze  Gold  Silver  bronze
# 0  PHELPS, MichaelPHELPS, Michael     NaN  14.0     0.0     NaN
# 1     PEIRSOL, AaronGREVERS, Matt     NaN   5.0     1.0     NaN
# 2       THORPE, IanPEIRSOL, Aaron     NaN   4.0     2.0     NaN
# 3    KITAJIMA, KosukeLOCHTE, Ryan     NaN   4.0     0.0     NaN
# 4  HACKETT, GrantKITAJIMA, Kosuke     NaN   3.0     2.0     NaN

# %%
top5
# Out:
#             Athlete  Gold  Silver  Bronze
# 0   PHELPS, Michael   6.0     0.0     2.0
# 1    PEIRSOL, Aaron   3.0     0.0     0.0
# 2       THORPE, Ian   2.0     1.0     1.0
# 3  KITAJIMA, Kosuke   2.0     0.0     1.0
# 4    HACKETT, Grant   1.0     2.0     0.0

# %%
top8
# Out:
#             Athlete  Gold  Silver  bronze
# 0   PHELPS, Michael   8.0     0.0     0.0
# 1     GREVERS, Matt   2.0     1.0     0.0
# 2    PEIRSOL, Aaron   2.0     1.0     0.0
# 3      LOCHTE, Ryan   2.0     0.0     2.0
# 4  KITAJIMA, Kosuke   2.0     0.0     1.0

# %%
top8.rename(columns = {'bronze':'Bronze'}, inplace = True)

# %%
top8
# Out:
#             Athlete  Gold  Silver  Bronze
# 0   PHELPS, Michael   8.0     0.0     0.0
# 1     GREVERS, Matt   2.0     1.0     0.0
# 2    PEIRSOL, Aaron   2.0     1.0     0.0
# 3      LOCHTE, Ryan   2.0     0.0     2.0
# 4  KITAJIMA, Kosuke   2.0     0.0     1.0

# %%
top5.set_index('Athlete', inplace = True)

# %%
top5
# Out:
#                   Gold  Silver  Bronze
# Athlete
# PHELPS, Michael    6.0     0.0     2.0
# PEIRSOL, Aaron     3.0     0.0     0.0
# THORPE, Ian        2.0     1.0     1.0
# KITAJIMA, Kosuke   2.0     0.0     1.0
# HACKETT, Grant     1.0     2.0     0.0

# %%
top8.set_index('Athlete', inplace = True)

# %%
top8
# Out:
#                   Gold  Silver  Bronze
# Athlete
# PHELPS, Michael    8.0     0.0     0.0
# GREVERS, Matt      2.0     1.0     0.0
# PEIRSOL, Aaron     2.0     1.0     0.0
# LOCHTE, Ryan       2.0     0.0     2.0
# KITAJIMA, Kosuke   2.0     0.0     1.0

# %%
top5 + top8
# Out:
#                   Gold  Silver  Bronze
# Athlete
# GREVERS, Matt      NaN     NaN     NaN
# HACKETT, Grant     NaN     NaN     NaN
# KITAJIMA, Kosuke   4.0     0.0     2.0
# LOCHTE, Ryan       NaN     NaN     NaN
# PEIRSOL, Aaron     5.0     1.0     0.0
# PHELPS, Michael   14.0     0.0     2.0
# THORPE, Ian        NaN     NaN     NaN

# %%
top5.exp(top8, fill_value = 0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30480\611062165.py in ?()
# ----> 1 top5.exp(top8, fill_value = 0)
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'exp'

# %%
men2004 = pd.read_csv("men2004.csv")
men2008 = pd.read_csv("men2008.csv")

# %%
men0408 = men2004.merge(men2008, how = 'outer', on = 'Athlete', suffixes = ['_2004', '_2008'], sort = True,indicator = True )

# %%
men0408._merge.value_counts()
# Out:
# _merge
# right_only    46
# left_only     43
# both          16
# Name: count, dtype: int64

# %%
men0408[men0408._merge == 'both']
# Out:
#               Athlete  Medals_2004  Medals_2008 _merge
# 15       CROCKER, Ian          3.0          1.0   both
# 16       CSEH, Laszlo          1.0          3.0   both
# 17      DAVIES, David          1.0          1.0   both
# 21    DUBOSCQ, Hugues          1.0          2.0   both
# 27     GANGLOFF, Mark          1.0          1.0   both
# 32     HACKETT, Grant          3.0          2.0   both
# 34    HANSEN, Brendan          3.0          1.0   both
# 36     JENSEN, Larsen          1.0          1.0   both
# 38      KELLER, Klete          2.0          1.0   both
# 41   KITAJIMA, Kosuke          3.0          3.0   both
# 48       LEZAK, Jason          2.0          3.0   both
# 50       LOCHTE, Ryan          2.0          4.0   both
# 68     PEIRSOL, Aaron          3.0          3.0   both
# 70    PHELPS, Michael          8.0          8.0   both
# 92  VANDERKAAY, Peter          1.0          2.0   both
# 94        VENDT, Erik          1.0          1.0   both

# %%
#GroupBY Obect

# %%
import pandas as pd

# %%
titanic.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 1 to 889
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  201 non-null    int64
#  1   pclass    201 non-null    int64
#  2   sex       201 non-null    object
#  3   age       201 non-null    float64
#  4   sibsp     201 non-null    int64
#  5   parch     201 non-null    int64
#  6   fare      201 non-null    float64
#  7   embarked  201 non-null    object
#  8   deck      201 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 15.7+ KB

# %%
titanic.isna().sum(axis = 0)
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# deck        0
# dtype: int64

# %%
titanic.deck.value_counts(dropna = False)
# Out:
# deck
# C    59
# B    45
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
titanic = pd.read_csv('titanic.csv')
titanic_slice = titanic.iloc[2:12,:]

# %%
titanic_slice
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C

# %%
titanic_slice.groupby('sex')

# %%
list(titanic_slice.groupby('sex'))[0][1][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 list(titanic_slice.groupby('sex'))[0][1][0]
#
# File c:\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0

# %%
#SPlitting with many key

# %%
summer = pd.read_csv('summer.csv',usecols = ['Athlete'], index_col = 'Athlete')

# %%
summer
# Out:
# Empty DataFrame
# Columns: []
# Index: [HAJOS, Alfred, HERSCHMANN, Otto, DRIVAS, Dimitrios, MALOKINIS, Ioannis, CHASAPIS, Spiridon, CHOROPHAS, Efstathios, HAJOS, Alfred, ANDREOU, Joannis, CHOROPHAS, Efstathios, NEUMANN, Paul, PEPANOS, Antonios, LANE, Francis, SZOKOLYI, Alajos, BURKE, Thomas, HOFMANN, Fritz, CURTIS, Thomas, GOULDING, Grantley, LERMUSIAUX, Albin, FLACK, Edwin, BLAKE, Arthur, GMELIN, Charles, BURKE, Thomas, JAMISON, Herbert, GOLEMIS, Dimitrios, FLACK, Edwin, DANI, Nandor, VERSIS, Sotirios, GARRETT, Robert, PARASKEVOPOULOS, Panagiotis, CLARK, Ellery, CONNOLLY, James, GARRETT, Robert, CONNOLLY, James, CLARK, Ellery, GARRETT, Robert, KELLNER, Gyula, LOUIS, Spyridon, VASILAKOS, Kharilaos, DAMASKOS, Evangelos, THEODOROPOULOS, Ioannis, HOYT, William Welles, TYLER, Albert, PAPASIDERIS, Georgios, GARRETT, Robert, GOUSKOS, Miltiadis, PERSAKIS, Ioannis, CONNOLLY, James, TUFFERI, Alexandre, BATTEL, Edward, KONSTANTINIDIS, Aristidis, GOEDRICH, August, FLAMENG, Léon, KOLETTIS, Georgios, SCHMAL, Adolf, MASSON, Paul, FLAMENG, Léon, SCHMAL, Adolf, KEEPING, Frank, SCHMAL, Adolf, MASSON, Paul, NIKOLOPOULOS, Stamatios, FLAMENG, Léon, MASSON, Paul, NIKOLOPOULOS, Stamatios, PIERRAKOS-MAVROMICHALIS, Perikles, GRAVELOTTE, Eugène-Henri, CALLOT, Henri, PYRGOS, Leonidas, PERRONNET, Maurice, NIELSEN, Holger, GEORGIADIS, Ioannis, KARAKALOS, Telemachos, WEINGÄRTNER, Hermann, FLATOW, Alfred, FLATOW, Alfred, ZUTTER, Louis, ZUTTER, Louis, WEINGÄRTNER, Hermann, PERSAKIS, Petros, MITROPOULOS, Ioannis, WEINGÄRTNER, Hermann, HOFMANN, Fritz, ANDRIAKOPOULOS, Nicolaos, XENAKIS, Thomasios, BÖCKER, Konrad, FLATOW, Alfred, FLATOW, Gustav Felix, HILMAR, Georg, HOFMANN, Fritz, MANTEUFFEL, Fritz, NEUKIRCH, Karl, RÖSTEL, Richard, SCHUFT, Gustav, SCHUMANN, Carl, WEINGÄRTNER, Hermann, CHRYSAPHIS, Ioannis, KARVELAS, Phillippos, LOUNDRAS, Dimitrios, MITROPOULOS, Ioannis, BÖCKER, Konrad, ...]
#
# [31165 rows x 0 columns]

# %%
summer.index.nunique()
# Out:
# 22762

# %%
summer.groupby('Athlete').count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [AABYE, Edgar, AALTONEN, Arvo Ossian, AALTONEN, Paavo Johannes, AAMODT, Ragnhild, AANING, Alf Lied, AARDENBURG, Willemien, AARDEWIJN, Pepijn, AARONES, Ann Kristin, AAS, Karl Jan, AAS, Thomas Valentin, ABAJO, Jose Luis, ABAKUMOVA, Maria, ABALMASAU, Aliaksei, ABALO, Luc, ABANDA ETONG, Patrice, ABARCA, Jose Maria, ABAS, Stephen, ABASCAL GARCIA, Alejandro, ABASCAL GOMEZ, Jose Manuel, ABASSOVA, Tamilla, ABATI, Joel, ABAY, Peter, ABAY-NEMES, Oszkar, ABBA, Silvano, ABBAGNALE, Agostino, ABBAGNALE, Carmine, ABBAGNALE, Giuseppe, ABBOTT, Des, ABBOTT, Margaret Ives, ABBOTT, Monica, ABDALLAH, Nia, ABDELAZIM, Tarek Yehia Fouad, ABDO, Reema, ABDOOLLAYEV, Mahammatkodir, ABDUL, Hamid, ABDUL, Rashid I, ABDUL, Rashid III, ABDUL, Rashid IV, ABDUL, Waheed, ABDULBEKOV, Zagalav, ABDULLAYEV, Namig, ABDUR-RAHIM, Shareef, ABDUSALOMOV, Yusup, ABDUVALIEV, Andrey, ABEBE, Addis, ABEGGLEN, Max, ABEL, Irene, ABEL, Jennifer, ABEL, Sten, ABELARDO, Olivier, ABELL, Louis, ABERA, Gezahegne, ABERG, Georg, ABERNATHY, Brent, ABERNETHY, Moira, ABEYLEGESSE, Elvan, ABILOV, Ismail, ABIR ABDELRAHMAN, Khalil Mahmoud K., ABLOWICH, Edgar Allen, ABLYAZIN, Denis, ABOIMOV, Viktor, ABOUELKASSEM, Alaaeldin, ABRAHAM, Attila, ABRAHAM, F., ABRAHAM, Gary, ABRAHAMIAN, Ara, ABRAHAMS, Harold, ABRAHAMSEN, Isak, ABRAHAMSSON, Erik, ABRAMOV, Pavel, ABRAMOVA, Nelli, ABROSIMOVA, Svetlana, ABSAIDOV, Saipulla, ABSALON, Julien, ABUKAWA-CHIBA, Ginko, ABUSHAKHMETOV, Aleksandr, ABUSHEV, Magomedgasan, ACATRINEI, Andreea, ACCAMBRAY, William, ACEDO, Domingo, ACEVEDO SANTIAGO, Anibal, ACEVES, Daniel, ACHEAMPONG, Joachin Yaw, ACHERMANN, Alfred, ACHIK, Abdelhak, ACHIK, Mohamed, ACHTERBERG, Chantal, ACKE, Fausto, ACKERLEY, Paul, ACKERLY, Charles Edwin, ACOSTA DUARTE, Osmai, ACOSTA Y LARA, Martin, ACOSTA, Lautaro, ADACH, Kazimierz, ADAM, Gordon Belgum, ADAM, Jiri, ADAM, John M., ADAM, Otto, ADAM, Pierre, ADAMS, Benjamin W., ...]
#
# [22762 rows x 0 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['age'].fillna(value = titanic.groupby('pclass').age.transform('mean'), inplace = True)
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_46252\3641083126.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['age'].fillna(value = titanic.groupby('pclass').age.transform('mean'), inplace = True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       891 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.groupby('pclass').age.mean()
# Out:
# pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: age, dtype: float64

# %%
titanic.age.mean()
# Out:
# 29.292874790272087

# %%
titanic
# Out:
#      survived  pclass     sex       age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.00000      1      0   7.2500        S  NaN
# 1           1       1  female  38.00000      1      0  71.2833        C    C
# 2           1       3  female  26.00000      0      0   7.9250        S  NaN
# 3           1       1  female  35.00000      1      0  53.1000        S    C
# 4           0       3    male  35.00000      0      0   8.0500        S  NaN
# ..        ...     ...     ...       ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.00000      0      0  13.0000        S  NaN
# 887         1       1  female  19.00000      0      0  30.0000        S    B
# 888         0       3  female  25.14062      1      2  23.4500        S  NaN
# 889         1       1    male  26.00000      0      0  30.0000        C    C
# 890         0       3    male  32.00000      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['have_relatives'] = titanic['sibsp'] + titanic['parch']

# %%
titanic
# Out:
#      survived  pclass     sex       age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.00000      1      0   7.2500        S  NaN
# 1           1       1  female  38.00000      1      0  71.2833        C    C
# 2           1       3  female  26.00000      0      0   7.9250        S  NaN
# 3           1       1  female  35.00000      1      0  53.1000        S    C
# 4           0       3    male  35.00000      0      0   8.0500        S  NaN
# ..        ...     ...     ...       ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.00000      0      0  13.0000        S  NaN
# 887         1       1  female  19.00000      0      0  30.0000        S    B
# 888         0       3  female  25.14062      1      2  23.4500        S  NaN
# 889         1       1    male  26.00000      0      0  30.0000        C    C
# 890         0       3    male  32.00000      0      0   7.7500        Q  NaN
#
#      have_relatives
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 0
# ..              ...
# 886               0
# 887               0
# 888               3
# 889               0
# 890               0
#
# [891 rows x 10 columns]

# %%
titanic.drop(['sibsp','parch'],axis = 1, inplace = True)

# %%
titanic
# Out:
#      survived  pclass     sex       age     fare embarked deck  have_relatives
# 0           0       3    male  22.00000   7.2500        S  NaN               1
# 1           1       1  female  38.00000  71.2833        C    C               1
# 2           1       3  female  26.00000   7.9250        S  NaN               0
# 3           1       1  female  35.00000  53.1000        S    C               1
# 4           0       3    male  35.00000   8.0500        S  NaN               0
# ..        ...     ...     ...       ...      ...      ...  ...             ...
# 886         0       2    male  27.00000  13.0000        S  NaN               0
# 887         1       1  female  19.00000  30.0000        S    B               0
# 888         0       3  female  25.14062  23.4500        S  NaN               3
# 889         1       1    male  26.00000  30.0000        C    C               0
# 890         0       3    male  32.00000   7.7500        Q  NaN               0
#
# [891 rows x 8 columns]

# %%
titanic.age.add(titanic.age)
# Out:
# 0      44.000000
# 1      76.000000
# 2      52.000000
# 3      70.000000
# 4      70.000000
#          ...
# 886    54.000000
# 887    38.000000
# 888    50.281239
# 889    52.000000
# 890    64.000000
# Name: age, Length: 891, dtype: float64

# %%
titanic.loc[:,'age'] = titanic.age.add(titanic.age)

# %%
titanic
# Out:
#      survived  pclass     sex        age     fare embarked deck  \
# 0           0       3    male  44.000000   7.2500        S  NaN
# 1           1       1  female  76.000000  71.2833        C    C
# 2           1       3  female  52.000000   7.9250        S  NaN
# 3           1       1  female  70.000000  53.1000        S    C
# 4           0       3    male  70.000000   8.0500        S  NaN
# ..        ...     ...     ...        ...      ...      ...  ...
# 886         0       2    male  54.000000  13.0000        S  NaN
# 887         1       1  female  38.000000  30.0000        S    B
# 888         0       3  female  50.281239  23.4500        S  NaN
# 889         1       1    male  52.000000  30.0000        C    C
# 890         0       3    male  64.000000   7.7500        Q  NaN
#
#      have_relatives
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 0
# ..              ...
# 886               0
# 887               0
# 888               3
# 889               0
# 890               0
#
# [891 rows x 8 columns]

# %%
summer = pd.read_csv('summer.csv')

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
city_country = {"Paris":"France", "Mexico":"Mexico", "Montreal":"Canada", "Moscow":"Russia", "Barcelona":"Spain", "Athens": "Greece"}

# %%
sample = summer.sample(n =7, random_state = 123)

# %%
sample
# Out:
#        Year       City      Sport  Discipline                   Athlete  \
# 13996  1976   Montreal   Aquatics    Swimming          MAC DONALD, Gary
# 19728  1992  Barcelona   Aquatics    Swimming        KULIKOV, Vladislav
# 11961  1968     Mexico  Athletics   Athletics  FOSBURY, Richard Douglas
# 11742  1968     Mexico   Aquatics    Swimming   WENDEN, Michael Vincent
# 16229  1980     Moscow     Rowing      Rowing       DMITRIENKO, Grigori
# 4196   1924      Paris   Aquatics  Water polo            AUSTIN, Arthur
# 25901  2004     Athens     Boxing      Boxing            YELEUOV, Serik
#
#       Country Gender                     Event   Medal
# 13996     CAN    Men       4X100M Medley Relay  Silver
# 19728     EUN    Men       4X100M Medley Relay  Silver
# 11961     USA    Men                 High Jump    Gold
# 11742     AUS    Men            200M Freestyle    Gold
# 16229     URS    Men  Eight With Coxswain (8+)  Bronze
# 4196      USA    Men                Water Polo  Bronze
# 25901     KAZ    Men   57 - 60KG (Lightweight)  Bronze

# %%
sample.loc[:,'Country'] = sample.City.map(city_country)

# %%
sample
# Out:
#        Year       City      Sport  Discipline                   Athlete  \
# 13996  1976   Montreal   Aquatics    Swimming          MAC DONALD, Gary
# 19728  1992  Barcelona   Aquatics    Swimming        KULIKOV, Vladislav
# 11961  1968     Mexico  Athletics   Athletics  FOSBURY, Richard Douglas
# 11742  1968     Mexico   Aquatics    Swimming   WENDEN, Michael Vincent
# 16229  1980     Moscow     Rowing      Rowing       DMITRIENKO, Grigori
# 4196   1924      Paris   Aquatics  Water polo            AUSTIN, Arthur
# 25901  2004     Athens     Boxing      Boxing            YELEUOV, Serik
#
#       Country Gender                     Event   Medal
# 13996  Canada    Men       4X100M Medley Relay  Silver
# 19728   Spain    Men       4X100M Medley Relay  Silver
# 11961  Mexico    Men                 High Jump    Gold
# 11742  Mexico    Men            200M Freestyle    Gold
# 16229  Russia    Men  Eight With Coxswain (8+)  Bronze
# 4196   France    Men                Water Polo  Bronze
# 25901  Greece    Men   57 - 60KG (Lightweight)  Bronze

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe(include = 'O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
titanic.plot(subplots = True, kind = 'bar', sharex = True)
# Out:
# array([<Axes: title={'center': 'survived'}>,
#        <Axes: title={'center': 'pclass'}>,
#        <Axes: title={'center': 'age'}>, <Axes: title={'center': 'sibsp'}>,
#        <Axes: title={'center': 'parch'}>,
#        <Axes: title={'center': 'fare'}>], dtype=object)

# %%
titanic.loc[:,'age'] = titanic['age'].fillna(titanic.age.groupby(titanic.pclass).transform('mean'))

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       891 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic['relatives'] = titanic['sibsp'] + titanic['parch']

# %%
titanic.shape
# Out:
# (891, 10)

# %%
titanic.drop(['sibsp','parch'], inplace = True, axis = 1)

# %%
titanic.shape
# Out:
# (891, 8)

# %%
sales = pd.read_csv('sales.csv', index_col = 0)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.Mon + sales.Thu
# Out:
# Steven      NaN
# Mike      132.0
# Andi       25.0
# Paul      132.0
# dtype: float64

# %%
sales.Mon.add(sales.Thu, fill_value= 0)
# Out:
# Steven     34.0
# Mike      132.0
# Andi       25.0
# Paul      132.0
# dtype: float64

# %%
#Transformation and Mapping

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age     fare embarked deck  relatives alone
# 0         0       3    male  22.0   7.2500        S  NaN          1    No
# 1         1       1  female  38.0  71.2833        C    C          1    No
# 2         1       3  female  26.0   7.9250        S  NaN          0   Yes
# 3         1       1  female  35.0  53.1000        S    C          1    No
# 4         0       3    male  35.0   8.0500        S  NaN          0   Yes

# %%
titanic['alone'] = np.where(titanic.relatives == 0,'Yes','No')

# %%
titanic.shape
# Out:
# (891, 9)

# %%
for element in titanic:
    if titanic.alone == 'Yes':
        titanic['not_alone'] = 'No'
    else:
        titanic['not_alone'] = 'Yes'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24836\3834788405.py in ?()
#       1 for element in titanic:
# ----> 2     if titanic.alone == 'Yes':
#       3         titanic['not_alone'] = 'No'
#       4     else:
#       5         titanic['not_alone'] = 'Yes'
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
titanic.loc[:,'not_alone'] = titanic.alone[titanic.alone == 'No']
titanic.loc[:, 'not_alone'] = (titanic.alone[titanic.alone == 'Yes'] | titanic.alone[titanic.alone == 'No'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for |: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 titanic.loc[:,'not_alone'] = titanic.alone[titanic.alone == 'No']
# ----> 2 titanic.loc[:, 'not_alone'] = (titanic.alone[titanic.alone == 'Yes'] | titanic.alone[titanic.alone == 'No'])
#
# File c:\anaconda3\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\arraylike.py:78, in OpsMixin.__or__(self, other)
#      76 @unpack_zerodim_and_defer("__or__")
#      77 def __or__(self, other):
# ---> 78     return self._logical_method(other, operator.or_)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\series.py:6130, in Series._logical_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.logical_op(lvalues, rvalues, op)
#    6131 return self._construct_result(res_values, name=res_name)
#
# File c:\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:454, in logical_op(left, right, op)
#     450 else:
#     451     # i.e. scalar
#     452     is_other_int_dtype = lib.is_integer(rvalues)
# --> 454 res_values = na_logical_op(lvalues, rvalues, op)
#     456 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     457 #   integer dtypes.  Otherwise these are boolean ops
#     458 if not (left.dtype.kind in "iu" and is_other_int_dtype):
#
# File c:\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:369, in na_logical_op(x, y, op)
#     367     x = ensure_object(x)
#     368     y = ensure_object(y)
# --> 369     result = libops.vec_binop(x.ravel(), y.ravel(), op)
#     370 else:
#     371     # let null fall thru
#     372     assert lib.is_scalar(y)
#
# File ops.pyx:252, in pandas._libs.ops.vec_binop()
#
# File ops.pyx:245, in pandas._libs.ops.vec_binop()
#
# TypeError: unsupported operand type(s) for |: 'str' and 'bool'

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age     fare embarked deck  relatives alone  \
# 0         0       3    male  22.0   7.2500        S  NaN          1    No
# 1         1       1  female  38.0  71.2833        C    C          1    No
# 2         1       3  female  26.0   7.9250        S  NaN          0   Yes
# 3         1       1  female  35.0  53.1000        S    C          1    No
# 4         0       3    male  35.0   8.0500        S  NaN          0   Yes
#
#   not_alone
# 0       NaN
# 1       NaN
# 2       Yes
# 3       NaN
# 4       Yes

# %%
#Coding Exercises
import pandas as pd
labels = ['mpg',
 'cylinders',
 'displacement',
 'horsepower',
 'weight',
 'acceleration',
 'model year',
 'origin',
 'name']

# %%
cars = pd.read_csv('cars_raw.csv', names = labels, skipfooter= 1, skiprows= 2)
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_25192\2550791976.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   cars = pd.read_csv('cars_raw.csv', names = labels, skipfooter= 1, skiprows= 2)

# %%
cars['mpg'] = cars['mpg'].round(2)
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           329 non-null    float64
#  1   cylinders     329 non-null    int64
#  2   displacement  329 non-null    float64
#  3   horsepower    329 non-null    object
#  4   weight        329 non-null    int64
#  5   acceleration  329 non-null    float64
#  6   model year    329 non-null    int64
#  7   origin        329 non-null    object
#  8   name          329 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 23.3+ KB

# %%
cars.loc[:,'horsepower'] = cars.loc[:,'horsepower'].str.replace('hp','')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25192\214158298.py in ?()
# ----> 1 cars.loc[:,'horsepower'] = cars.loc[:,'horsepower'].str.replace('hp','').strip()
#
# c:\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
cars['horsepower'] = cars.horsepower.str.strip()

# %%
cars['horsepower'] = pd.to_numeric(cars.horsepower, errors= 'coerce')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           329 non-null    float64
#  1   cylinders     329 non-null    int64
#  2   displacement  329 non-null    float64
#  3   horsepower    323 non-null    float64
#  4   weight        329 non-null    int64
#  5   acceleration  329 non-null    float64
#  6   model year    329 non-null    int64
#  7   origin        329 non-null    object
#  8   name          329 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 23.3+ KB

# %%
cars
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.00          8         307.0       130.0    3504          12.0
# 1    15.00          8         350.0       165.0    3693          11.5
# 2    18.00          8         318.0       150.0    3436          11.0
# 3    16.00          8         304.0       150.0    3433          12.0
# 4    17.00          8         302.0       140.0    3449          10.5
# 5    15.00          8         429.0       198.0    4341          10.0
# 6    14.00          8         454.0       220.0    4354           9.0
# 7    14.00          8         440.0       215.0    4312           8.5
# 8    14.00          8         455.0       225.0    4425          10.0
# 9    15.00          8         390.0       190.0    3850           8.5
# 10   15.00          8         383.0       170.0    3563          10.0
# 11   14.00          8         340.0       160.0    3609           8.0
# 12   15.00          8         400.0       150.0    3761           9.5
# 13   14.00          8         455.0       225.0    3086          10.0
# 14   22.00          6         198.0        95.0    2833          15.5
# 15   18.00          6         199.0        97.0    2774          15.5
# 16   21.00          6         200.0        85.0    2587          16.0
# 17   26.00          4          97.0        46.0    1835          20.5
# 18   25.00          4         110.0        87.0    2672          17.5
# 19   24.00          4         107.0        90.0    2430          14.5
# 20   25.00          4         104.0        95.0    2375          17.5
# 21   26.00          4         121.0       113.0    2234          12.5
# 22   21.00          6         199.0        90.0    2648          15.0
# 23   10.00          8         360.0       215.0    4615          14.0
# 24   10.00          8         307.0       200.0    4376          15.0
# 25   11.00          8         318.0       210.0    4382          13.5
# 26    9.00          8         304.0       193.0    4732          18.5
# 27   28.00          4         140.0        90.0    2264          15.5
# 28   25.00          4          98.0         NaN    2046          19.0
# 29   19.00          6         232.0       100.0    2634          13.0
# 30   16.00          6         225.0       105.0    3439          15.5
# 31   17.00          6         250.0       100.0    3329          15.5
# 32   19.00          6         250.0        88.0    3302          15.5
# 33   18.00          6         232.0       100.0    3288          15.5
# 34   14.00          8         350.0       165.0    4209          12.0
# 35   14.00          8         400.0       175.0    4464          11.5
# 36   14.00          8         351.0       153.0    4154          13.5
# 37   14.00          8         318.0       150.0    4096          13.0
# 38   12.00          8         383.0       180.0    4955          11.5
# 39   13.00          8         400.0       170.0    4746          12.0
# 40   13.00          8         400.0       175.0    5140          12.0
# 41   18.00          6         258.0       110.0    2962          13.5
# 42   22.00          4         140.0        72.0    2408          19.0
# 43   19.00          6         250.0       100.0    3282          15.0
# 44   18.00          6         250.0        88.0    3139          14.5
# 45   23.00          4         122.0        86.0    2220          14.0
# 46   28.00          4         116.0        90.0    2123          14.0
# 47   30.00          4          79.0        70.0    2074          19.5
# 48   30.00          4          88.0        76.0    2065          14.5
# 49   27.00          4          97.0        60.0    1834          19.0
# 50   26.00          4          91.0        70.0    1955          20.5
# 51   25.00          4          97.5        80.0    2126          17.0
# 52   23.00          4          97.0        54.0    2254          23.5
# 53   20.00          4         140.0        90.0    2408          19.5
# 54   21.00          4         122.0        86.0    2226          16.5
# 55   13.00          8         350.0       165.0    4274          12.0
# 56   14.00          8         400.0       175.0    4385          12.0
# 57   15.00          8         318.0       150.0    4135          13.5
# 58   14.00          8         351.0       153.0    4129          13.0
# 59   17.00          8         304.0       150.0    3672          11.5
# 60   11.00          8         429.0       208.0    4633          11.0
# 61   13.00          8         350.0       155.0    4502          13.5
# 62   12.00          8         350.0       160.0    4456          13.5
# 63   13.00          8         400.0       190.0    4422          12.5
# 64   15.00          8         304.0       150.0    3892          12.5
# 65   13.00          8         307.0       130.0    4098          14.0
# 66   13.00          8         302.0       140.0    4294          16.0
# 67   14.00          8         318.0       150.0    4077          14.0
# 68   18.00          4         121.0       112.0    2933          14.5
# 69   22.00          4         121.0        76.0    2511          18.0
# 70   21.00          4         120.0        87.0    2979          19.5
# 71   26.00          4          96.0        69.0    2189          18.0
# 72   22.00          4         122.0        86.0    2395          16.0
# 73   28.00          4          98.0        80.0    2164          15.0
# 74   13.00          8         350.0       175.0    4100          13.0
# 75   14.00          8         304.0       150.0    3672          11.5
# 76   13.00          8         350.0       145.0    3988          13.0
# 77   14.00          8         302.0       137.0    4042          14.5
# 78   15.00          8         318.0       150.0    3777          12.5
# 79   12.00          8         429.0       198.0    4952          11.5
# 80   13.00          8         400.0       150.0    4464          12.0
# 81   13.00          8         351.0       158.0    4363          13.0
# 82   14.00          8         318.0       150.0    4237          14.5
# 83   13.00          8         440.0       215.0    4735          11.0
# 84   12.00          8         455.0       225.0    4951          11.0
# 85   13.00          8         360.0       175.0    3821          11.0
# 86   18.00          6         225.0       105.0    3121          16.5
# 87   16.00          6         250.0       100.0    3278          18.0
# 88   18.00          6         232.0       100.0    2945          16.0
# 89   18.00          6         250.0        88.0    3021          16.5
# 90   23.00          6         198.0        95.0    2904          16.0
# 91   26.00          4          97.0        46.0    1950          21.0
# 92   11.00          8         400.0       150.0    4997          14.0
# 93   12.00          8         400.0       167.0    4906          12.5
# 94   13.00          8         360.0       170.0    4654          13.0
# 95   12.00          8         350.0       180.0    4499          12.5
# 96   18.00          6         232.0       100.0    2789          15.0
# 97   21.00          4         140.0        72.0    2401          19.5
# 98   19.00          4         122.0        85.0    2310          18.5
# 99   21.00          6         155.0       107.0    2472          14.0
# 100  26.00          4          98.0        90.0    2265          15.5
# 101  15.00          8         350.0       145.0    4082          13.0
# 102  16.00          8         400.0       230.0    4278           9.5
# 103  29.00          4          68.0        49.0    1867          19.5
# 104  24.00          4         116.0        75.0    2158          15.5
# 105  20.00          4         114.0        91.0    2582          14.0
# 106  19.00          4         121.0       112.0    2868          15.5
# 107  15.00          8         318.0       150.0    3399          11.0
# 108  24.00          4         121.0       110.0    2660          14.0
# 109  11.00          8         350.0       180.0    3664          11.0
# 110  20.00          6         198.0        95.0    3102          16.5
# 111  21.00          6         200.0         NaN    2875          17.0
# 112  19.00          6         232.0       100.0    2901          16.0
# 113  15.00          6         250.0       100.0    3336          17.0
# 114  26.00          4         122.0        80.0    2451          16.5
# 115  25.00          4         140.0        75.0    2542          17.0
# 116  16.00          6         250.0       100.0    3781          17.0
# 117  16.00          6         258.0       110.0    3632          18.0
# 118  18.00          6         225.0       105.0    3613          16.5
# 119  16.00          8         302.0       140.0    4141          14.0
# 120  13.00          8         350.0       150.0    4699          14.5
# 121  14.00          8         318.0       150.0    4457          13.5
# 122  14.00          8         302.0       140.0    4638          16.0
# 123  14.00          8         304.0       150.0    4257          15.5
# 124  29.00          4          98.0        83.0    2219          16.5
# 125  26.00          4          79.0        67.0    1963          15.5
# 126  26.00          4          97.0        78.0   23000          14.5
# 127  28.00          4          90.0        75.0    2125          14.5
# 128  24.00          4          90.0        75.0    2108          15.5
# 129  26.00          4         116.0        75.0    2246          14.0
# 130  31.00          4          79.0        67.0    2000          16.0
# 131  19.00          6         225.0        95.0    3264          16.0
# 132  18.00          6         250.0       105.0    3459          16.0
# 133  15.00          6         250.0        72.0    3432          21.0
# 134  15.00          6         250.0        72.0    3158          19.5
# 135  16.00          8         400.0       170.0    4668          11.5
# 136  15.00          8         350.0       145.0    4440          14.0
# 137  16.00          8         318.0       150.0    4498          14.5
# 138  14.00          8         351.0       148.0    4657          13.5
# 139  17.00          6         231.0       110.0    3907          21.0
# 140  16.00          6         250.0       105.0    3897          18.5
# 141  15.00          6         258.0       110.0    3730          19.0
# 142  18.00          6         225.0        95.0    3785          19.0
# 143  21.00          6         231.0       110.0    3039          15.0
# 144  20.00          8         262.0       110.0    3221          13.5
# 145  13.00          8         302.0       129.0    3169          12.0
# 146  23.00          4         140.0        83.0    2639          17.0
# 147  20.00          6         232.0       100.0    2914          16.0
# 148  23.00          4         140.0        78.0    2592          18.5
# 149  25.00          4          90.0        71.0    2223          16.5
# 150  18.00          6         171.0        97.0    2984          14.5
# 151  29.00          4          90.0        70.0    1937          14.0
# 152  19.00          6         232.0        90.0    3211          17.0
# 153  23.00          4         115.0        95.0    2694          15.0
# 154  23.00          4         120.0        88.0    2957          17.0
# 155  22.00          4         121.0        98.0    2945          14.5
# 156  25.00          4         121.0       115.0    2671          13.5
# 157  28.00          4         107.0        86.0    2464          15.5
# 158  25.00          4         116.0        81.0    2220          16.9
# 159  25.00          4         140.0        92.0    2572          14.9
# 160  26.00          4          98.0        79.0    2255          17.7
# 161  27.00          4         101.0        83.0    2202          15.3
# 162  17.50          8         305.0       140.0    4215          13.0
# 163  16.00          8         318.0       150.0    4190          13.0
# 164  15.50          8         304.0       120.0    3962          13.9
# 165  14.50          8         351.0       152.0    4215          12.8
# 166  22.00          6         225.0       100.0    3233          15.4
# 167  22.00          6         250.0       105.0    3353          14.5
# 168  24.00          6         200.0        81.0    3012          17.6
# 169  22.50          6         232.0        90.0    3085          17.6
# 170  29.00          4          85.0        52.0    2035          22.2
# 171  24.50          4          98.0        60.0    2164          22.1
# 172  29.00          4          90.0        70.0    1937          14.2
# 173  20.00          6         225.0       100.0    3651          17.7
# 174  18.00          6         250.0        78.0    3574          21.0
# 175  18.50          6         250.0       110.0    3645          16.2
# 176  17.50          6         258.0        95.0    3193          17.8
# 177  29.50          4          97.0        71.0    1825          12.2
# 178  26.50          4         140.0        72.0    2565          13.6
# 179  20.00          4         130.0       102.0    3150          15.7
# 180  13.00          8         318.0       150.0    3940          13.2
# 181  19.00          4         120.0        88.0    3270          21.9
# 182  16.50          6         168.0       120.0    3820          16.7
# 183  16.50          8         350.0       180.0    4380          12.1
# 184  13.00          8         350.0       145.0    4055          12.0
# 185  13.00          8         302.0       130.0    3870          15.0
# 186  13.00          8         318.0       150.0    3755          14.0
# 187  30.00          4         111.0        80.0    2155          14.8
# 188  36.00          4          79.0        58.0    1825          18.6
# 189  25.50          4         122.0        96.0    2300          15.5
# 190  17.50          8         305.0       145.0    3880          12.5
# 191  17.00          8         260.0       110.0    4060          19.0
# 192  15.50          8         318.0       145.0    4140          13.7
# 193  15.00          8         302.0       130.0    4295          14.9
# 194  17.50          6         250.0       110.0    3520          16.4
# 195  20.50          6         231.0       105.0    3425          16.9
# 196  19.00          6         225.0       100.0    3630          17.7
# 197  18.50          6         250.0        98.0    3525          19.0
# 198  16.00          8         400.0       180.0    4220          11.1
# 199  15.50          8         350.0       170.0    4165          11.4
# 200  15.50          8         400.0       190.0    4325          12.2
# 201  16.00          8         351.0       149.0    4335          14.5
# 202  29.00          4          97.0        78.0    1940          14.5
# 203  24.50          4         151.0        88.0    2740          16.0
# 204  25.50          4         140.0        89.0    2755          15.8
# 205  30.50          4          98.0        63.0    2051          17.0
# 206  33.50          4          98.0        83.0    2075          15.9
# 207  30.50          4          97.0        78.0    2190          14.1
# 208  21.50          4         121.0       110.0    2600          12.8
# 209  43.10          4          90.0        48.0    1985          21.5
# 210  36.10          4          98.0        66.0    1800          14.4
# 211  19.90          8         260.0       110.0    3365          15.5
# 212  19.40          8         318.0       140.0    3735          13.2
# 213  20.20          8         302.0       139.0    3570          12.8
# 214  19.20          6         231.0       105.0    3535          19.2
# 215  20.50          6         200.0        95.0    3155          18.2
# 216  20.20          6         200.0        85.0    2965          15.8
# 217  25.10          4         140.0        88.0    2720          15.4
# 218  20.50          6         225.0       100.0    3430          17.2
# 219  19.40          6         232.0        90.0    3210          17.2
# 220  20.60          6         231.0       105.0    3380          15.8
# 221  20.80          6         200.0        85.0    3070          16.7
# 222  18.60          6         225.0       110.0    3620          18.7
# 223  18.10          6         258.0       120.0    3410          15.1
# 224  19.20          8         305.0       145.0    3425          13.2
# 225  17.70          6         231.0       165.0    3445          13.4
# 226  18.10          8         302.0       139.0    3205          11.2
# 227  17.50          8         318.0       140.0    4080          13.7
# 228  30.00          4          98.0        68.0    2155          16.5
# 229  30.90          4         105.0        75.0    2230          14.5
# 230  23.20          4         156.0       105.0    2745          16.7
# 231  23.80          4         151.0        85.0    2855          17.6
# 232  20.30          5         131.0       103.0    2830          15.9
# 233  17.00          6         163.0       125.0    3140          13.6
# 234  21.60          4         121.0       115.0    2795          15.7
# 235  16.20          6         163.0       133.0    3410          15.8
# 236  31.50          4          89.0        71.0    1990          14.9
# 237  21.50          6         231.0       115.0    3245          15.4
# 238  19.80          6         200.0        85.0    2990          18.2
# 239  22.30          4         140.0        88.0    2890          17.3
# 240  20.20          6         232.0        90.0    3265          18.2
# 241  20.60          6         225.0       110.0    3360          16.6
# 242  17.00          8         305.0       130.0    3840          15.4
# 243  17.60          8         302.0       129.0    3725          13.4
# 244   0.06          8         351.0       138.0    3955          13.2
# 245  18.20          8         318.0       135.0    3830          15.2
# 246  16.90          8         350.0       155.0    4360          14.9
# 247  15.50          8         351.0       142.0    4054          14.3
# 248  19.20          8         267.0       125.0    3605          15.0
# 249  18.50          8         360.0       150.0    3940          13.0
# 250  31.90          4          89.0        71.0    1925          14.0
# 251  35.70          4          98.0        80.0    1915          14.4
# 252  27.40          4         121.0        80.0    2670          15.0
# 253  25.40          5         183.0        77.0    3530          20.1
# 254  23.00          8         350.0       125.0    3900          17.4
# 255  27.20          4         141.0        71.0    3190          24.8
# 256  23.90          8         260.0        90.0    3420          22.2
# 257  34.20          4         105.0        70.0    2200          13.2
# 258  34.50          4         105.0        70.0    2150          14.9
# 259  37.30          4          91.0        69.0    2130          14.7
# 260  28.40          4         151.0        90.0    2670          16.0
# 261  28.80          6         173.0       115.0    2595          11.3
# 262  26.80          6         173.0       115.0    2700          12.9
# 263  33.50          4         151.0        90.0    2556          13.2
# 264  41.50          4          98.0        76.0    2144          14.7
# 265  32.10          4          98.0        70.0    2120          15.5
# 266  28.00          4         151.0        90.0    2678          16.5
# 267  26.40          4         140.0        88.0    2870          18.1
# 268  24.30          4         151.0        90.0    3003          20.1
# 269  19.10          6         225.0        90.0    3381          18.7
# 270  34.30          4          97.0        78.0    2188          15.8
# 271  27.90          4         156.0       105.0    2800          14.4
# 272  44.30          4          90.0        48.0    2085          21.7
# 273  43.40          4          90.0        48.0    2335          23.7
# 274  36.40          5         121.0        67.0    2950          19.9
# 275  30.00          4         146.0        67.0    3250          21.8
# 276  40.90          4          85.0         NaN    1835          17.3
# 277  29.80          4          89.0        62.0    1845          15.3
# 278  35.00          4         122.0        88.0    2500          15.1
# 279  23.60          4         140.0         NaN    2905          14.3
# 280  27.20          4         135.0        84.0    2490          15.7
# 281  26.60          4         151.0        84.0    2635          16.4
# 282  25.80          4         156.0        92.0    2620          14.4
# 283  23.50          6         173.0       110.0    2725          12.6
# 284  30.00          4         135.0        84.0    2385          12.9
# 285  39.00          4          86.0        64.0    1875          16.4
# 286  34.70          4         105.0        63.0    2215          14.9
# 287  34.40          4          98.0        65.0    2045          16.2
# 288  29.90          4          98.0        65.0    2380          20.7
# 289  33.00          4         105.0        74.0    2190          14.2
# 290  34.50          4         100.0         NaN    2320          15.8
# 291  28.10          4         141.0        80.0    3230          20.4
# 292  30.70          6         145.0        76.0    3160          19.6
# 293  22.40          6         231.0       110.0    3415          15.8
# 294  26.60          8         350.0       105.0    3725          19.0
# 295  20.20          6         200.0        88.0    3060          17.1
# 296  17.60          6         225.0        85.0    3465          16.6
# 297  28.00          4         112.0        88.0    2605          19.6
# 298  27.00          4         112.0        88.0    2640          18.6
# 299  34.00          4         112.0        88.0    2395          18.0
# 300  31.00          4         112.0        85.0    2575          16.2
# 301  29.00          4         135.0        84.0    2525          16.0
# 302  27.00          4         151.0        90.0    2735          18.0
# 303  24.00          4         140.0        92.0    2865          16.4
# 304  23.00          4         151.0         NaN    3035          20.5
# 305  36.00          4         105.0        74.0    1980          15.3
# 306  38.00          4         105.0        63.0    2125          14.7
# 307  36.00          4          98.0        70.0    2125          17.3
# 308  25.00          6         181.0       110.0    2945          16.4
# 309  38.00          6         262.0        85.0    3015          17.0
# 310  26.00          4         156.0        92.0    2585          14.5
# 311  22.00          6         232.0       112.0    2835          14.7
# 312  36.00          4         135.0        84.0    2370          13.0
# 313  27.00          4         151.0        90.0    2950          17.3
# 314  27.00          4         140.0        86.0    2790          15.6
# 315  44.00          4          97.0        52.0    2130          24.6
# 316  32.00          4         135.0        84.0    2295          11.6
# 317  28.00          4         120.0        79.0    2625          18.6
# 318  31.00          4         119.0        82.0    2720          19.4
# 319  25.00          4         104.0        95.0    2375          17.5
# 320  14.00          8         340.0       160.0    3609           8.0
# 321  13.00          8         360.0       170.0    4654          13.0
# 322  16.00          6         258.0       110.0    3632          18.0
# 323  24.30          4         151.0        90.0    3003          20.1
# 324  12.00          8         429.0       198.0    4952          11.5
# 325  27.00          4         101.0        83.0    2202          15.3
# 326  17.00          6         250.0       100.0    3329          15.5
# 327  14.50          8         351.0       152.0    4215          12.8
# 328  25.00          6         181.0       110.0    2945          16.4
#
#      model year         origin                                     name
# 0            70  United States               chevrolet chevelle malibu
# 1            70  United States                       buick skylark 320
# 2            70  United States                      plymouth satellite
# 3            70            usa                           amc rebel sst
# 4            70            usa                             FORD TORINO
# 5            70            usa                        FORD GALAXIE 500
# 6            70            usa                        chevrolet impala
# 7            70            usa                       plymouth fury iii
# 8            70            usa                        pontiac catalina
# 9            70            usa                      amc ambassador dpl
# 10           70            usa                     dodge challenger se
# 11           70            usa                      plymouth 'cuda 340
# 12           70            usa                   chevrolet monte carlo
# 13           70            usa                 buick estate wagon (sw)
# 14           70            usa                         plymouth duster
# 15           70            usa                              amc hornet
# 16           70            usa                           ford maverick
# 17           70         europe                    vw 1131 deluxe sedan
# 18           70         europe                             peugeot 504
# 19           70         europe                             audi 100 ls
# 20           70         europe                                saab 99e
# 21           70         europe                                bmw 2002
# 22           70            usa                             amc gremlin
# 23           70            usa                               ford f250
# 24           70            usa                           chevrolet c20
# 25           70            usa                              dodge d200
# 26           70            usa                                ih 1200d
# 27           71            usa                     chevrolet vega 2300
# 28           71            usa                              ford pinto
# 29           71            usa                             amc gremlin
# 30           71            usa               plymouth satellite custom
# 31           71            usa               chevrolet chevelle malibu
# 32           71            usa                         ford torino 500
# 33           71            usa                             amc matador
# 34           71            usa                        chevrolet impala
# 35           71            usa               pontiac catalina brougham
# 36           71            usa                        ford galaxie 500
# 37           71            usa                       plymouth fury iii
# 38           71            usa                       dodge monaco (sw)
# 39           71            usa                ford country squire (sw)
# 40           71            usa                     pontiac safari (sw)
# 41           71            usa              amc hornet sportabout (sw)
# 42           71            usa                     chevrolet vega (sw)
# 43           71            usa                        pontiac firebird
# 44           71            usa                            ford mustang
# 45           71            usa                      mercury capri 2000
# 46           71         europe                               opel 1900
# 47           71         europe                             peugeot 304
# 48           71         europe                               fiat 124b
# 49           71         europe                            vw model 111
# 50           71            usa                        plymouth cricket
# 51           72            usa                      dodge colt hardtop
# 52           72         europe                               vw type 3
# 53           72            usa                          chevrolet vega
# 54           72            usa                     ford pinto runabout
# 55           72            usa                        chevrolet impala
# 56           72            usa                        pontiac catalina
# 57           72            usa                       plymouth fury iii
# 58           72            usa                        ford galaxie 500
# 59           72            usa                      amc ambassador sst
# 60           72            usa                         mercury marquis
# 61           72            usa                    buick lesabre custom
# 62           72            usa              oldsmobile delta 88 royale
# 63           72            usa                  chrysler newport royal
# 64           72            usa                        amc matador (sw)
# 65           72            usa        chevrolet chevelle concours (sw)
# 66           72            usa                   ford gran torino (sw)
# 67           72            usa          plymouth satellite custom (sw)
# 68           72         europe                         volvo 145e (sw)
# 69           72         europe                             vw 411 (sw)
# 70           72         europe                        peugeot 504 (sw)
# 71           72         europe                         renault 12 (sw)
# 72           72            usa                         ford pinto (sw)
# 73           72            usa                         dodge colt (sw)
# 74           73            usa                       buick century 350
# 75           73            usa                             amc matador
# 76           73            usa                        chevrolet malibu
# 77           73            usa                        ford gran torino
# 78           73            usa                    dodge coronet custom
# 79           73            usa                mercury marquis brougham
# 80           73            usa               chevrolet caprice classic
# 81           73            usa                                ford ltd
# 82           73            usa                plymouth fury gran sedan
# 83           73            usa            chrysler new yorker brougham
# 84           73            usa                buick electra 225 custom
# 85           73            usa                 amc ambassador brougham
# 86           73            usa                        plymouth valiant
# 87           73            usa                   chevrolet nova custom
# 88           73            usa                              amc hornet
# 89           73            usa                           ford maverick
# 90           73            usa                         plymouth duster
# 91           73         europe                         vw super beetle
# 92           73            usa                        chevrolet impala
# 93           73            usa                            ford country
# 94           73            usa                  plymouth custom suburb
# 95           73            usa                oldsmobile vista cruiser
# 96           73            usa                             amc gremlin
# 97           73            usa                          chevrolet vega
# 98           73            usa                              ford pinto
# 99           73            usa                        mercury capri v6
# 100          73         europe                    fiat 124 sport coupe
# 101          73            usa                 chevrolet monte carlo s
# 102          73            usa                      pontiac grand prix
# 103          73         europe                                fiat 128
# 104          73         europe                              opel manta
# 105        1973         europe                              audi 100ls
# 106        1973         europe                             volvo 144ea
# 107        1973            usa                       dodge dart custom
# 108        1973         europe                               saab 99le
# 109        1973            usa                        oldsmobile omega
# 110          74            usa                         plymouth duster
# 111          74            usa                           ford maverick
# 112          74            usa                              amc hornet
# 113          74            usa                          chevrolet nova
# 114          74            usa                              ford pinto
# 115          74            usa                          chevrolet vega
# 116          74            usa       chevrolet chevelle malibu classic
# 117          74            usa                             amc matador
# 118          74            usa              plymouth satellite sebring
# 119          74            usa                        ford gran torino
# 120          74            usa                buick century luxus (sw)
# 121          74            usa               dodge coronet custom (sw)
# 122          74            usa                   ford gran torino (sw)
# 123          74            usa                        amc matador (sw)
# 124          74         europe                                audi fox
# 125          74         europe                               vw dasher
# 126          74         europe                              opel manta
# 127          74            usa                              dodge colt
# 128          74         europe                                fiat 128
# 129          74         europe                             fiat 124 tc
# 130          74         europe                               fiat x1.9
# 131          75            usa                 plymouth valiant custom
# 132          75            usa                          chevrolet nova
# 133          75            usa                         mercury monarch
# 134          75            usa                           ford maverick
# 135          75            usa                        pontiac catalina
# 136          75            usa                       chevrolet bel air
# 137          75            usa                     plymouth grand fury
# 138          75            usa                                ford ltd
# 139          75            usa                           buick century
# 140          75            usa               chevrolet chevelle malibu
# 141          75            usa                             amc matador
# 142          75            usa                           plymouth fury
# 143          75            usa                           buick skyhawk
# 144          75            usa                     chevrolet monza 2+2
# 145          75            usa                         ford mustang ii
# 146          75            usa                              ford pinto
# 147          75            usa                             amc gremlin
# 148          75            usa                           pontiac astro
# 149          75         europe                               vw dasher
# 150          75            usa                              ford pinto
# 151          75         europe                               vw rabbit
# 152          75            usa                               amc pacer
# 153          75         europe                              audi 100ls
# 154          75         europe                             peugeot 504
# 155          75         europe                             volvo 244dl
# 156          75         europe                               saab 99le
# 157          76         europe                                fiat 131
# 158          76         europe                               opel 1900
# 159          76            usa                        mercury capri ii
# 160          76            usa                              dodge colt
# 161          76         europe                            renault 12tl
# 162          76            usa       chevrolet chevelle malibu classic
# 163          76            usa                  dodge coronet brougham
# 164          76            usa                             amc matador
# 165          76            usa                        ford gran torino
# 166          76            usa                        plymouth valiant
# 167          76            usa                          chevrolet nova
# 168          76            usa                           ford maverick
# 169          76            usa                              amc hornet
# 170          76            usa                      chevrolet chevette
# 171          76            usa                         chevrolet woody
# 172          76         europe                               vw rabbit
# 173          76            usa                          dodge aspen se
# 174          76            usa                       ford granada ghia
# 175          76            usa                      pontiac ventura sj
# 176          76            usa                           amc pacer d/l
# 177          76         europe                               vw rabbit
# 178          76            usa                              ford pinto
# 179          76         europe                               volvo 245
# 180          76            usa              plymouth volare premier v8
# 181          76         europe                             peugeot 504
# 182          76         europe                      mercedes-benz 280s
# 183          76            usa                        cadillac seville
# 184          76            usa                           chevrolet c10
# 185          76            usa                               ford f108
# 186          76            usa                              dodge d100
# 187          77            usa                 buick opel isuzu deluxe
# 188          77         europe                           renault 5 gtl
# 189          77            usa                       plymouth arrow gs
# 190          77            usa               chevrolet caprice classic
# 191          77            usa              oldsmobile cutlass supreme
# 192          77            usa                   dodge monaco brougham
# 193          77            usa                 mercury cougar brougham
# 194          77            usa                      chevrolet concours
# 195          77            usa                           buick skylark
# 196          77            usa                  plymouth volare custom
# 197          77            usa                            ford granada
# 198          77            usa                   pontiac grand prix lj
# 199          77            usa            chevrolet monte carlo landau
# 200          77            usa                        chrysler cordoba
# 201          77            usa                        ford thunderbird
# 202          77         europe                        vw rabbit custom
# 203          77            usa                   pontiac sunbird coupe
# 204          77            usa                     ford mustang ii 2+2
# 205          77            usa                      chevrolet chevette
# 206          77            usa                          dodge colt m/m
# 207          77         europe                               vw dasher
# 208          77         europe                                bmw 320i
# 209          78         europe                 vw rabbit custom diesel
# 210          78            usa                             ford fiesta
# 211          78            usa       oldsmobile cutlass salon brougham
# 212          78            usa                          dodge diplomat
# 213          78            usa                    mercury monarch ghia
# 214          78            usa                      pontiac phoenix lj
# 215          78            usa                        chevrolet malibu
# 216          78            usa                    ford fairmont (auto)
# 217          78            usa                     ford fairmont (man)
# 218          78            usa                         plymouth volare
# 219          78            usa                             amc concord
# 220          78            usa                   buick century special
# 221          78            usa                          mercury zephyr
# 222          78            usa                             dodge aspen
# 223          78            usa                         amc concord d/l
# 224          78            usa            chevrolet monte carlo landau
# 225          78            usa         buick regal sport coupe (turbo)
# 226          78            usa                             ford futura
# 227          78            usa                         dodge magnum xe
# 228          78            usa                      chevrolet chevette
# 229          78            usa                              dodge omni
# 230          78            usa                        plymouth sapporo
# 231          78            usa                  oldsmobile starfire sx
# 232          78         europe                               audi 5000
# 233          78         europe                             volvo 264gl
# 234          78         europe                              saab 99gle
# 235          78         europe                           peugeot 604sl
# 236          78         europe                             vw scirocco
# 237          79            usa                       pontiac lemans v6
# 238          79            usa                        mercury zephyr 6
# 239          79            usa                         ford fairmont 4
# 240          79            usa                        amc concord dl 6
# 241          79            usa                           dodge aspen 6
# 242          79            usa               chevrolet caprice classic
# 243          79            usa                         ford ltd landau
# 244          79            usa                   mercury grand marquis
# 245          79            usa                         dodge st. regis
# 246          79            usa                 buick estate wagon (sw)
# 247          79            usa                ford country squire (sw)
# 248          79            usa           chevrolet malibu classic (sw)
# 249          79            usa    chrysler lebaron town @ country (sw)
# 250          79         europe                        vw rabbit custom
# 251          79            usa             dodge colt hatchback custom
# 252          79            usa                           amc spirit dl
# 253          79         europe                      mercedes-benz 300d
# 254          79            usa                       cadillac eldorado
# 255          79         europe                             peugeot 504
# 256          79            usa       oldsmobile cutlass salon brougham
# 257          79            usa                        plymouth horizon
# 258          79            usa                    plymouth horizon tc3
# 259          79         europe                      fiat strada custom
# 260          79            usa                   buick skylark limited
# 261          79            usa                      chevrolet citation
# 262          79            usa               oldsmobile omega brougham
# 263          79            usa                         pontiac phoenix
# 264          80         europe                               vw rabbit
# 265          80            usa                      chevrolet chevette
# 266          80            usa                      chevrolet citation
# 267          80            usa                           ford fairmont
# 268          80            usa                             amc concord
# 269          80            usa                             dodge aspen
# 270          80         europe                               audi 4000
# 271          80            usa                              dodge colt
# 272          80         europe                    vw rabbit c (diesel)
# 273          80         europe                      vw dasher (diesel)
# 274          80         europe                     audi 5000s (diesel)
# 275          80         europe                      mercedes-benz 240d
# 276          80         europe                    renault lecar deluxe
# 277          80         europe                               vw rabbit
# 278          80         europe                       triumph tr7 coupe
# 279          80            usa                      ford mustang cobra
# 280          81            usa                        plymouth reliant
# 281          81            usa                           buick skylark
# 282          81            usa                  dodge aries wagon (sw)
# 283          81            usa                      chevrolet citation
# 284          81            usa                        plymouth reliant
# 285          81            usa                          plymouth champ
# 286          81            usa                      plymouth horizon 4
# 287          81            usa                          ford escort 4w
# 288          81            usa                          ford escort 2h
# 289          81         europe                                vw jetta
# 290          81         europe                             renault 18i
# 291          81         europe               peugeot 505s turbo diesel
# 292          81         europe                            volvo diesel
# 293          81            usa                           buick century
# 294          81            usa                   oldsmobile cutlass ls
# 295          81            usa                         ford granada gl
# 296          81            usa                  chrysler lebaron salon
# 297          82            usa                      chevrolet cavalier
# 298          82            usa                chevrolet cavalier wagon
# 299          82            usa               chevrolet cavalier 2-door
# 300          82            usa              pontiac j2000 se hatchback
# 301          82            usa                          dodge aries se
# 302          82            usa                         pontiac phoenix
# 303          82            usa                    ford fairmont futura
# 304          82            usa                          amc concord dl
# 305          82         europe                             vw rabbit l
# 306          82            usa                  plymouth horizon miser
# 307          82            usa                          mercury lynx l
# 308          82            usa                   buick century limited
# 309          82            usa       oldsmobile cutlass ciera (diesel)
# 310          82            usa              chrysler lebaron medallion
# 311          82            usa                          ford granada l
# 312          82            usa                       dodge charger 2.2
# 313          82            usa                        chevrolet camaro
# 314          82            usa                         ford mustang gl
# 315          82         europe                               vw pickup
# 316          82            usa                           dodge rampage
# 317          82            usa                             ford ranger
# 318          82            usa                          chevrolet s-10
# 319          70         europe                                saab 99e
# 320          70            usa                      plymouth 'cuda 340
# 321          73            usa                  plymouth custom suburb
# 322          74            usa                             amc matador
# 323          80            usa                             amc concord
# 324          73            usa                mercury marquis brougham
# 325          76         europe                            renault 12tl
# 326          71            usa               chevrolet chevelle malibu
# 327          76            usa                        ford gran torino
# 328          82            usa                   buick century limited

# %%
cars.origin.value_counts()
# Out:
# origin
# usa              254
# europe            72
# United States      3
# Name: count, dtype: int64

# %%
cars.loc[:,'origin'] = cars.origin.map({'usa': 'United States', 'europe': 'Europe', 'United States': 'United States'})

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year         origin                          name
# 0          70  United States    chevrolet chevelle malibu
# 1          70  United States            buick skylark 320
# 2          70  United States           plymouth satellite
# 3          70  United States                amc rebel sst
# 4          70  United States                  FORD TORINO

# %%
cars['name'] = cars.name.str.title()

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year         origin                          name
# 0          70  United States    Chevrolet Chevelle Malibu
# 1          70  United States            Buick Skylark 320
# 2          70  United States           Plymouth Satellite
# 3          70  United States                Amc Rebel Sst
# 4          70  United States                  Ford Torino

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           329 non-null    float64
#  1   cylinders     329 non-null    int64
#  2   displacement  329 non-null    float64
#  3   horsepower    323 non-null    float64
#  4   weight        329 non-null    int64
#  5   acceleration  329 non-null    float64
#  6   model year    329 non-null    int64
#  7   origin        329 non-null    object
#  8   name          329 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 23.3+ KB

# %%
cars.to_csv('cars_cleaned.csv', index = False)

# %%
cars['name'] = cars['name'].str.strip()

# %%
cars.horsepower.value_counts(dropna = False)
# Out:
# horsepower
# 150.000000    22
# 90.000000     19
# 110.000000    19
# 100.000000    16
# 88.000000     14
# 105.000000    12
# 95.000000     10
# 85.000000      9
# 70.000000      8
# 80.000000      7
# 140.000000     7
# 145.000000     7
# 84.000000      6
# 78.000000      6
# 75.000000      6
# 170.000000     6
# 71.000000      5
# 72.000000      5
# 83.000000      5
# 180.000000     5
# 115.000000     5
# 175.000000     5
# 86.000000      5
# 130.000000     5
# 79.932331      5
# 92.000000      4
# 165.000000     4
# 67.000000      4
# 76.000000      4
# 198.000000     3
# 63.000000      3
# 215.000000     3
# 112.000000     3
# 225.000000     3
# 125.000000     3
# 190.000000     3
# 160.000000     3
# 48.000000      3
# 120.000000     3
# 129.000000     2
# 52.000000      2
# 152.000000     2
# 79.000000      2
# 81.000000      2
# 139.000000     2
# 98.000000      2
# 60.000000      2
# 153.000000     2
# 74.000000      2
# 97.000000      2
# 46.000000      2
# 69.000000      2
# 87.000000      2
# 155.000000     2
# 65.000000      2
# 103.000000     1
# 64.000000      1
# 62.000000      1
# 149.000000     1
# 68.000000      1
# 77.000000      1
# 142.000000     1
# 66.000000      1
# 135.000000     1
# 138.000000     1
# 133.000000     1
# 89.000000      1
# 167.000000     1
# 96.000000      1
# 137.000000     1
# 220.000000     1
# 113.000000     1
# 200.000000     1
# 210.000000     1
# 193.000000     1
# 54.000000      1
# 208.000000     1
# 158.000000     1
# 58.000000      1
# 107.000000     1
# 230.000000     1
# 49.000000      1
# 91.000000      1
# 100.625000     1
# 148.000000     1
# 102.000000     1
# 82.000000      1
# Name: count, dtype: int64

# %%
cars.horsepower.fillna(cars.groupby('cylinders').horsepower.transform('mean'), inplace = True)
# Out:
# C:\Users\Mehak Chawla\AppData\Local\Temp\ipykernel_25192\4031885044.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cars.horsepower.fillna(cars.groupby('cylinders').horsepower.transform('mean'), inplace = True)

# %%
cars.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cars.info()
#
# NameError: name 'cars' is not defined

# %%
cars = pd.read_csv('cars_cleaned.csv')

# %%
import pandas as pd

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 324  12.0          8         429.0       198.0    4952          11.5
# 325  27.0          4         101.0        83.0    2202          15.3
# 326  17.0          6         250.0       100.0    3329          15.5
# 327  14.5          8         351.0       152.0    4215          12.8
# 328  25.0          6         181.0       110.0    2945          16.4
#
#      model year         origin                       name
# 0            70  United States  Chevrolet Chevelle Malibu
# 1            70  United States          Buick Skylark 320
# 2            70  United States         Plymouth Satellite
# 3            70  United States              Amc Rebel Sst
# 4            70  United States                Ford Torino
# ..          ...            ...                        ...
# 324          73  United States   Mercury Marquis Brougham
# 325          76         Europe               Renault 12Tl
# 326          71  United States  Chevrolet Chevelle Malibu
# 327          76  United States           Ford Gran Torino
# 328          82  United States      Buick Century Limited
#
# [329 rows x 9 columns]

# %%
cars[cars.duplicated(keep= False) == True]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11   14.0          8         340.0       160.0    3609           8.0
# 20   25.0          4         104.0        95.0    2375          17.5
# 31   17.0          6         250.0       100.0    3329          15.5
# 79   12.0          8         429.0       198.0    4952          11.5
# 94   13.0          8         360.0       170.0    4654          13.0
# 117  16.0          6         258.0       110.0    3632          18.0
# 161  27.0          4         101.0        83.0    2202          15.3
# 165  14.5          8         351.0       152.0    4215          12.8
# 268  24.3          4         151.0        90.0    3003          20.1
# 308  25.0          6         181.0       110.0    2945          16.4
# 319  25.0          4         104.0        95.0    2375          17.5
# 320  14.0          8         340.0       160.0    3609           8.0
# 321  13.0          8         360.0       170.0    4654          13.0
# 322  16.0          6         258.0       110.0    3632          18.0
# 323  24.3          4         151.0        90.0    3003          20.1
# 324  12.0          8         429.0       198.0    4952          11.5
# 325  27.0          4         101.0        83.0    2202          15.3
# 326  17.0          6         250.0       100.0    3329          15.5
# 327  14.5          8         351.0       152.0    4215          12.8
# 328  25.0          6         181.0       110.0    2945          16.4
#
#      model year         origin                       name
# 11           70  United States         Plymouth 'Cuda 340
# 20           70         Europe                   Saab 99E
# 31           71  United States  Chevrolet Chevelle Malibu
# 79           73  United States   Mercury Marquis Brougham
# 94           73  United States     Plymouth Custom Suburb
# 117          74  United States                Amc Matador
# 161          76         Europe               Renault 12Tl
# 165          76  United States           Ford Gran Torino
# 268          80  United States                Amc Concord
# 308          82  United States      Buick Century Limited
# 319          70         Europe                   Saab 99E
# 320          70  United States         Plymouth 'Cuda 340
# 321          73  United States     Plymouth Custom Suburb
# 322          74  United States                Amc Matador
# 323          80  United States                Amc Concord
# 324          73  United States   Mercury Marquis Brougham
# 325          76         Europe               Renault 12Tl
# 326          71  United States  Chevrolet Chevelle Malibu
# 327          76  United States           Ford Gran Torino
# 328          82  United States      Buick Century Limited

# %%
cars.drop_duplicates
